# %% [markdown]
# # Deals Part 2: The Power of SQL `SELECT`s

# %% [markdown]
# *This notebook uses SQL select statements to learn about mergers and acquisitions in the 1990s. No, actually it's just all about SELECT statements.*

# %% [markdown]
# ## Library Imports & Database Connection
# Some version of the following will need to appear near the top of every notebook in this course. It imports the necessary software libraries and connects to a database

# %%
# All query results are returned as Pandas DataFrames 
import pandas as pd

# Needed for %sql Magic
# %load_ext sql

# use %sql magic to connect to the deals database
# %sql mysql+pymysql://dealsuser:deals@localhost/deals
# Out:
# 'Connected: dealsuser@deals'

# %% [markdown]
# Let's review, line by line:
# - The code above is actually Python, which is what Jupyter prefers to use natively.
# - The lines that start with `#` are comments with English text explaining what the line below is about.
# - The `import` line allows us to use the pandas library that is all the rage at data science parties. pandas -- note that the p is is never capitalized -- provides data structures that emulate database tables. We won't make use of it here but it may be useful in later assignments.
# - The `%load_ext` statement extends Jupyter to allow SQL statements instead of Python. Any statement that starts with %sql or %%sql is run as SQL instead of Python. For details of how this works, RTFM at the [ipython-sql](https://github.com/catherinedevlin/ipython-sql) repo on GitHub.
# - The last line uses `%sql` to connect to an online MySQL database. The pseudo-URL at the end (complete with `://` in the middle) tells Jupyter
#     i) how to connect (i.e., using the pymysql bridge),
#     ii) what kind of database server is on the other end of the connection (i.e., mysql),
#     iii) who is connecting (i.e., login with user `dealsuser` and password `deals`), and
#     iv) where to connect to (i.e., a databse called `deals` hosted on the local [same] computer as Jupyter).

# %% [markdown]
# ## A Brief Warmup
# To make sure that everything is working correctly, let's try a basic `SELECT` query. Copy the following into the code cell below.
#
# ```SQL
# %%sql
# /* Indicate that we are using the deals database */
# USE deals;
# /* Execute a test query  */
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc."
# ```
# A few notes:
# - `%%sql` magic allows us to split SQL statements onto multiple lines.
# - `US`E indicates what database to use, which is useful when there are multiple database connections (e.g., when copying data from one database to another).
# - SQL comments use `/*  */` format.
# - The `SELECT` statement is broken out into multiple clauses, each with a different purpose. The last clause (`WHERE CompanyName like "%Inc."`) restricts the listing to only companies with "Inc." at the end of their names.
# - The table names are case sensitive! If we were to use `COMPANIES` instead of `Companies` then the query breaks. Try it yourself! (Why the nonstandard name? When this database was first created in 1998, it was distributed as an MS Access database, which always followed CamelCase for table names.)

# %%
# %%sql
# USE deals;
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc.";
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 0 rows affected.
# 111 rows affected.
# [(2, 'Abitibi-Price Inc.'),
#  (5, 'AirTouch Communications, Inc.'),
#  (6, 'Alex. Brown Inc.'),
#  (7, 'Allegheny Power System Inc.'),
#  (318, 'American Bankers Insurance Group Inc.'),
#  (319, 'American International Group Inc.'),
#  (11, 'American Medical Response, Inc.'),
#  (13, 'American Standard Companies, Inc.'),
#  (19, 'Apria Healthcare Group Inc.'),
#  (20, 'Ascend Communications, Inc.'),
#  (25, 'Barnett Banks, Inc.'),
#  (314, 'BDM International Inc.'),
#  (311, 'Beckman Instruments, Inc.'),
#  (31, 'Brooks Fiber Properties, Inc.'),
#  (33, 'Burlington Resources Inc.'),
#  (35, 'Calilber Systems Inc.'),
#  (37, 'Cardinal Health, Inc.'),
#  (303, 'Caterpillar Inc.'),
#  (41, 'Central Fidelity Banks Inc.'),
#  (42, 'Century Telephone Enterprises Inc.'),
#  (279, 'Ciba Specialty Chemicals Inc.'),
#  (50, 'Clear Channel Communications, Inc.'),
#  (52, 'Coca-Cola Enterprises Inc.'),
#  (64, 'CUC International Inc.'),
#  (68, 'Destec Energy, Inc.'),
#  (70, 'DowBrands Inc.'),
#  (71, 'DQE Inc.'),
#  (79, 'Evans Withycombe Residential Inc.'),
#  (81, 'Excel Communications, Inc.'),
#  (85, 'First Bank System, Inc.'),
#  (89, 'First USA, Inc.'),
#  (90, 'Fisher Scientific International Inc.'),
#  (91, 'Fleet Financial Group, Inc.'),
#  (93, 'Fox Kids Worldwide Inc.'),
#  (94, 'Fred Meyer Inc.'),
#  (96, 'GPU, Inc.'),
#  (97, 'GranCare Inc.'),
#  (99, 'Greenfield Industries, Inc.'),
#  (102, 'Healthsource, Inc.'),
#  (278, 'Hercules Inc.'),
#  (108, 'HFS Inc.'),
#  (109, 'Hicks, Muse, Tate & Furst Inc.'),
#  (112, 'Homeside, Inc.'),
#  (114, 'Household International Inc.'),
#  (115, 'HSN Inc.'),
#  (122, 'Integrated Health Services Inc.'),
#  (123, 'International Family Entertainment Inc.'),
#  (126, 'Investor Group led by Transworld Healthcare Inc.'),
#  (130, 'JP Foodservice Inc.'),
#  (131, 'Kennametal Inc.'),
#  (132, 'Keystone International Inc.'),
#  (138, 'Laidlaw Environmental Services, Inc.'),
#  (140, 'Laidlaw Inc.'),
#  (145, 'Living Centers of America Inc.'),
#  (150, 'Lucent Technologies Inc.'),
#  (151, "Mac Frugal's Bargains & Close-Outs Inc."),
#  (152, 'Mallinckrodt Inc.'),
#  (300, 'Mapco Inc.'),
#  (153, 'Marriott International, Inc.'),
#  (154, 'Marsh & McLennan Companies, Inc.'),
#  (155, 'McAfee Associates Inc.'),
#  (156, 'McClatchy Newspapers, Inc.'),
#  (159, 'MedPartners, Inc.'),
#  (162, 'MESA, Inc.'),
#  (163, 'Monterey Resources Inc.'),
#  (165, 'Morgan Stanley Group Inc.'),
#  (170, 'Nellcor Puritan Bennett Inc.'),
#  (317, 'Newcourt Credit Group Inc.'),
#  (282, 'Ocean Energy Inc.'),
#  (177, 'Outdoor Systems Inc.'),
#  (178, 'Overseas Shipholding Group, Inc.'),
#  (179, 'Pacific Telecom Inc.'),
#  (183, 'Patriot American Hospitality Inc.'),
#  (187, 'PhyCor Inc.'),
#  (194, 'Quality Food Centers Inc.'),
#  (197, 'Raycom Media, Inc.'),
#  (296, 'Renal Treatment Centers Inc.'),
#  (202, 'Revco D.S., Inc.'),
#  (204, 'Rohr Inc.'),
#  (205, 'Rollins Environmental Services, Inc.'),
#  (207, 'Rykoff Sexton Inc.'),
#  (208, 'S.C. Johnson & Son Inc.'),
#  (211, 'Salomon Inc.'),
#  (213, 'Scudder, Stevens & Clark Inc.'),
#  (217, 'SFX Broadcasting Inc.'),
#  (289, 'Showboat Inc.'),
#  (294, 'Simon DeBartolo Group Inc.'),
#  (280, 'Sonat Inc.'),
#  (226, 'Tambrands Inc.'),
#  (227, 'Tandem Computers Inc.'),
#  (228, 'Target Therapeutics, Inc.'),
#  (231, 'Telco Communications Group Inc.'),
#  (232, 'Tele-Communications, Inc.'),
#  (233, 'Tencor Instruments Inc.'),
#  (234, 'Texaco Inc.'),
#  (297, 'Total Renal Care Holdings Inc.'),
#  (315, 'TRW Inc.'),
#  (246, 'U.S. West, Inc.'),
#  (247, 'Union Pacific Resources Group Inc.'),
#  (248, 'United Waste Systems, Inc.'),
#  (249, 'Universal Outdoor Holdings Inc.'),
#  (250, 'Universal Studios, Inc.'),
#  (252, 'USA Waste Services Inc.'),
#  (255, 'Value Health, Inc.'),
#  (256, 'Vencor, Inc.'),
#  (257, 'Verifone, Inc.'),
#  (259, 'Vivra Inc.'),
#  (261, 'Wal-Mart Stores, Inc.'),
#  (262, 'Washington Mutual Inc.'),
#  (264, 'Western Resources, Inc.'),
#  (268, 'WorldCom, Inc.')]

# %% [markdown]
# ## Your First Bug
# Run the code below, which has two SQL statements in a row. It has a bug, as indicated by a cryptic error message:
# > (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'SELECT *\nFROM Companies\nORDER BY CompanyID' at line 7")
#
# What does `Error Code: 1064` mean? It's a syntax error. Can you spot the bug in the code? In this case it's pretty subtle: we are missing a semi-colon (`;`) at the end of each SELECT statement. Add the missing semi-colons and rerun. It should work now (though only the results of the second query will be shown; it's a Jupyter thing).

# %%
# %%sql
# /* Select companies whose names end with Inc. */
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc.";
#
# /* Select companies sorted by CompanyName */
# SELECT *
# FROM Companies
# ORDER BY CompanyID
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 111 rows affected.
# 10 rows affected.
# [(1, '3Com Corporation'),
#  (2, 'Abitibi-Price Inc.'),
#  (3, 'ADT Limited'),
#  (4, 'Advanta Corp. Credit card unit'),
#  (5, 'AirTouch Communications, Inc.'),
#  (6, 'Alex. Brown Inc.'),
#  (7, 'Allegheny Power System Inc.'),
#  (8, 'Allied Irish Banks P.L.C.'),
#  (9, 'American Electric Power Co. Inc. and Public Service'),
#  (10, 'American General Corp.')]

# %% [markdown]
# ## Your First Join
# Now let's add another query, this time with data from two tables: `Deals` and `DealParts`.

# %%
# %%sql
# SELECT DealName,PartNumber,DollarValue
# FROM Deals, DealParts
# WHERE Deals.DealID = DealParts.DealID
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 10 rows affected.
# [('ADT Limited', 1, Decimal('5600.0000')),
#  ('Advanta Corp.', 1, Decimal('1300.0000')),
#  ('Alex. Brown Inc.', 1, Decimal('1700.0000')),
#  ('Allied Colloids Group PLC', 1, Decimal('1810.0000')),
#  ('American First Financial Insurance Group Inc.', 1, Decimal('2200.0000')),
#  ('American Medical Response, Inc.', 1, Decimal('1120.0000')),
#  ('American Radio Systems Corp.', 1, Decimal('2600.0000')),
#  ('American Standard Companies, Inc.', 1, Decimal('4000.0000')),
#  ('Amerisource Health Corp.', 1, Decimal('2322.0000')),
#  ('Amphenol Corp.', 1, Decimal('1500.0000'))]

# %% [markdown]
# Here we used the `WHERE` clause to indicate that the `DealID` on the `Deals` table has to match the `DealID` on the `DealParts` table. Believe it or not, that basic logic (that keys on one table have t match keys on anther table) is exactly 92% of the power of the Relational Database Model. We can now just end the course now. How about the final exam next week?

# %% [markdown]
# More seriously, while using the `WHERE` clause to match records from different tables works, it s not very efficient. Instead we will want to use a `JOIN .. USING` operator, which is optimized to work with millions of records without breaking a sweat. In this case we don't even need a WHERE clause!

# %%
# %%sql
# SELECT DealName,PartNumber,DollarValue
# FROM Deals
#      JOIN DealParts USING (DealID)
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 10 rows affected.
# [('ADT Limited', 1, Decimal('5600.0000')),
#  ('Advanta Corp.', 1, Decimal('1300.0000')),
#  ('Alex. Brown Inc.', 1, Decimal('1700.0000')),
#  ('Allied Colloids Group PLC', 1, Decimal('1810.0000')),
#  ('American First Financial Insurance Group Inc.', 1, Decimal('2200.0000')),
#  ('American Medical Response, Inc.', 1, Decimal('1120.0000')),
#  ('American Radio Systems Corp.', 1, Decimal('2600.0000')),
#  ('American Standard Companies, Inc.', 1, Decimal('4000.0000')),
#  ('Amerisource Health Corp.', 1, Decimal('2322.0000')),
#  ('Amphenol Corp.', 1, Decimal('1500.0000'))]

# %% [markdown]
# We can actually 'chain' table joins to link in data from as many tables as we want. We just have to specify what columns to use as keys! Each join in the chain creates a virtual table onto which we can join another table.

# %%
# %%sql
# SELECT DealName,LongCode as Role,CompanyName
# FROM Companies
#     JOIN Players USING (CompanyID)
#     JOIN RoleCodes USING (RoleCode)
#     JOIN Deals USING (DealID)
# ORDER BY DealName
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 10 rows affected.
# [('ADT Limited', 'Target', 'ADT Limited'),
#  ('ADT Limited', 'Second Bidder', 'Tyco International Ltd.'),
#  ('ADT Limited', 'First Bidder', 'Western Resources, Inc.'),
#  ('Advanta Corp.', 'Acquiror', 'Fleet Financial Group, Inc.'),
#  ('Advanta Corp.', 'Target', 'Advanta Corp. Credit card unit'),
#  ('Alex. Brown Inc.', 'Acquiror', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Target', 'Alex. Brown Inc.'),
#  ('Allied Colloids Group PLC', 'Target', 'Allied Colloids Group'),
#  ('Allied Colloids Group PLC', 'First Bidder', 'Hercules Inc.'),
#  ('American First Financial Insurance Group Inc.', 'Acquiror', 'American International Group Inc.')]

# %% [markdown]
# Study the database schema below to see more opportunities to join tables. You will use this as a guide in the queries that follow.
#  ![Deals ERD](img/img2_7.png)

# %% [markdown]
# ## Challenge Queries: Now for the Fun Stuff
# Three queries are described below. In the code cell provided after each description, write a SQL query that best answers the question. Each query should answer the question completely, without us humans needing to do any sorting, counting, etc.
#
# Don't forget to start each query cell with `%%sql`.
#
# It's okay to collaborate with your classmates. Just be sure that you are typing out your own code.

# %% [markdown]
# ### Query 1: Lots of joins
# **For each deal, list every firm involved, what supporting role it played, and which company it supported.**
# You will need to output the following fields:
# - `DealName` from the `Deals` table
# - `Name` from the `Firms` table
# - `LongCode` from the `SupportCodes` table
# - `CompanyName` from the `Companies` table
#
# You will also need to use keys from the `Players` and `PlayerSupport` tables.

# %%
# %%sql
# -- Need Players and PlayerSupport because they connect
# SELECT DISTINCT DealName, Name AS 'FirmName', LongCode AS 'SupportRole', CompanyName
# FROM Deals
#     JOIN Players USING (DealID)
#     JOIN Companies USING (CompanyID)
#     JOIN PlayerSupports USING (PlayerID)
#     JOIN Firms USING (FirmID)
#     JOIN SupportCodes USING (SupportCodeID);
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 1264 rows affected.
# [('Alex. Brown Inc.', 'BT Wolfensohn', 'Investment Adviser', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Debevoise & Plimpton', 'Counsel', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Kissel-Blake Inc.', 'Proxy Solicitor', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Bankers Trust New York Corporation'),
#  ('American Medical Response, Inc.', 'Katten Muchin & Zavis', 'Outside Counsel', 'Laidlaw Inc.'),
#  ('American Medical Response, Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Laidlaw Inc.'),
#  ('American Medical Response, Inc.', 'Simpson Thacher & Bartlett', 'Counsel', 'Laidlaw Inc.'),
#  ('Amphenol Corp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'Kekst and Company', 'Public Relations Firm', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'MacKenzie Partners, Inc.', 'Proxy Solicitor', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'Kohlberg Kravis Roberts & Co.'),
#  ('Berliner Kraft & Licht AG', 'Dresdner Kleinwort Benson', 'Investment Adviser', 'Inv. Group led by Southern Comp. and Viag AG'),
#  ('Berliner Kraft & Licht AG', 'Troutman Sanders', 'Outside Counsel', 'Inv. Group led by Southern Comp. and Viag AG'),
#  ('Cascade Communications Corp.', 'Deutsche Morgan Grenfell', 'Investment Adviser', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'Gallagher PR', 'Public Relations Firm', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'Gray Carey Ware & Friedenrich', 'Outside Counsel', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'Richards, Layton & Finger', 'Outside Counsel', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'Skinner & Co.', 'Proxy Solicitor', 'Ascend Communications, Inc.'),
#  ('Chancellor Broadcasting Comp.', 'Jaffoni & Collins Inc.', 'Public Relations Firm', 'Evergreen Media Corporation'),
#  ('Chancellor Broadcasting Comp.', 'Latham & Watkins', 'Outside Counsel', 'Evergreen Media Corporation'),
#  ('Chancellor Broadcasting Comp.', 'Morris, Nichols, Arsht & Tunnell', 'Outside Counsel', 'Evergreen Media Corporation'),
#  ('Chancellor Broadcasting Comp.', 'Paul, Weiss, Rifkind, Wharton & Garrison', 'Counsel', 'Evergreen Media Corporation'),
#  ('Chancellor Broadcasting Comp.', 'Wasserstein Perella & Co. Inc.', 'Investment Adviser', 'Evergreen Media Corporation'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'CIBC Wood Gundy Securities, Inc.', 'Proxy Solicitor', 'Coca-Cola Enterprises Inc.'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'Credit Suisse First Boston', 'Investment Adviser', 'Coca-Cola Enterprises Inc.'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'Long Aldridge Norman', 'Outside Counsel', 'Coca-Cola Enterprises Inc.'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'Miller & Martin', 'Outside Counsel', 'Coca-Cola Enterprises Inc.'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'Shearman & Sterling', 'Counsel', 'Coca-Cola Enterprises Inc.'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'Stikeman, Elliot', 'Outside Counsel', 'Coca-Cola Enterprises Inc.'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'Union Bank of Switzerland', 'Investment Adviser', 'Coca-Cola Enterprises Inc.'),
#  ('Dauphin Deposit Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Allied Irish Banks P.L.C.'),
#  ('Dauphin Deposit Corp.', 'Simpson Thacher & Bartlett', 'Counsel', 'Allied Irish Banks P.L.C.'),
#  ('Dauphin Deposit Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Allied Irish Banks P.L.C.'),
#  ('The Dow Chemical Company', 'Credit Suisse First Boston', 'Investment Adviser', 'S.C. Johnson & Son Inc.'),
#  ('The Dow Chemical Company', 'Kirkland & Ellis', 'Outside Counsel', 'S.C. Johnson & Son Inc.'),
#  ('The Dow Chemical Company', 'Tanner & Co. Inc.', 'Investment Adviser', 'S.C. Johnson & Son Inc.'),
#  ('DQE Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Allegheny Power System Inc.'),
#  ('DQE Inc.', 'Sullivan & Cromwell', 'Outside Counsel', 'Allegheny Power System Inc.'),
#  ('DQE Inc.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'Allegheny Power System Inc.'),
#  ('Eller Media Corp.', 'Akin Gump', 'Securities Counsel', 'Clear Channel Communications, Inc.'),
#  ('Eller Media Corp.', 'Daniels & Associates', 'Investment Adviser', 'Clear Channel Communications, Inc.'),
#  ('Eller Media Corp.', 'Piper & Marbury', 'Outside Counsel', 'Clear Channel Communications, Inc.'),
#  ('The Energy Group PLC', 'Goldman, Sachs & Co.', 'Investment Adviser', 'PacifiCorp'),
#  ('The Energy Group PLC', 'Linklaters & Paines', 'Outside Counsel', 'PacifiCorp'),
#  ('The Energy Group PLC', 'Shareholder Communications Corporation', 'Proxy Solicitor', 'PacifiCorp'),
#  ('The Energy Group PLC', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'PacifiCorp'),
#  ('The Energy Group PLC', 'Stoel Rives', 'Outside Counsel', 'PacifiCorp'),
#  ('First Financial Corp.', 'Shearman & Sterling', 'Outside Counsel', 'Associated Banc-Corp'),
#  ('First USA, Inc.', 'Lazard Freres & Co. LLC', 'Investment Adviser', 'Banc One Corporation'),
#  ('First USA, Inc.', 'UBS Securities', 'Investment Adviser', 'Banc One Corporation'),
#  ('First USA, Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Banc One Corporation'),
#  ('First USA, Inc.', 'Willkie Farr & Gallagher', 'Counsel', 'Banc One Corporation'),
#  ('Fort Howard Corp.', 'Burson-Marsteller', 'Public Relations Firm', 'James River Corp.'),
#  ('Fort Howard Corp.', 'McGuire, Woods, Battle & Boothe', 'Outside Counsel', 'James River Corp.'),
#  ('Fort Howard Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'James River Corp.'),
#  ('Fort Howard Corp.', 'Salomon Brothers Inc.', 'Investment Adviser', 'James River Corp.'),
#  ('Fort Howard Corp.', 'Simpson Thacher & Bartlett', 'Counsel', 'James River Corp.'),
#  ('Fort Howard Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'James River Corp.'),
#  ('General Motors Corp.', 'Bear, Stearns & Co., Inc.', 'Investment Adviser', 'Raytheon Company'),
#  ('General Motors Corp.', 'Credit Suisse First Boston', 'Investment Adviser', 'Raytheon Company'),
#  ('General Motors Corp.', 'Dewey Ballantine', 'Counsel', 'Raytheon Company'),
#  ('General Motors Corp.', 'Paul, Weiss, Rifkind, Wharton & Garrison', 'Counsel', 'Raytheon Company'),
#  ('General Motors Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Raytheon Company'),
#  ('General Motors Corp.', 'White & Case', 'Outside Counsel', 'Raytheon Company'),
#  ('Healthsource, Inc.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'CIGNA Corporation'),
#  ('Healthsource, Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'CIGNA Corporation'),
#  ('Healthsource, Inc.', 'Jones, Day, Reavis & Pogue', 'Outside Counsel', 'CIGNA Corporation'),
#  ('Healthsource, Inc.', 'Sullivan & Cromwell', 'Counsel', 'CIGNA Corporation'),
#  ('Hercules Inc. and Mallickrodt Inc', 'Davis Polk & Wardell', 'Outside Counsel', 'Roche Holding AG'),
#  ('Heritage Media Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'The News Corporation Limited'),
#  ('Heritage Media Corp.', 'Squardon, Ellenoff, Plesent & Sheinfeld', 'Outside Counsel', 'The News Corporation Limited'),
#  ('HFS Inc.', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'CUC International Inc.'),
#  ('HFS Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'CUC International Inc.'),
#  ('HFS Inc.', 'Robinson Lerer & Montgomery', 'Public Relations Firm', 'CUC International Inc.'),
#  ('HFS Inc.', 'Sullivan & Cromwell', 'Counsel', 'CUC International Inc.'),
#  ('HFS Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'CUC International Inc.'),
#  ('Horizon/CMS Healthcare Corp.', 'Dewey Ballantine', 'Counsel', 'HealthSouth Corp.'),
#  ('Horizon/CMS Healthcare Corp.', 'Morrow & Co., Inc.', 'Proxy Solicitor', 'HealthSouth Corp.'),
#  ('Horizon/CMS Healthcare Corp.', 'Noonan/Russo Communications, Inc.', 'Public Relations Firm', 'HealthSouth Corp.'),
#  ('Horizon/CMS Healthcare Corp.', 'Smith Barney Inc.', 'Investment Adviser', 'HealthSouth Corp.'),
#  ('International Family Entertainment Inc.', 'Potter Anderson & Corroon', 'Outside Counsel', 'Fox Kids Worldwide Inc.'),
#  ('International Family Entertainment Inc.', 'Squardon, Ellenoff', 'Outside Counsel', 'Fox Kids Worldwide Inc.'),
#  ('International Family Entertainment Inc.', 'Troop, Meisinger, Steuer, Pasich', 'Outside Counsel', 'Fox Kids Worldwide Inc.'),
#  ('Johnson & Higgins', 'J.P. Morgan & Co., Inc.', 'Investment Adviser', 'Marsh & McLennan Companies, Inc.'),
#  ('Johnson & Higgins', 'Kekst and Company', 'Public Relations Firm', 'Marsh & McLennan Companies, Inc.'),
#  ('Johnson & Higgins', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'Marsh & McLennan Companies, Inc.'),
#  ('Keystone International Inc.', 'Kekst and Company', 'Public Relations Firm', 'Tyco International Ltd.'),
#  ('Keystone International Inc.', 'Kramer, Levin, Naftalis & Frankel', 'Outside Counsel', 'Tyco International Ltd.'),
#  ('Keystone International Inc.', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'Tyco International Ltd.'),
#  ('Keystone International Inc.', 'Smith Barney Inc.', 'Investment Adviser', 'Tyco International Ltd.'),
#  ('KU Energy Corporation', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'LG&E Energy Corporation'),
#  ('KU Energy Corporation', 'Davis Polk & Wardell', 'Counsel', 'LG&E Energy Corporation'),
#  ('KU Energy Corporation', 'Dewey Ballantine', 'Outside Counsel', 'LG&E Energy Corporation'),
#  ('KU Energy Corporation', 'Gardner, Carton & Douglas', 'Outside Counsel', 'LG&E Energy Corporation'),
#  ('KU Energy Corporation', 'Ketchum Public Relations', 'Public Relations Firm', 'LG&E Energy Corporation'),
#  ('KU Energy Corporation', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'LG&E Energy Corporation'),
#  ('KU Energy Corporation', 'The Blackstone Group L.P.', 'Investment Adviser', 'LG&E Energy Corporation'),
#  ('Lincoln National Corporation', 'Broadgate Consultants', 'Public Relations Firm', 'Safeco Corporation'),
#  ('Lincoln National Corporation', 'Perkins Coie', 'Outside Counsel', 'Safeco Corporation'),
#  ('Lincoln National Corporation', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'Safeco Corporation'),
#  ('Lincoln National Corporation', 'Smith Barney Inc.', 'Investment Adviser', 'Safeco Corporation'),
#  ('Lincoln National Corporation', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Safeco Corporation'),
#  ('Minnesota Mining and Manufacturing Comp.', 'CIBC Wood Gundy Inc.', 'Investment Adviser', 'Outdoor Systems Inc.'),
#  ('Minnesota Mining and Manufacturing Comp.', 'Powell, Goldstein, Frazer & Murphy', 'Outside Counsel', 'Outdoor Systems Inc.'),
#  ('Morgan Stanley Group Inc.', 'Cravath, Swaine & Moore', 'Outside Counsel', 'Dean Witter Discover & Co.'),
#  ('Morgan Stanley Group Inc.', 'Richards, Layton & Finger', 'Outside Counsel', 'Dean Witter Discover & Co.'),
#  ('Morgan Stanley Group Inc.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'Dean Witter Discover & Co.'),
#  ('Morgan Stanley Group Inc.', 'Wasserstein Perella & Co. Inc.', 'Investment Adviser', 'Dean Witter Discover & Co.'),
#  ('Pacificorp', 'Boles & Boles', 'Outside Counsel', 'Century Telephone Enterprises Inc.'),
#  ('Pacificorp', 'Carrerre & Denegre', 'Antitrust Counsel', 'Century Telephone Enterprises Inc.'),
#  ('Pacificorp', 'Chadbourne & Parke', 'Counsel', 'Century Telephone Enterprises Inc.'),
#  ('Pacificorp', 'Jones, Walker, Wachter, Poitevent, Carrere & Denegre', 'Outside Counsel', 'Century Telephone Enterprises Inc.'),
#  ('Pacificorp', 'Lazard Freres & Co. LLC', 'Investment Adviser', 'Century Telephone Enterprises Inc.'),
#  ('Parker & Parsley Petrolium Company', 'Baker & Botts', 'Outside Counsel', 'MESA, Inc.'),
#  ('Parker & Parsley Petrolium Company', 'Merrill Lynch & Co.', 'Investment Adviser', 'MESA, Inc.'),
#  ('Parker & Parsley Petrolium Company', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'MESA, Inc.'),
#  ('Parker & Parsley Petrolium Company', 'Morrow & Co., Inc.', 'Proxy Solicitor', 'MESA, Inc.'),
#  ('Parker & Parsley Petrolium Company', 'Richards, Layton & Finger', 'Outside Counsel', 'MESA, Inc.'),
#  ('Parker & Parsley Petrolium Company', 'Shearman & Sterling', 'Counsel', 'MESA, Inc.'),
#  ('Parker & Parsley Petrolium Company', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'MESA, Inc.'),
#  ('Read-Rite Corp.', 'Chadbourne & Parke', 'Counsel', 'Applied Magnetics Corp.'),
#  ('Read-Rite Corp.', 'Gleacher Natwest Inc.', 'Investment Adviser', 'Applied Magnetics Corp.'),
#  ('Safety-Kleen Corp.', 'Innisfree M&A Inc.', 'Proxy Solicitor', 'Laidlaw Environmental Services, Inc.'),
#  ('Revco D.S., Inc.', 'Dewey Ballantine', 'Investment Adviser', 'CVS Corporation'),
#  ('Read-Rite Corp.', 'Morris, Nichols, Arsht & Tunnell', 'Delaware Counsel', 'Applied Magnetics Corp.'),
#  ('Renaissance Hotel Group N.V.', 'Gibson, Dunn & Crutcher', 'Counsel', 'Marriott International, Inc.'),
#  ('Read-Rite Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'Applied Magnetics Corp.'),
#  ('Revco D.S., Inc.', 'Credit Suisse First Boston', 'Investment Adviser', 'CVS Corporation'),
#  ('Revco D.S., Inc.', 'Davis Polk & Wardell', 'Outside Counsel', 'CVS Corporation'),
#  ('Revco D.S., Inc.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'CVS Corporation'),
#  ('Revco D.S., Inc.', 'Kekst and Company', 'Public Relations Firm', 'CVS Corporation'),
#  ('Revco D.S., Inc.', 'Sullivan & Cromwell', 'Counsel', 'CVS Corporation'),
#  ('Stone-Consolidated Corp.', 'Credit Suisse First Boston', 'Investment Adviser', 'Abitibi-Price Inc.'),
#  ('Stone-Consolidated Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'Abitibi-Price Inc.'),
#  ('Stone-Consolidated Corp.', 'Tory, Tory, DesLauriers & Binnington', 'Outside Counsel', 'Abitibi-Price Inc.'),
#  ('Tambrands Inc.', 'Cleary, Gottlieb, Steen & Hamilton', 'Outside Counsel', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'Dinsmore & Shohl', 'Outside Counsel', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'Jones, Day, Reavis & Pogue', 'Antitrust Counsel', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'Morris, Nichols, Arsht & Tunnell', 'Outside Counsel', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'SJ Berwin & Co.', 'Outside Counsel', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'The Dilenschneider Group', 'Public Relations Firm', 'Procter & Gamble Co.'),
#  ('Target Therapeutics, Inc.', 'Lehman Brothers', 'Investment Adviser', 'Boston Scientific Corporation'),
#  ('Target Therapeutics, Inc.', 'Shearman & Sterling', 'Outside Counsel', 'Boston Scientific Corporation'),
#  ('Telco Communications Group Inc.', 'Lehman Brothers', 'Investment Adviser', 'Excel Communications, Inc.'),
#  ('Telco Communications Group Inc.', 'Milbank, Tweed, Hadley & McCloy', 'Counsel', 'Excel Communications, Inc.'),
#  ('Telco Communications Group Inc.', 'Munsch Hardt Kopf Harr & Dinan', 'Outside Counsel', 'Excel Communications, Inc.'),
#  ('Telco Communications Group Inc.', 'Weil, Gotshal & Manges', 'Outside Counsel', 'Excel Communications, Inc.'),
#  ('Telco Communications Group Inc.', 'Wilcox & Savage', 'Outside Counsel', 'Excel Communications, Inc.'),
#  ('Tencor Instruments Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'KLA Instruments Corporation'),
#  ('Tencor Instruments Inc.', 'Paul, Weiss, Rifkind, Wharton & Garrison', 'Counsel', 'KLA Instruments Corporation'),
#  ('Tencor Instruments Inc.', 'Paul, Weiss, Rifkind, Wharton & Garrison', 'Antitrust Counsel', 'KLA Instruments Corporation'),
#  ('Tencor Instruments Inc.', 'Skinner & Co.', 'Proxy Solicitor', 'KLA Instruments Corporation'),
#  ('Tencor Instruments Inc.', 'Wilson, Sonsini, Goodrich & Rosati', 'Outside Counsel', 'KLA Instruments Corporation'),
#  ('Texas Instruments Inc.', 'Bear, Stearns & Co., Inc.', 'Investment Adviser', 'Raytheon Company'),
#  ('Texas Instruments Inc.', 'Paul, Weiss, Rifkind, Wharton & Garrison', 'Counsel', 'Raytheon Company'),
#  ('Texas Instruments Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Raytheon Company'),
#  ('Texas Instruments Inc.', 'White & Case', 'Outside Counsel', 'Raytheon Company'),
#  ('Transamerica Corp.', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'Household International Inc.'),
#  ('Transamerica Corp.', 'Wilmer, Cutler & Pickering', 'Outside Counsel', 'Household International Inc.'),
#  ('The Unilever Group', 'Davis Polk & Wardell', 'Outside Counsel', 'Imperial Chemical Industries PLC'),
#  ('The Unilever Group', 'Freshfields', 'Outside Counsel', 'Imperial Chemical Industries PLC'),
#  ('The Unilever Group', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Imperial Chemical Industries PLC'),
#  ('The Unilever Group', 'SBC Warburg', 'Investment Adviser', 'Imperial Chemical Industries PLC'),
#  ('United Waste Systems, Inc.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'USA Waste Services Inc.'),
#  ('United Waste Systems, Inc.', 'McDermott, Will & Emery', 'Outside Counsel', 'USA Waste Services Inc.'),
#  ('United Waste Systems, Inc.', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'USA Waste Services Inc.'),
#  ('Uslife Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'American General Corp.'),
#  ('U.S. Robotics Corp.', 'Goldman, Sachs & Co.', 'Investment Adviser', '3Com Corporation'),
#  ('U.S. Robotics Corp.', 'Gray Carey Ware & Friedenrich', 'Outside Counsel', '3Com Corporation'),
#  ('U.S. Robotics Corp.', 'Richards, Layton & Finger', 'Outside Counsel', '3Com Corporation'),
#  ('U.S. Robotics Corp.', 'Sullivan & Cromwell', 'Counsel', '3Com Corporation'),
#  ('U.S. West, Inc.', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'AirTouch Communications, Inc.'),
#  ('U.S. West, Inc.', 'Pillsbury Madison & Sutro', 'Outside Counsel', 'AirTouch Communications, Inc.'),
#  ('U.S. West, Inc.', 'Richards, Layton & Finger', 'Outside Counsel', 'AirTouch Communications, Inc.'),
#  ('Valero Energy Corp.', 'Fulbright & Jaworski', 'Outside Counsel', 'PG&E Corporation'),
#  ('Valero Energy Corp.', 'Kekst and Company', 'Public Relations Firm', 'PG&E Corporation'),
#  ('Valero Energy Corp.', 'LeBoeuf, Lamb, Greene & MacRae', 'Outside Counsel', 'PG&E Corporation'),
#  ('Valero Energy Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'PG&E Corporation'),
#  ('Valero Energy Corp.', 'Orrick, Herrington & Sutcliffe', 'Outside Counsel', 'PG&E Corporation'),
#  ('Value Health, Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'Columbia-HCA Healthcare Corporation'),
#  ('Value Health, Inc.', 'Furman Selz Inc.', 'Investment Adviser', 'Columbia-HCA Healthcare Corporation'),
#  ('Verifone, Inc.', 'Drinker Biddle & Reath', 'Antitrust Counsel', 'Hewlett-Packard Company'),
#  ('Verifone, Inc.', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'Hewlett-Packard Company'),
#  ('Verifone, Inc.', 'Wilson, Sonsini, Goodrich & Rosati', 'Outside Counsel', 'Hewlett-Packard Company'),
#  ('Viacom Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Seagram Co.'),
#  ('Viacom Inc.', 'Munger, Tolles & Olson', 'Outside Counsel', 'Seagram Co.'),
#  ('Viacom Inc.', 'Sullivan & Cromwell', 'Counsel', 'Seagram Co.'),
#  ('Viacom Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Seagram Co.'),
#  ('Viacom Inc.', 'Young, Conaway, Stargatt & Taylor', 'Outside Counsel', 'Seagram Co.'),
#  ('Vivra Inc.', 'Citigate Inc.', 'Public Relations Firm', 'Incentive AB'),
#  ('Vivra Inc.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'Incentive AB'),
#  ('Vivra Inc.', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'Incentive AB'),
#  ('Vivra Inc.', 'Shearman & Sterling', 'Outside Counsel', 'Incentive AB'),
#  ('Vivra Inc.', 'UBS Securities', 'Investment Adviser', 'Incentive AB'),
#  ('Wyndham Hotel Corp.', 'Goodwin, Procter & Hoar', 'Outside Counsel', 'Patriot American Hospitality Inc.'),
#  ('Wyndham Hotel Corp.', 'Morris, Nichols, Arsht & Tunnell', 'Outside Counsel', 'Patriot American Hospitality Inc.'),
#  ('Yorkshire Electricity', 'Allen & Overy', 'Outside Counsel', 'American Electric Power Co. Inc. and Public Service'),
#  ('Yorkshire Electricity', 'Cahill Gordon & Reindel', 'Counsel', 'American Electric Power Co. Inc. and Public Service'),
#  ('Yorkshire Electricity', 'Financial Dynamics', 'Public Relations Firm', 'American Electric Power Co. Inc. and Public Service'),
#  ('Yorkshire Electricity', 'Linklaters & Paines', 'Counsel', 'American Electric Power Co. Inc. and Public Service'),
#  ('Yorkshire Electricity', 'Merrill Lynch & Co.', 'Investment Adviser', 'American Electric Power Co. Inc. and Public Service'),
#  ('Yorkshire Electricity', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'American Electric Power Co. Inc. and Public Service'),
#  ('Yorkshire Electricity', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'American Electric Power Co. Inc. and Public Service'),
#  ('Celebrity Cruise Lines Inc', 'Davis Polk & Wardell', 'Outside Counsel', 'Royal Caribbean Cruises Ltd.'),
#  ('Celebrity Cruise Lines Inc', 'Neal, Gerber & Eisenberg', 'Outside Counsel', 'Royal Caribbean Cruises Ltd.'),
#  ('Central Fidelity Banks Inc.', 'Credit Suisse First Boston', 'Investment Adviser', 'Wachovia Corporation'),
#  ('Central Fidelity Banks Inc.', 'Simpson Thacher & Bartlett', 'Counsel', 'Wachovia Corporation'),
#  ('Central Fidelity Banks Inc.', 'Sullivan & Cromwell', 'Outside Counsel', 'Wachovia Corporation'),
#  ('Cigna Corporation', 'Merrill Lynch & Co.', 'Investment Adviser', 'Lincoln National Corporation'),
#  ('Cigna Corporation', 'Sard Verbinnen & Co., Inc.', 'Public Relations Firm', 'Lincoln National Corporation'),
#  ('Cigna Corporation', 'Sutherland, Asbill & Brennan', 'Outside Counsel', 'Lincoln National Corporation'),
#  ('Equitable of Iowa Companies', 'Salomon Brothers Inc.', 'Investment Adviser', 'ING Group NV'),
#  ('Equitable of Iowa Companies', 'Sullivan & Cromwell', 'Outside Counsel', 'ING Group NV'),
#  ('Falcon Drilling Co.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'Reading & Bates Corporation'),
#  ('Falcon Drilling Co.', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'Reading & Bates Corporation'),
#  ('Falcon Drilling Co.', 'Richards, Layton & Finger', 'Outside Counsel', 'Reading & Bates Corporation'),
#  ('Imperial Chemical Industries PLC', 'BT Wolfensohn', 'Investment Adviser', 'DuPont Co.'),
#  ('Imperial Chemical Industries PLC', 'Cleary, Gottlieb, Steen & Hamilton', 'Outside Counsel', 'DuPont Co.'),
#  ('The Louisiana Land and Exploration Company', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'Burlington Resources Inc.'),
#  ('The Louisiana Land and Exploration Company', 'Davis Polk & Wardell', 'Counsel', 'Burlington Resources Inc.'),
#  ('The Louisiana Land and Exploration Company', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'Burlington Resources Inc.'),
#  ('The Louisiana Land and Exploration Company', 'Kekst and Company', 'Public Relations Firm', 'Burlington Resources Inc.'),
#  ('The Louisiana Land and Exploration Company', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'Burlington Resources Inc.'),
#  ('The Louisiana Land and Exploration Company', 'White & Case', 'Outside Counsel', 'Burlington Resources Inc.'),
#  ('Montgomery Securities', 'Credit Suisse First Boston', 'Investment Adviser', 'NationsBank Corporation'),
#  ('Montgomery Securities', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'NationsBank Corporation'),
#  ('The Multicare Companies, Inc.', 'Cleary, Gottlieb, Steen & Hamilton', 'Outside Counsel', 'Genesis ElderCare Corp., Cypress Group & TX Pacifi'),
#  ('The Multicare Companies, Inc.', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'Genesis ElderCare Corp., Cypress Group & TX Pacifi'),
#  ('The Multicare Companies, Inc.', 'Davis Polk & Wardell', 'Counsel', 'Genesis ElderCare Corp., Cypress Group & TX Pacifi'),
#  ('The Multicare Companies, Inc.', 'Montgomery Securities', 'Investment Adviser', 'Genesis ElderCare Corp., Cypress Group & TX Pacifi'),
#  ('The Multicare Companies, Inc.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Genesis ElderCare Corp., Cypress Group & TX Pacifi'),
#  ('The Multicare Companies, Inc.', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'Genesis ElderCare Corp., Cypress Group & TX Pacifi'),
#  ('New York State Electric & Gas Corp.', 'Credit Suisse First Boston', 'Investment Adviser', 'CalEnergy Co.'),
#  ('New York State Electric & Gas Corp.', 'Lehman Brothers', 'Investment Adviser', 'CalEnergy Co.'),
#  ('New York State Electric & Gas Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'CalEnergy Co.'),
#  ('New York State Electric & Gas Corp.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'CalEnergy Co.'),
#  ('New York State Electric & Gas Corp.', 'White & Case', 'Outside Counsel', 'CalEnergy Co.'),
#  ('New York State Electric & Gas Corp.', 'Willkie Farr & Gallagher', 'Outside Counsel', 'CalEnergy Co.'),
#  ('Northrop Grumman Corp.', 'Bear, Stearns & Co., Inc.', 'Investment Adviser', 'Lockheed Martin Corp.'),
#  ('Northrop Grumman Corp.', 'Dewey Ballantine', 'Outside Counsel', 'Lockheed Martin Corp.'),
#  ('Northrop Grumman Corp.', 'Lehman Brothers', 'Investment Adviser', 'Lockheed Martin Corp.'),
#  ('Northrop Grumman Corp.', 'Richards, Layton & Finger', 'Outside Counsel', 'Lockheed Martin Corp.'),
#  ('Northrop Grumman Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'Lockheed Martin Corp.'),
#  ('Octel Communications Corporation', 'Morrow & Co., Inc.', 'Proxy Solicitor', 'Lucent Technologies Inc.'),
#  ('Nellcor Puritan Bennett Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Counsel', 'Mallinckrodt Inc.'),
#  ('Nellcor Puritan Bennett Inc.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'Mallinckrodt Inc.'),
#  ('Nellcor Puritan Bennett Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Mallinckrodt Inc.'),
#  ('Nellcor Puritan Bennett Inc.', 'Sullivan & Cromwell', 'Outside Counsel', 'Mallinckrodt Inc.'),
#  ('Nellcor Puritan Bennett Inc.', 'White & Case', 'Outside Counsel', 'Mallinckrodt Inc.'),
#  ('Pennzoil Comp.', 'Dewey Ballantine', 'Counsel', 'Union Pacific Resources Group Inc.'),
#  ('Pennzoil Comp.', 'Morgan, Lewis & Bockius', 'Outside Counsel', 'Union Pacific Resources Group Inc.'),
#  ('Pennzoil Comp.', 'Morrow & Co., Inc.', 'Proxy Solicitor', 'Union Pacific Resources Group Inc.'),
#  ('Pennzoil Comp.', 'Robinson Lerer & Montgomery', 'Public Relations Firm', 'Union Pacific Resources Group Inc.'),
#  ('Pennzoil Comp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'Union Pacific Resources Group Inc.'),
#  ('Pennzoil Comp.', 'Smith Barney Inc.', 'Investment Adviser', 'Union Pacific Resources Group Inc.'),
#  ('Rykoff Sexton Inc.', 'Dewey Ballantine', 'Counsel', 'JP Foodservice Inc.'),
#  ('Rykoff Sexton Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'JP Foodservice Inc.'),
#  ('Rykoff Sexton Inc.', 'Hogan & Hartson', 'Outside Counsel', 'JP Foodservice Inc.'),
#  ('Rykoff Sexton Inc.', 'Kekst and Company', 'Public Relations Firm', 'JP Foodservice Inc.'),
#  ('Rykoff Sexton Inc.', 'PaineWebber Inc.', 'Investment Adviser', 'JP Foodservice Inc.'),
#  ('Rykoff Sexton Inc.', 'Smith Barney Inc.', 'Investment Adviser', 'JP Foodservice Inc.'),
#  ('Rykoff Sexton Inc.', 'Sullivan & Cromwell', 'Counsel', 'JP Foodservice Inc.'),
#  ('Rykoff Sexton Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'JP Foodservice Inc.'),
#  ('Scudder, Stevens & Clark Inc.', 'Lazard Freres & Co. LLC', 'Investment Adviser', 'Zurich Group'),
#  ('Scudder, Stevens & Clark Inc.', 'Willkie Farr & Gallagher', 'Outside Counsel', 'Zurich Group'),
#  ('Signet Banking Corp.', 'Credit Suisse First Boston', 'Investment Adviser', 'First Union Corporation'),
#  ('Signet Banking Corp.', 'Simpson Thacher & Bartlett', 'Counsel', 'First Union Corporation'),
#  ('Signet Banking Corp.', 'Sullivan & Cromwell', 'Outside Counsel', 'First Union Corporation'),
#  ('Tandem Computers Inc.', 'Davis Polk & Wardell', 'Outside Counsel', 'Compaq Computer Corp.'),
#  ('Tandem Computers Inc.', 'Greenhill & Co.', 'Investment Adviser', 'Compaq Computer Corp.'),
#  ('Tandem Computers Inc.', 'Miller Shandwick Technologies', 'Public Relations Firm', 'Compaq Computer Corp.'),
#  ('Tandem Computers Inc.', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'Compaq Computer Corp.'),
#  ('Tandem Computers Inc.', 'Richards, Layton & Finger', 'Outside Counsel', 'Compaq Computer Corp.'),
#  ('Tandem Computers Inc.', 'Wilmer, Cutler & Pickering', 'Antitrust Counsel', 'Compaq Computer Corp.'),
#  ('Barnett Banks, Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Counsel', 'NationsBank Corporation'),
#  ('Barnett Banks, Inc.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'NationsBank Corporation'),
#  ('Barnett Banks, Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'NationsBank Corporation'),
#  ('Barnett Banks, Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'NationsBank Corporation'),
#  ('Barnett Banks, Inc.', 'Montgomery Securities', 'Investment Adviser', 'NationsBank Corporation'),
#  ('Barnett Banks, Inc.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'NationsBank Corporation'),
#  ('Barnett Banks, Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'NationsBank Corporation'),
#  ('Beacon Properties Corp.', 'J.P. Morgan & Co., Inc.', 'Investment Adviser', 'Equity Office Properties Trust'),
#  ('Beacon Properties Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Equity Office Properties Trust'),
#  ('Beacon Properties Corp.', 'Simpson Thacher & Bartlett', 'Counsel', 'Equity Office Properties Trust'),
#  ('Bergen Brunswig Corp.', 'Dewey Ballantine', 'Counsel', 'Cardinal Health, Inc.'),
#  ('Bergen Brunswig Corp.', 'Jones, Day, Reavis & Pogue', 'Antitrust Counsel', 'Cardinal Health, Inc.'),
#  ('Bergen Brunswig Corp.', 'Morrow & Co., Inc.', 'Proxy Solicitor', 'Cardinal Health, Inc.'),
#  ('Bergen Brunswig Corp.', 'Smith Barney Inc.', 'Investment Adviser', 'Cardinal Health, Inc.'),
#  ('Bergen Brunswig Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Cardinal Health, Inc.'),
#  ('Chauvco Resources LTD.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Pioneer Natural Resources Co.'),
#  ('Chauvco Resources LTD.', 'Sullivan & Cromwell', 'Counsel', 'Pioneer Natural Resources Co.'),
#  ('Doubletree Corporation', 'BT Wolfensohn', 'Investment Adviser', 'Promus Hotel Corp.'),
#  ('Doubletree Corporation', 'Debevoise & Plimpton', 'Counsel', 'Promus Hotel Corp.'),
#  ('Doubletree Corporation', 'Latham & Watkins', 'Outside Counsel', 'Promus Hotel Corp.'),
#  ('Evans Withycombe Residential Inc.', 'J.P. Morgan & Co., Inc.', 'Investment Adviser', 'Equity Residential Properties Trust'),
#  ('Evans Withycombe Residential Inc.', 'Rudnick & Wolfe', 'Outside Counsel', 'Equity Residential Properties Trust'),
#  ('Fisher Scientific International Inc.', 'Davis Polk & Wardell', 'Outside Counsel', 'Inv. Group led by Thomas H. Lee Company'),
#  ('Fisher Scientific International Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Inv. Group led by Thomas H. Lee Company'),
#  ('Fisher Scientific International Inc.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'Inv. Group led by Thomas H. Lee Company'),
#  ('W.R. Grace & Comp.', 'Chadbourne & Parke', 'Counsel', 'Sealed Air Corporation'),
#  ('W.R. Grace & Comp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'Sealed Air Corporation'),
#  ('H&R Block Inc.', 'Bryan Cave', 'Outside Counsel', 'WorldCom, Inc.'),
#  ('H&R Block Inc.', 'Heller Ehrman White & McAuliffe', 'Antitrust Counsel', 'WorldCom, Inc.'),
#  ('Lin Television Corp.', 'Davis Polk & Wardell', 'Outside Counsel', 'Hicks, Muse, Tate & Furst Inc. and NBC'),
#  ('Lin Television Corp.', 'Greenhill & Co.', 'Investment Adviser', 'Hicks, Muse, Tate & Furst Inc. and NBC'),
#  ('Lin Television Corp.', 'Kekst and Company', 'Public Relations Firm', 'Hicks, Muse, Tate & Furst Inc. and NBC'),
#  ('Lin Television Corp.', 'Weil, Gotshal & Manges', 'Outside Counsel', 'Hicks, Muse, Tate & Furst Inc. and NBC'),
#  ('Lin Television Corp.', 'Wiley, Rein & Fielding', 'Outside Counsel', 'Hicks, Muse, Tate & Furst Inc. and NBC'),
#  ('Monterey Resources Inc.', 'Credit Suisse First Boston', 'Investment Adviser', 'Texaco Inc.'),
#  ('Monterey Resources Inc.', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'Texaco Inc.'),
#  ('Ralston Purina Co.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'DuPont Co.'),
#  ('SFX Broadcasting Inc.', 'Kekst and Company', 'Public Relations Firm', 'Hicks, Muse, Tate & Furst Inc.'),
#  ('Western National Corp.', 'Debevoise & Plimpton', 'Counsel', 'American General Corp.'),
#  ('Western National Corp.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'American General Corp.'),
#  ('Western National Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'American General Corp.'),
#  ('Westin Hotels & Resorts', 'Fried, Frank, Harris, Shriver & Jacobson', 'Counsel', 'Starwood Lodging Trust'),
#  ('Westin Hotels & Resorts', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Starwood Lodging Trust'),
#  ('Westin Hotels & Resorts', 'Shearman & Sterling', 'Counsel', 'Starwood Lodging Trust'),
#  ('Westinghouse Electric Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Ingersoll-Rand Company'),
#  ('Westinghouse Electric Corp.', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'Ingersoll-Rand Company'),
#  ('American Radio Systems Corp.', 'Chase Securities Inc.', 'Investment Adviser', 'Westinghouse Electric Corp.'),
#  ('American Radio Systems Corp.', 'Cravath, Swaine & Moore', 'Outside Counsel', 'Westinghouse Electric Corp.'),
#  ('American Radio Systems Corp.', 'Jones, Day, Reavis & Pogue', 'Antitrust Counsel', 'Westinghouse Electric Corp.'),
#  ('American Radio Systems Corp.', 'Simpson Thacher & Bartlett', 'Counsel', 'Westinghouse Electric Corp.'),
#  ('American Radio Systems Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'Westinghouse Electric Corp.'),
#  ('Amerisource Health Corp.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'McKesson Corp.'),
#  ('Amerisource Health Corp.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'McKesson Corp.'),
#  ('Amerisource Health Corp.', 'Peter J. Solomon Company', 'Investment Adviser', 'McKesson Corp.'),
#  ('Amerisource Health Corp.', 'Willkie Farr & Gallagher', 'Counsel', 'McKesson Corp.'),
#  ('Apria Healthcare Group Inc.', 'Cravath, Swaine & Moore', 'Counsel', 'Investor Group led by Transworld Healthcare Inc.'),
#  ('Apria Healthcare Group Inc.', 'Credit Suisse First Boston', 'Investment Adviser', 'Investor Group led by Transworld Healthcare Inc.'),
#  ('Apria Healthcare Group Inc.', 'Lehman Brothers', 'Investment Adviser', 'Investor Group led by Transworld Healthcare Inc.'),
#  ('Apria Healthcare Group Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Investor Group led by Transworld Healthcare Inc.'),
#  ('Brooks Fiber Properties, Inc.', 'Peper, Martin, Jensen, Maichel and Hetlage', 'Outside Counsel', 'WorldCom, Inc.'),
#  ('Calilber Systems Inc.', 'Davis Polk & Wardell', 'Outside Counsel', 'Federal Express Corporation'),
#  ('Calilber Systems Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Federal Express Corporation'),
#  ('Calilber Systems Inc.', 'Morrow & Co., Inc.', 'Proxy Solicitor', 'Federal Express Corporation'),
#  ('Greenfield Industries, Inc.', 'Buchanan Ingersol', 'Outside Counsel', 'Kennametal Inc.'),
#  ('Greenfield Industries, Inc.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'Kennametal Inc.'),
#  ('Greenfield Industries, Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Kennametal Inc.'),
#  ('Greenfield Industries, Inc.', 'Simpson Thacher & Bartlett', 'Counsel', 'Kennametal Inc.'),
#  ('Network General Corp.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'McAfee Associates Inc.'),
#  ('Powernet Victoria', 'J.P. Morgan & Co., Inc.', 'Investment Adviser', 'GPU, Inc.'),
#  ('The Quick & Reilly Group, Inc.', 'Cleary, Gottlieb, Steen & Hamilton', 'Outside Counsel', 'Fleet Financial Group, Inc.'),
#  ('The Quick & Reilly Group, Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'Fleet Financial Group, Inc.'),
#  ('The Quick & Reilly Group, Inc.', 'UBS Securities', 'Investment Adviser', 'Fleet Financial Group, Inc.'),
#  ('Salomon Inc.', 'Kekst and Company', 'Public Relations Firm', 'Travelers Group'),
#  ('Salomon Inc.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'Travelers Group'),
#  ('Rohr Inc.', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'B.F. Goodrich Co.'),
#  ('Rohr Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'B.F. Goodrich Co.'),
#  ('Rohr Inc.', 'Jones, Day, Reavis & Pogue', 'Counsel', 'B.F. Goodrich Co.'),
#  ('Rohr Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'B.F. Goodrich Co.'),
#  ('Tejas Gas Corp.', 'Cravath, Swaine & Moore', 'Outside Counsel', 'Shell Oil Company'),
#  ('Tejas Gas Corp.', 'Davis Polk & Wardell', 'Outside Counsel', 'Shell Oil Company'),
#  ('Tejas Gas Corp.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Shell Oil Company'),
#  ('Tejas Gas Corp.', 'Richards, Layton & Finger', 'Outside Counsel', 'Shell Oil Company'),
#  ('Tejas Gas Corp.', 'Sullivan & Cromwell', 'Counsel', 'Shell Oil Company'),
#  ('T&N PLC', 'Cazenove', 'Investment Adviser', 'Federal-Mogul Corp.'),
#  ('T&N PLC', 'Cleary, Gottlieb, Steen & Hamilton', 'Outside Counsel', 'Federal-Mogul Corp.'),
#  ('T&N PLC', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'Federal-Mogul Corp.'),
#  ('T&N PLC', 'Davis Polk & Wardell', 'Counsel', 'Federal-Mogul Corp.'),
#  ('T&N PLC', 'Freshfields', 'Counsel', 'Federal-Mogul Corp.'),
#  ('T&N PLC', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Federal-Mogul Corp.'),
#  ('Viacom Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Counsel', 'Evergreen Media Corporation'),
#  ('Advanta Corp.', 'Kekst and Company', 'Public Relations Firm', 'Fleet Financial Group, Inc.'),
#  ('Advanta Corp.', 'Lehman Brothers', 'Investment Adviser', 'Fleet Financial Group, Inc.'),
#  ('Advanta Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Fleet Financial Group, Inc.'),
#  ('Advanta Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Fleet Financial Group, Inc.'),
#  ('Browning-Ferris Industries Inc.', 'Gavin Anderson & Company', 'Public Relations Firm', 'SITA SA'),
#  ('Browning-Ferris Industries Inc.', 'Sullivan & Cromwell', 'Outside Counsel', 'SITA SA'),
#  ('Corestates Financial Corp.', 'Alston & Bird', 'Outside Counsel', 'First Union Corporation'),
#  ('Corestates Financial Corp.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'First Union Corporation'),
#  ('Corestates Financial Corp.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'First Union Corporation'),
#  ('Cowles Media Company', 'Cleary, Gottlieb, Steen & Hamilton', 'Counsel', 'McClatchy Newspapers, Inc.'),
#  ('Cowles Media Company', 'Morris, Nichols, Arsht & Tunnell', 'Outside Counsel', 'McClatchy Newspapers, Inc.'),
#  ('Cowles Media Company', 'Pillsbury Madison & Sutro', 'Outside Counsel', 'McClatchy Newspapers, Inc.'),
#  ('Cowles Media Company', 'Salomon Brothers Inc.', 'Investment Adviser', 'McClatchy Newspapers, Inc.'),
#  ('The Dow Chemical Company', 'Chadbourne & Parke', 'Outside Counsel', 'NGC Corp.'),
#  ('The Dow Chemical Company', 'Chase Securities Inc.', 'Investment Adviser', 'NGC Corp.'),
#  ('The Dow Chemical Company', 'Vinson & Elkins', 'Outside Counsel', 'NGC Corp.'),
#  ('First Commerce Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Banc One Corporation'),
#  ('Healthsouth Corp.', 'Blass & Driggs', 'Outside Counsel', 'Integrated Health Services Inc.'),
#  ('Healthsouth Corp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'Integrated Health Services Inc.'),
#  ('Healthsouth Corp.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Integrated Health Services Inc.'),
#  ('Homeside, Inc.', 'Cohane Rafferty Securities Inc.', 'Investment Adviser', 'National Bank Australia Limited'),
#  ('Homeside, Inc.', 'Hanover Capital Partners Ltd.', 'Investment Adviser', 'National Bank Australia Limited'),
#  ('Homeside, Inc.', 'Keefe, Bruyette & Woods, Inc.', 'Investment Adviser', 'National Bank Australia Limited'),
#  ('Homeside, Inc.', 'Sullivan & Cromwell', 'Outside Counsel', 'National Bank Australia Limited'),
#  ('Homeside, Inc.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'National Bank Australia Limited'),
#  ('Powernet Victoria', 'Berlach, Israel & Liberman', 'Outside Counsel', 'GPU, Inc.'),
#  ('Ralphs Grocery Company', 'Morgan, Lewis & Bockius', 'Outside Counsel', 'Apollo Advisors'),
#  ('Ralston Purina Co.', 'BT Wolfensohn', 'Investment Adviser', 'DuPont Co.'),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 'Georgeson & Company Inc.', 'Proxy Solicitor', 'Consolidated Stores Corp.'),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 'Merrill Lynch & Co.', 'Investment Adviser', 'Consolidated Stores Corp.'),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'Consolidated Stores Corp.'),
#  ('Medpartners, Inc.', 'Alston & Bird', 'Antitrust Counsel', 'PhyCor Inc.'),
#  ('Medpartners, Inc.', 'BT Alex. Brown', 'Investment Adviser', 'PhyCor Inc.'),
#  ('Medpartners, Inc.', 'Shearman & Sterling', 'Counsel', 'PhyCor Inc.'),
#  ('Medpartners, Inc.', 'Waller Lansden Dortch & Davis', 'Outside Counsel', 'PhyCor Inc.'),
#  ('Quality Food Centers Inc.', 'Cleary, Gottlieb, Steen & Hamilton', 'Counsel', 'Fred Meyer Inc.'),
#  ('Quality Food Centers Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Fred Meyer Inc.'),
#  ('Quality Food Centers Inc.', 'Salomon Brothers Inc.', 'Investment Adviser', 'Fred Meyer Inc.'),
#  ('Quality Food Centers Inc.', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'Fred Meyer Inc.'),
#  ('Quality Food Centers Inc.', 'Stoel Rives', 'Outside Counsel', 'Fred Meyer Inc.'),
#  ('Quality Food Centers Inc.', 'Sullivan & Cromwell', 'Counsel', 'Fred Meyer Inc.'),
#  ('Ralphs Grocery Company', 'Cleary, Gottlieb, Steen & Hamilton', 'Counsel', 'Fred Meyer Inc.'),
#  ('Ralphs Grocery Company', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Fred Meyer Inc.'),
#  ('Ralphs Grocery Company', 'Salomon Brothers Inc.', 'Investment Adviser', 'Fred Meyer Inc.'),
#  ('Ralphs Grocery Company', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'Fred Meyer Inc.'),
#  ('Ralphs Grocery Company', 'Stoel Rives', 'Outside Counsel', 'Fred Meyer Inc.'),
#  ('Ralphs Grocery Company', 'Sullivan & Cromwell', 'Counsel', 'Fred Meyer Inc.'),
#  ('Safety-Kleen Corp.', 'Bear, Stearns & Co., Inc.', 'Investment Adviser', 'Laidlaw Environmental Services, Inc.'),
#  ('Safety-Kleen Corp.', 'Debevoise & Plimpton', 'Counsel', 'Laidlaw Environmental Services, Inc.'),
#  ('Safety-Kleen Corp.', 'Katten Muchin & Zavis', 'Outside Counsel', 'Laidlaw Environmental Services, Inc.'),
#  ('Safety-Kleen Corp.', 'Morrow & Co., Inc.', 'Proxy Solicitor', 'Laidlaw Environmental Services, Inc.'),
#  ('Safety-Kleen Corp.', 'Quarles & Brady', 'Outside Counsel', 'Laidlaw Environmental Services, Inc.'),
#  ('Safety-Kleen Corp.', 'Raymond James & Associates Inc.', 'Investment Adviser', 'Laidlaw Environmental Services, Inc.'),
#  ('Santa Fe Pacific Pipeline Partners', 'Akin, Gump, Strauss, Hauer & Feld', 'Regulatory Counsel', 'Kinder Morgan Energy Partners'),
#  ('Santa Fe Pacific Pipeline Partners', 'Andrews & Kurth', 'Counsel', 'Kinder Morgan Energy Partners'),
#  ('Santa Fe Pacific Pipeline Partners', 'Bracewell & Paterson', 'Outside Counsel', 'Kinder Morgan Energy Partners'),
#  ('Santa Fe Pacific Pipeline Partners', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Kinder Morgan Energy Partners'),
#  ('Santa Fe Pacific Pipeline Partners', 'Morris, Nichols, Arsht & Tunnell', 'Outside Counsel', 'Kinder Morgan Energy Partners'),
#  ('Santa Fe Pacific Pipeline Partners', 'Morrison & Hecker', 'SEC Counsel', 'Kinder Morgan Energy Partners'),
#  ('Santa Fe Pacific Pipeline Partners', 'Smith Barney Inc.', 'Investment Adviser', 'Kinder Morgan Energy Partners'),
#  ('Santa Fe Pacific Pipeline Partners', 'Sullivan & Cromwell', 'Counsel', 'Kinder Morgan Energy Partners'),
#  ('Seagram Company', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'HSN Inc.'),
#  ('Universal Outdoor Holdings Inc.', 'Akin, Gump, Strauss, Hauer & Feld', 'Outside Counsel', 'Clear Channel Communications, Inc.'),
#  ('Westinghouse Electric Corp.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Siemens A.G.'),
#  ('Westinghouse Electric Corp.', 'Latham & Watkins', 'Outside Counsel', 'Siemens A.G.'),
#  ('Westinghouse Electric Corp.', 'Rogers & Wells', 'Outside Counsel', 'Siemens A.G.'),
#  ('Westinghouse Electric Corp.', 'Sullivan & Cromwell', 'Counsel', 'Siemens A.G.'),
#  ('Viacom Inc.', 'Cravath, Swaine & Moore', 'Counsel', 'Vencor, Inc.'),
#  ('Viacom Inc.', 'Credit Suisse First Boston', 'Investment Adviser', 'Vencor, Inc.'),
#  ('Viacom Inc.', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'Vencor, Inc.'),
#  ('Viacom Inc.', 'Sullivan & Cromwell', 'Outside Counsel', 'Vencor, Inc.'),
#  ('ADT Limited', 'Bear, Stearns & Co., Inc.', 'Investment Adviser', 'Western Resources, Inc.'),
#  ('ADT Limited', 'Chase Securities Inc.', 'Investment Adviser', 'Western Resources, Inc.'),
#  ('ADT Limited', 'Cravath, Swaine & Moore', 'Counsel', 'Western Resources, Inc.'),
#  ('ADT Limited', 'Fleishman-Hillard, Inc.', 'Public Relations Firm', 'Western Resources, Inc.'),
#  ('ADT Limited', 'MacKenzie Partners, Inc.', 'Proxy Solicitor', 'Western Resources, Inc.'),
#  ('ADT Limited', 'Salomon Brothers Inc.', 'Investment Adviser', 'Western Resources, Inc.'),
#  ('ADT Limited', 'Sullivan & Cromwell', 'Outside Counsel', 'Western Resources, Inc.'),
#  ('ITT Corp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'Hilton Hotels Corp.'),
#  ('ITT Corp.', 'Latham & Watkins', 'Outside Counsel', 'Hilton Hotels Corp.'),
#  ('ITT Corp.', 'MacKenzie Partners, Inc.', 'Proxy Solicitor', 'Hilton Hotels Corp.'),
#  ('ITT Corp.', 'Schreck Morris', 'Litigation Counsel', 'Hilton Hotels Corp.'),
#  ('ITT Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'Counsel', 'Hilton Hotels Corp.'),
#  ('ITT Corp.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'Hilton Hotels Corp.'),
#  ('ITT Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Hilton Hotels Corp.'),
#  ('MCI Communications Corporation', 'Burson-Marsteller', 'Public Relations Firm', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Jones, Day, Reavis & Pogue', 'Regulatory Counsel', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Linklaters & Paines', 'Outside Counsel', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Milbank, Tweed, Hadley & McCloy', 'Outside Counsel', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Morris, Nichols, Arsht & Tunnell', 'Outside Counsel', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Paul, Weiss, Rifkind, Wharton & Garrison', 'Outside Counsel', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Paul, Weiss, Rifkind, Wharton & Garrison', 'Counsel', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Rothschild Inc./NM Rothschild & Sons Ltd.', 'Investment Adviser', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'Shearman & Sterling', 'Outside Counsel', 'British Telecommunications PLC'),
#  ('Great Western Financial Corp.', 'Credit Suisse First Boston', 'Investment Adviser', 'H.F. Ahmanson & Co.'),
#  ('Great Western Financial Corp.', 'Dewey Ballantine', 'Counsel', 'H.F. Ahmanson & Co.'),
#  ('Great Western Financial Corp.', 'Kekst and Company', 'Public Relations Firm', 'H.F. Ahmanson & Co.'),
# ...
#  ('Rykoff Sexton Inc.', 'Simpson Thacher & Bartlett', 'Counsel', 'Rykoff Sexton Inc.'),
#  ('Rykoff Sexton Inc.', 'Wasserstein Perella & Co. Inc.', 'Investment Adviser', 'Rykoff Sexton Inc.'),
#  ('Scudder, Stevens & Clark Inc.', 'Debevoise & Plimpton', 'Outside Counsel', 'Scudder, Stevens & Clark Inc.'),
#  ('Scudder, Stevens & Clark Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Scudder, Stevens & Clark Inc.'),
#  ('Scudder, Stevens & Clark Inc.', 'Sullivan & Cromwell', 'Counsel', 'Scudder, Stevens & Clark Inc.'),
#  ('Scudder, Stevens & Clark Inc.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'Scudder, Stevens & Clark Inc.'),
#  ('Signet Banking Corp.', 'J.P. Morgan & Co., Inc.', 'Investment Adviser', 'Signet Banking Corp.'),
#  ('Signet Banking Corp.', 'McGuire, Woods, Battle & Boothe', 'Outside Counsel', 'Signet Banking Corp.'),
#  ('Signet Banking Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Signet Banking Corp.'),
#  ('Tandem Computers Inc.', 'Corporate Investor Communications Inc.', 'Proxy Solicitor', 'Tandem Computers Inc.'),
#  ('Tandem Computers Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'Tandem Computers Inc.'),
#  ('Tandem Computers Inc.', 'Lehman Brothers', 'Investment Adviser', 'Tandem Computers Inc.'),
#  ('Tandem Computers Inc.', 'Morrison & Foerster', 'Outside Counsel', 'Tandem Computers Inc.'),
#  ('Barnett Banks, Inc.', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'Barnett Banks, Inc.'),
#  ('Barnett Banks, Inc.', 'J.P. Morgan & Co., Inc.', 'Investment Adviser', 'Barnett Banks, Inc.'),
#  ('Barnett Banks, Inc.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Barnett Banks, Inc.'),
#  ('Barnett Banks, Inc.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'Barnett Banks, Inc.'),
#  ('Beacon Properties Corp.', 'Goodwin, Procter & Hoar', 'Outside Counsel', 'Beacon Properties Corp.'),
#  ('Beacon Properties Corp.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Beacon Properties Corp.'),
#  ('Bergen Brunswig Corp.', 'Lowenstein, Sandler, Kohl, Fisher & Boy-Ian', 'Outside Counsel', 'Bergen Brunswig Corp.'),
#  ('Bergen Brunswig Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Bergen Brunswig Corp.'),
#  ('Bergen Brunswig Corp.', 'Rogers & Wells', 'Outside Counsel', 'Bergen Brunswig Corp.'),
#  ('Bergen Brunswig Corp.', 'Shearman & Sterling', 'Outside Counsel', 'Bergen Brunswig Corp.'),
#  ('Bergen Brunswig Corp.', 'Simpson Thacher & Bartlett', 'Counsel', 'Bergen Brunswig Corp.'),
#  ('Chauvco Resources LTD.', 'Baker & Botts', 'Outside Counsel', 'Chauvco Resources Ltd.'),
#  ('Chauvco Resources LTD.', 'Bennet Jones Verchere', 'Outside Counsel', 'Chauvco Resources Ltd.'),
#  ('Chauvco Resources LTD.', 'Cleary, Gottlieb, Steen & Hamilton', 'Counsel', 'Chauvco Resources Ltd.'),
#  ('Chauvco Resources LTD.', 'RBC Dominion Securities Inc.', 'Investment Adviser', 'Chauvco Resources Ltd.'),
#  ('Chauvco Resources LTD.', 'Salomon Brothers Inc.', 'Investment Adviser', 'Chauvco Resources Ltd.'),
#  ('Doubletree Corporation', 'Dewey Ballantine', 'Outside Counsel', 'Doubletree Corporation'),
#  ('Doubletree Corporation', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Doubletree Corporation'),
#  ('Evans Withycombe Residential Inc.', 'Gibson, Dunn & Crutcher', 'Outside Counsel', 'Evans Withycombe Residential Inc.'),
#  ('Evans Withycombe Residential Inc.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Evans Withycombe Residential Inc.'),
#  ('Fisher Scientific International Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Counsel', 'Fisher Scientific International Inc.'),
#  ('Fisher Scientific International Inc.', 'Kekst and Company', 'Public Relations Firm', 'Fisher Scientific International Inc.'),
#  ('Fisher Scientific International Inc.', 'Lazard Freres & Co. LLC', 'Investment Adviser', 'Fisher Scientific International Inc.'),
#  ('Fisher Scientific International Inc.', 'Salomon Brothers Inc.', 'Investment Adviser', 'Fisher Scientific International Inc.'),
#  ('Fisher Scientific International Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Fisher Scientific International Inc.'),
#  ('W.R. Grace & Comp.', 'Cravath, Swaine & Moore', 'Counsel', 'Cryovac'),
#  ('W.R. Grace & Comp.', 'Credit Suisse First Boston', 'Investment Adviser', 'Cryovac'),
#  ('W.R. Grace & Comp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Cryovac'),
#  ('W.R. Grace & Comp.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Cryovac'),
#  ('H&R Block Inc.', 'Cravath, Swaine & Moore', 'Counsel', 'CompuServe Corp.'),
#  ('H&R Block Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Counsel', 'CompuServe Corp.'),
#  ('H&R Block Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'CompuServe Corp.'),
#  ('H&R Block Inc.', 'Kekst and Company', 'Public Relations Firm', 'CompuServe Corp.'),
#  ('H&R Block Inc.', 'Salomon Brothers Inc.', 'Investment Adviser', 'CompuServe Corp.'),
#  ('H&R Block Inc.', 'Sullivan & Cromwell', 'Outside Counsel', 'CompuServe Corp.'),
#  ('Lin Television Corp.', 'Morgan Stanley & Co. Inc.', 'Investment Adviser', 'Lin Television Corp.'),
#  ('Lin Television Corp.', 'Richards, Layton & Finger', 'Outside Counsel', 'Lin Television Corp.'),
#  ('Lin Television Corp.', 'Shearman & Sterling', 'Counsel', 'Lin Television Corp.'),
#  ('Lin Television Corp.', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'Lin Television Corp.'),
#  ('Lin Television Corp.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'Lin Television Corp.'),
#  ('Lin Television Corp.', 'Wasserstein Perella & Co. Inc.', 'Investment Adviser', 'Lin Television Corp.'),
#  ('Lin Television Corp.', 'Willkie Farr & Gallagher', 'Counsel', 'Lin Television Corp.'),
#  ('Monterey Resources Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Monterey Resources Inc.'),
#  ('Monterey Resources Inc.', 'Morrow & Co., Inc.', 'Proxy Solicitor', 'Monterey Resources Inc.'),
#  ('Monterey Resources Inc.', 'Sullivan & Cromwell', 'Counsel', 'Monterey Resources Inc.'),
#  ('SFX Broadcasting Inc.', 'Richards, Layton & Finger', 'Delaware Counsel', 'SFX Broadcasting Inc.'),
#  ('Western National Corp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'Western National Corp.'),
#  ('Western National Corp.', 'Morris, Nichols, Arsht & Tunnell', 'Outside Counsel', 'Western National Corp.'),
#  ('Western National Corp.', 'Sullivan & Cromwell', 'Outside Counsel', 'Western National Corp.'),
#  ('Westin Hotels & Resorts', 'Sullivan & Cromwell', 'Outside Counsel', 'Westin Hotels & Resorts'),
#  ('Westinghouse Electric Corp.', 'Cravath, Swaine & Moore', 'Outside Counsel', 'Thermo King'),
#  ('Westinghouse Electric Corp.', 'Evercore Partners', 'Investment Adviser', 'Thermo King'),
#  ('American Radio Systems Corp.', 'Credit Suisse First Boston', 'Investment Adviser', 'American Radio Systems Corp.'),
#  ('American Radio Systems Corp.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'American Radio Systems Corp.'),
#  ('American Radio Systems Corp.', 'Paul, Weiss, Rifkind, Wharton & Garrison', 'Counsel', 'American Radio Systems Corp.'),
#  ('American Radio Systems Corp.', 'Richards, Layton & Finger', 'Outside Counsel', 'American Radio Systems Corp.'),
#  ('American Radio Systems Corp.', 'Sullivan & Cromwell', 'Counsel', 'American Radio Systems Corp.'),
#  ('American Radio Systems Corp.', 'Sullivan & Worcester', 'Outside Counsel', 'American Radio Systems Corp.'),
#  ('Amerisource Health Corp.', 'Cravath, Swaine & Moore', 'Counsel', 'Amerisource Health Corp.'),
#  ('Amerisource Health Corp.', 'Dechert Price & Rhoads', 'Outside Counsel', 'Amerisource Health Corp.'),
#  ('Amerisource Health Corp.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Amerisource Health Corp.'),
#  ('Apria Healthcare Group Inc.', 'Gibson, Dunn & Crutcher', 'Outside Counsel', 'Apria Healthcare Group Inc.'),
#  ('Apria Healthcare Group Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Apria Healthcare Group Inc.'),
#  ('Apria Healthcare Group Inc.', 'Sullivan & Cromwell', 'Counsel', 'Apria Healthcare Group Inc.'),
#  ('Brooks Fiber Properties, Inc.', 'Bryan Cave', 'Outside Counsel', 'Brooks Fiber Properties, Inc.'),
#  ('Brooks Fiber Properties, Inc.', 'Corporate Communications', 'Public Relations Firm', 'Brooks Fiber Properties, Inc.'),
#  ('Brooks Fiber Properties, Inc.', 'Cravath, Swaine & Moore', 'Counsel', 'Brooks Fiber Properties, Inc.'),
#  ('Brooks Fiber Properties, Inc.', 'Salomon Brothers Inc.', 'Investment Adviser', 'Brooks Fiber Properties, Inc.'),
#  ('Calilber Systems Inc.', 'Cravath, Swaine & Moore', 'Outside Counsel', 'Calilber Systems Inc.'),
#  ('Calilber Systems Inc.', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'Calilber Systems Inc.'),
#  ('Calilber Systems Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Calilber Systems Inc.'),
#  ('Calilber Systems Inc.', 'Jones, Day, Reavis & Pogue', 'Outside Counsel', 'Calilber Systems Inc.'),
#  ('Calilber Systems Inc.', 'Sullivan & Cromwell', 'Counsel', 'Calilber Systems Inc.'),
#  ('Calilber Systems Inc.', 'The Abernathy / MacGregor Group, Inc.', 'Public Relations Firm', 'Calilber Systems Inc.'),
#  ('Coopers & Lybrand L.L.P.', 'Hughes Hubbard & Reed', 'Outside Counsel', 'Coopers & Lybrand L.L.P.'),
#  ('Greenfield Industries, Inc.', 'Credit Suisse First Boston', 'Investment Adviser', 'Greenfield Industries, Inc.'),
#  ('Greenfield Industries, Inc.', 'Dickstein Shapiro Morin & Oshinsky', 'Outside Counsel', 'Greenfield Industries, Inc.'),
#  ('Greenfield Industries, Inc.', 'NationsBanc Capital Markets', 'Investment Adviser', 'Greenfield Industries, Inc.'),
#  ('MCI Communications Corporation', 'Georgeson & Company Inc.', 'Proxy Solicitor', 'MCI Communications Corporation'),
#  ('MCI Communications Corporation', 'Lazard Freres & Co. LLC', 'Investment Adviser', 'MCI Communications Corporation'),
#  ('MCI Communications Corporation', 'Lehman Brothers', 'Investment Adviser', 'MCI Communications Corporation'),
#  ('MCI Communications Corporation', 'Richards, Layton & Finger', 'Outside Counsel', 'MCI Communications Corporation'),
#  ('MCI Communications Corporation', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'MCI Communications Corporation'),
#  ('MCI Communications Corporation', 'Sullivan & Cromwell', 'Counsel', 'MCI Communications Corporation'),
#  ('Network General Corp.', 'Hambrecht & Quist', 'Investment Adviser', 'Network General Corp.'),
#  ('Network General Corp.', 'Richards, Layton & Finger', 'Outside Counsel', 'Network General Corp.'),
#  ('Powernet Victoria', 'Credit Suisse First Boston', 'Investment Adviser', 'PowerNet Victoria'),
#  ('The Quick & Reilly Group, Inc.', 'Gleacher Natwest Inc.', 'Investment Adviser', 'Quick & Reilly Group, Inc., The'),
#  ('The Quick & Reilly Group, Inc.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Quick & Reilly Group, Inc., The'),
#  ('The Quick & Reilly Group, Inc.', 'Kekst and Company', 'Public Relations Firm', 'Quick & Reilly Group, Inc., The'),
#  ('The Quick & Reilly Group, Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Quick & Reilly Group, Inc., The'),
#  ('Salomon Inc.', 'Cravath, Swaine & Moore', 'Outside Counsel', 'Salomon Inc.'),
#  ('Salomon Inc.', 'Richards, Layton & Finger', 'Outside Counsel', 'Salomon Inc.'),
#  ('Sony Corporation of America', 'Credit Suisse First Boston', 'Investment Adviser', 'Loews Theatre Exhibition Group'),
#  ('Sony Corporation of America', 'Davies, Ward & Beck', 'Outside Counsel', 'Loews Theatre Exhibition Group'),
#  ('Sony Corporation of America', 'Dewey Ballantine', 'Outside Counsel', 'Loews Theatre Exhibition Group'),
#  ('Sony Corporation of America', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'Loews Theatre Exhibition Group'),
#  ('Sony Corporation of America', 'Fulbright & Jaworski', 'Counsel', 'Loews Theatre Exhibition Group'),
#  ('Rohr Inc.', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'Rohr Inc.'),
#  ('Rohr Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'Rohr Inc.'),
#  ('Rohr Inc.', 'Gibson, Dunn & Crutcher', 'Outside Counsel', 'Rohr Inc.'),
#  ('Rohr Inc.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Rohr Inc.'),
#  ('Tejas Gas Corp.', 'Baker & Botts', 'Outside Counsel', 'Tejas Gas Corp.'),
#  ('Tejas Gas Corp.', 'Bartlit Beck Herman Palenchar & Scott', 'Outside Counsel', 'Tejas Gas Corp.'),
#  ('Tejas Gas Corp.', 'Kirkland & Ellis', 'Outside Counsel', 'Tejas Gas Corp.'),
#  ('Tejas Gas Corp.', 'MacKenzie Partners, Inc.', 'Proxy Solicitor', 'Tejas Gas Corp.'),
#  ('Tejas Gas Corp.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Tejas Gas Corp.'),
#  ('Viacom Inc.', 'Morris, Nichols, Arsht & Tunnell', 'Outside Counsel', 'USA Networks'),
#  ('Viacom Inc.', 'Skadden, Arps, Slate, Meagher & Flom', 'Outside Counsel', 'USA Networks'),
#  ('Advanta Corp.', 'BT Wolfensohn', 'Investment Adviser', 'Advanta Corp. Credit card unit'),
#  ('Advanta Corp.', 'D.F. King & Co., Inc.', 'Proxy Solicitor', 'Advanta Corp. Credit card unit'),
#  ('Advanta Corp.', 'Kekst and Company', 'Public Relations Firm', 'Advanta Corp. Credit card unit'),
#  ('Browning-Ferris Industries Inc.', 'Morgan Stanley Dean Witter', 'Investment Adviser', 'Browning-Ferris Ind. Foreign Waste Management unit'),
#  ('Browning-Ferris Industries Inc.', 'Shearman & Sterling', 'Counsel', 'Browning-Ferris Ind. Foreign Waste Management unit'),
#  ('Corestates Financial Corp.', 'Credit Suisse First Boston', 'Investment Adviser', 'Corestates Financial Corp.'),
#  ('Corestates Financial Corp.', 'Dewey Ballantine', 'Counsel', 'Corestates Financial Corp.'),
#  ('Corestates Financial Corp.', 'J.P. Morgan & Co., Inc.', 'Investment Adviser', 'Corestates Financial Corp.'),
#  ('Corestates Financial Corp.', 'Kekst and Company', 'Public Relations Firm', 'Corestates Financial Corp.'),
#  ('Corestates Financial Corp.', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'Corestates Financial Corp.'),
#  ('Cowles Media Company', 'Faegre & Benson', 'Outside Counsel', 'Cowles Media Company'),
#  ('Cowles Media Company', 'Fried, Frank, Harris, Shriver & Jacobson', 'Outside Counsel', 'Cowles Media Company'),
#  ('Cowles Media Company', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Cowles Media Company'),
#  ('Cowles Media Company', 'Sullivan & Cromwell', 'Counsel', 'Cowles Media Company'),
#  ('The Dow Chemical Company', 'Goldman, Sachs & Co.', 'Investment Adviser', 'DowBrands Inc.'),
#  ('First Commerce Corp.', 'Correro Fishman Haygood Phelps Weiss Walmsey & Cas', 'Outside Counsel', 'First Commerce Corp.'),
#  ('First Commerce Corp.', 'Keefe, Bruyette & Woods, Inc.', 'Investment Adviser', 'First Commerce Corp.'),
#  ('Healthsouth Corp.', 'Dewey Ballantine', 'Counsel', 'Healthsouth Corp. Long term facilities'),
#  ('Healthsouth Corp.', 'Haskell Slaughter & Young', 'Outside Counsel', 'Healthsouth Corp. Long term facilities'),
#  ('Healthsouth Corp.', 'Smith Barney Inc.', 'Investment Adviser', 'Healthsouth Corp. Long term facilities'),
#  ('Homeside, Inc.', 'Dewey Ballantine', 'Counsel', 'Homeside, Inc.'),
#  ('Homeside, Inc.', 'Hutchins, Wheeler & Ditmar', 'Outside Counsel', 'Homeside, Inc.'),
#  ('Homeside, Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Homeside, Inc.'),
#  ('Homeside, Inc.', 'Smith Barney Inc.', 'Investment Adviser', 'Homeside, Inc.'),
#  ('Ralston Purina Co.', 'Bryan Cave', 'Outside Counsel', 'Protein Technologies International'),
#  ('Ralston Purina Co.', 'J.P. Morgan & Co., Inc.', 'Investment Adviser', 'Protein Technologies International'),
#  ('Read-Rite Corp.', 'Wilson, Sonsini, Goodrich & Rosati', 'Outside Counsel', 'Read-Rite Corp.'),
#  ('Read-Rite Corp.', 'Goldman, Sachs & Co.', 'Investment Adviser', 'Read-Rite Corp.'),
#  ('Read-Rite Corp.', 'Shearman & Sterling', 'Counsel', 'Read-Rite Corp.'),
#  ('Read-Rite Corp.', 'Montgomery Securities', 'Investment Adviser', 'Applied Magnetics Corp.'),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 'Georgeson & Company Inc.', 'Proxy Solicitor', "Mac Frugal's Bargains & Close-Outs Inc."),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 'Gibson, Dunn & Crutcher', 'Outside Counsel', "Mac Frugal's Bargains & Close-Outs Inc."),
#  ...]

# %% [markdown]
# ### Query 2: Aggregation
# **List the DealID, total dollar value and number of parts for each deal.**
# Don't forget to use your database schema map when planning out your joins. Also, be sure to include a comment (above the code) indicating what the view is intended to do.

# %%
# %%sql
# -- Listing Deal ID, Total Dollar Value and Number of Parts from Deals and DealParts tables.
# SELECT DISTINCT DealID, COUNT(PartNumber) as NumParts, SUM(DollarValue) AS TotalDollarValue
# FROM Deals
#     JOIN DealParts USING (DealID)
# GROUP BY DealID;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 151 rows affected.
# [(1, 1, Decimal('5600.0000')),
#  (2, 1, Decimal('1700.0000')),
#  (3, 1, Decimal('1120.0000')),
#  (4, 1, Decimal('4000.0000')),
#  (5, 1, Decimal('1500.0000')),
#  (6, 1, Decimal('1600.0000')),
#  (7, 1, Decimal('1870.0000')),
#  (8, 1, Decimal('3700.0000')),
#  (9, 1, Decimal('1600.0000')),
#  (10, 1, Decimal('1200.0000')),
#  (11, 1, Decimal('1617.0000')),
#  (12, 1, Decimal('1360.0000')),
#  (13, 1, Decimal('1270.0000')),
#  (14, 1, Decimal('4210.0000')),
#  (15, 1, Decimal('1150.0000')),
#  (16, 1, Decimal('9700.0000')),
#  (17, 1, Decimal('1050.0000')),
#  (18, 1, Decimal('7000.0000')),
#  (19, 1, Decimal('3400.0000')),
#  (20, 1, Decimal('9500.0000')),
#  (21, 1, Decimal('6590.0000')),
#  (22, 1, Decimal('1700.0000')),
#  (23, 1, Decimal('1100.0000')),
#  (24, 1, Decimal('1355.0000')),
#  (25, 1, Decimal('10900.0000')),
#  (26, 1, Decimal('1650.0000')),
#  (27, 1, Decimal('1900.0000')),
#  (28, 1, Decimal('6500.0000')),
#  (29, 1, Decimal('1800.0000')),
#  (30, 1, Decimal('1200.0000')),
#  (31, 1, Decimal('1500.0000')),
#  (32, 1, Decimal('1230.0000')),
#  (33, 1, Decimal('2820.0000')),
#  (34, 1, Decimal('1000.0000')),
#  (35, 1, Decimal('1000.0000')),
#  (36, 1, Decimal('10500.0000')),
#  (37, 1, Decimal('2223.0000')),
#  (38, 1, Decimal('1800.0000')),
#  (39, 1, Decimal('1700.0000')),
#  (40, 1, Decimal('1000.0000')),
#  (41, 1, Decimal('3700.0000')),
#  (42, 1, Decimal('1500.0000')),
#  (43, 1, Decimal('2000.0000')),
#  (44, 1, Decimal('1100.0000')),
#  (45, 1, Decimal('1080.0000')),
#  (46, 1, Decimal('1300.0000')),
#  (47, 1, Decimal('2950.0000')),
#  (48, 1, Decimal('1100.0000')),
#  (49, 1, Decimal('8000.0000')),
#  (50, 1, Decimal('1500.0000')),
#  (51, 1, Decimal('9000.0000')),
#  (52, 1, Decimal('1770.0000')),
#  (53, 1, Decimal('7300.0000')),
#  (54, 1, Decimal('5000.0000')),
#  (55, 1, Decimal('1500.0000')),
#  (56, 1, Decimal('1300.0000')),
#  (57, 1, Decimal('1180.0000')),
#  (58, 1, Decimal('1075.0000')),
#  (59, 1, Decimal('1590.0000')),
#  (60, 1, Decimal('1100.0000')),
#  (61, 1, Decimal('2800.0000')),
#  (62, 2, Decimal('2625.0000')),
#  (63, 1, Decimal('2300.0000')),
#  (64, 1, Decimal('1400.0000')),
#  (65, 1, Decimal('2600.0000')),
#  (66, 1, Decimal('2500.0000')),
#  (67, 1, Decimal('3000.0000')),
#  (68, 1, Decimal('3000.0000')),
#  (69, 1, Decimal('1200.0000')),
#  (70, 1, Decimal('1392.0000')),
#  (71, 1, Decimal('1920.0000')),
#  (72, 1, Decimal('8260.0000')),
#  (73, 1, Decimal('1800.0000')),
#  (74, 1, Decimal('1900.0000')),
#  (75, 1, Decimal('6200.0000')),
#  (76, 1, Decimal('1389.0000')),
#  (77, 1, Decimal('1667.0000')),
#  (78, 1, Decimal('3250.0000')),
#  (79, 1, Decimal('3000.0000')),
#  (80, 1, Decimal('15500.0000')),
#  (81, 1, Decimal('4000.0000')),
#  (82, 1, Decimal('2500.0000')),
#  (83, 1, Decimal('1197.0000')),
#  (84, 1, Decimal('2000.0000')),
#  (85, 1, Decimal('1057.0000')),
#  (86, 1, Decimal('1060.0000')),
#  (87, 1, Decimal('4900.0000')),
#  (88, 1, Decimal('1200.0000')),
#  (89, 1, Decimal('1710.0000')),
#  (90, 1, Decimal('1100.0000')),
#  (91, 1, Decimal('1500.0000')),
#  (92, 1, Decimal('1200.0000')),
#  (93, 1, Decimal('1200.0000')),
#  (94, 1, Decimal('1780.0000')),
#  (95, 1, Decimal('2560.0000')),
#  (96, 1, Decimal('2600.0000')),
#  (97, 1, Decimal('2322.0000')),
#  (98, 1, Decimal('1450.0000')),
#  (99, 1, Decimal('2900.0000')),
#  (100, 1, Decimal('2237.0000')),
#  (101, 1, Decimal('12000.0000')),
#  (102, 1, Decimal('1000.0000')),
#  (103, 3, Decimal('78880.0000')),
#  (104, 1, Decimal('1300.0000')),
#  (105, 1, Decimal('1880.0000')),
#  (106, 1, Decimal('1600.0000')),
#  (107, 1, Decimal('9000.0000')),
#  (108, 1, Decimal('1000.0000')),
#  (109, 1, Decimal('1216.0000')),
#  (110, 1, Decimal('2350.0000')),
#  (111, 1, Decimal('2300.0000')),
#  (112, 1, Decimal('1700.0000')),
#  (113, 1, Decimal('1300.0000')),
#  (114, 1, Decimal('1450.0000')),
#  (115, 1, Decimal('18000.0000')),
#  (116, 1, Decimal('1490.0000')),
#  (117, 2, Decimal('3000.0000')),
#  (118, 1, Decimal('13000.0000')),
#  (119, 1, Decimal('3000.0000')),
#  (120, 1, Decimal('1250.0000')),
#  (121, 1, Decimal('1230.0000')),
#  (122, 2, Decimal('19500.0000')),
#  (123, 2, Decimal('3900.0000')),
#  (124, 1, Decimal('1000.0000')),
#  (125, 1, Decimal('8180.0000')),
#  (126, 1, Decimal('1700.0000')),
#  (127, 1, Decimal('3100.0000')),
#  (128, 1, Decimal('1800.0000')),
#  (129, 1, Decimal('1100.0000')),
#  (130, 1, Decimal('4100.0000')),
#  (131, 1, Decimal('1750.0000')),
#  (132, 1, Decimal('1525.0000')),
#  (133, 1, Decimal('1810.0000')),
#  (134, 1, Decimal('2200.0000')),
#  (135, 1, Decimal('1600.0000')),
#  (136, 1, Decimal('1000.0000')),
#  (137, 1, Decimal('6600.0000')),
#  (138, 1, Decimal('1050.0000')),
#  (139, 1, Decimal('6800.0000')),
#  (140, 1, Decimal('1000.0000')),
#  (141, 2, Decimal('2640.0000')),
#  (142, 1, Decimal('1330.0000')),
#  (143, 1, Decimal('3460.0000')),
#  (144, 1, Decimal('5300.0000')),
#  (145, 1, Decimal('1100.0000')),
#  (146, 1, Decimal('1000.0000')),
#  (147, 1, Decimal('1283.0000')),
#  (148, 1, Decimal('2000.0000')),
#  (149, 1, Decimal('2100.0000')),
#  (150, 1, Decimal('1200.0000')),
#  (151, 1, Decimal('1040.0000'))]

# %% [markdown]
# ### Query 3: Even More Aggregation
# **List the DealID, DealName, number of players, total dollar value, and number of parts for each deal.**
# Bonus: use a subquery to construct a comma-separated list of deal types for each deal. (Don't forget the explanatory comment.)

# %%
# %%sql
# SELECT DISTINCT DealID, DealName, SUM(DollarValue) AS TotalValue, COUNT(PartNumber) AS NumParts,
#     (SELECT COUNT(PlayerID) FROM Players WHERE Players.DealID = Deals.DealID) AS NumPlayers
# FROM DealParts
#     JOIN Deals USING (DealID)
# GROUP BY DealID, DealName
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 10 rows affected.
# [(1, 'ADT Limited', Decimal('5600.0000'), 1, 3),
#  (2, 'Alex. Brown Inc.', Decimal('1700.0000'), 1, 2),
#  (3, 'American Medical Response, Inc.', Decimal('1120.0000'), 1, 2),
#  (4, 'American Standard Companies, Inc.', Decimal('4000.0000'), 1, 2),
#  (5, 'Amphenol Corp.', Decimal('1500.0000'), 1, 2),
#  (6, 'Bankamerica Corp.', Decimal('1600.0000'), 1, 1),
#  (7, 'Berliner Kraft & Licht AG', Decimal('1870.0000'), 1, 1),
#  (8, 'Cascade Communications Corp.', Decimal('3700.0000'), 1, 2),
#  (9, 'Chancellor Broadcasting Comp.', Decimal('1600.0000'), 1, 2),
#  (10, 'Cifra S.A.', Decimal('1200.0000'), 1, 2)]

# %% [markdown]
# ### Query 4: A Surprisingly Tricky One
# **List TypeCode, number of deals, and total value of deals for each deal type.**
# Each firm should be listed, even if there are no deals for that firm.

# %%
# %%sql
# SELECT Name, TypeCode, COUNT(DealName) AS NumDeals, SUM(DollarValue) AS TotalValue
# FROM Firms
# LEFT JOIN PlayerSupports USING (FIRMID)
# LEFT JOIN Players ON (PlayerSupports.PlayerID = Players.PlayerID)
# LEFT JOIN Deals ON (Players.DealID = Deals.DealID)
# LEFT JOIN DealTypes ON (Deals.DealID = DealTypes.DealID)
# LEFT JOIN DealParts ON (Deals.DealID = DealParts.DealID)
# GROUP BY Name, TypeCode;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 474 rows affected.
# [('Akin Gump', 'C/S', 1, Decimal('1150.0000')),
#  ('Akin, Gump, Strauss, Hauer & Feld', 'C/S', 1, Decimal('1100.0000')),
#  ('Akin, Gump, Strauss, Hauer & Feld', 'SS', 2, Decimal('2950.0000')),
#  ('Alex. Brown & Sons Inc.', 'C/S', 1, Decimal('1150.0000')),
#  ('Alex. Brown & Sons Inc.', 'SS', 1, Decimal('1700.0000')),
#  ('Allen & Overy', 'CM', 1, Decimal('5300.0000')),
#  ('Allen & Overy', 'TO', 1, Decimal('2800.0000')),
#  ('Alston & Bird', 'C/S', 1, Decimal('18000.0000')),
#  ('Alston & Bird', 'SS', 1, Decimal('8180.0000')),
#  ('Andrews & Kurth', 'C/S', 3, Decimal('3140.0000')),
#  ('Andrews & Kurth', 'SS', 3, Decimal('3300.0000')),
#  ('Ashurst Morris Crisp', 'TO', 1, Decimal('2800.0000')),
#  ('BA Partners', 'C/S', 1, Decimal('1050.0000')),
#  ('Baker & Botts', 'C/S', 4, Decimal('9547.0000')),
#  ('Baker & Botts', 'SS', 2, Decimal('3000.0000')),
#  ('Baker & Botts', 'TO', 1, Decimal('6200.0000')),
#  ('Baker & MacKenzie', 'C/S', 1, Decimal('1200.0000')),
#  ('Banamex', 'C/S', 1, Decimal('1200.0000')),
#  ('Bankers Trust Corp.', 'C/S', 1, Decimal('1500.0000')),
#  ('Bartlit Beck Herman Palenchar & Scott', 'C/S', 1, Decimal('2350.0000')),
#  ('Bear, Stearns & Co., Inc.', 'C/S', 5, Decimal('15710.0000')),
#  ('Bear, Stearns & Co., Inc.', 'PF', 2, Decimal('19500.0000')),
#  ('Bear, Stearns & Co., Inc.', 'SS', 4, Decimal('27750.0000')),
#  ('Bear, Stearns & Co., Inc.', 'TO', 5, Decimal('28600.0000')),
#  ('Bennet Jones Verchere', 'C/S', 1, Decimal('1197.0000')),
#  ('Berlach, Israel & Liberman', 'PA', 1, Decimal('1880.0000')),
#  ('Blake, Cassels & Grayson', 'C/S', 1, Decimal('1600.0000')),
#  ('Blass & Driggs', 'C/S', 1, Decimal('1250.0000')),
#  ('Bobby Blake and Associates', 'SS', 1, Decimal('1100.0000')),
#  ('Boles & Boles', 'C/S', 1, Decimal('2223.0000')),
#  ('Boxenbaum, Grates', 'C/S', 1, Decimal('1617.0000')),
#  ('Bracewell & Paterson', 'C/S', 2, Decimal('2140.0000')),
#  ('Brainerd Communicators', 'SS', 1, Decimal('1600.0000')),
#  ('Broadgate Consultants', 'C/S', 1, Decimal('2820.0000')),
#  ('Brobeck, Phleger & Harrison', 'TO', 2, Decimal('2860.0000')),
#  ('Brown & Wood', 'SS', 1, Decimal('7000.0000')),
#  ('Bryan Cave', 'C/S', 4, Decimal('80080.0000')),
#  ('Bryan Cave', 'SS', 2, Decimal('4400.0000')),
#  ('BT Alex. Brown', 'C/S', 1, Decimal('1283.0000')),
#  ('BT Alex. Brown', 'SS', 2, Decimal('9930.0000')),
#  ('BT Wolfensohn', 'C/S', 2, Decimal('4300.0000')),
#  ('BT Wolfensohn', 'SS', 3, Decimal('5200.0000')),
#  ('Buchanan Ingersol', 'TO', 1, Decimal('1000.0000')),
#  ('Burson-Marsteller', 'C/S', 3, Decimal('78880.0000')),
#  ('Burson-Marsteller', 'PF', 2, Decimal('19500.0000')),
#  ('Burson-Marsteller', 'SS', 3, Decimal('11500.0000')),
#  ('Burson-Marsteller', 'TO', 3, Decimal('25700.0000')),
#  ('Cahill Gordon & Reindel', 'C/S', 2, Decimal('2947.0000')),
#  ('Cahill Gordon & Reindel', 'SS', 1, Decimal('3000.0000')),
#  ('Cahill Gordon & Reindel', 'TO', 1, Decimal('2800.0000')),
#  ('Carrerre & Denegre', 'C/S', 1, Decimal('2223.0000')),
#  ('Cazenove', 'C/S', 2, Decimal('4110.0000')),
#  ('Chadbourne & Parke', 'C/S', 1, Decimal('2223.0000')),
#  ('Chadbourne & Parke', 'CM', 1, Decimal('1500.0000')),
#  ('Chadbourne & Parke', 'PF', 1, Decimal('1700.0000')),
#  ('Chadbourne & Parke', 'SS', 2, Decimal('6600.0000')),
#  ('Chadbourne & Parke', 'TO', 2, Decimal('2970.0000')),
#  ('Chase Securities Inc.', 'C/S', 1, Decimal('2600.0000')),
#  ('Chase Securities Inc.', 'SS', 2, Decimal('6600.0000')),
#  ('Chase Securities Inc.', 'TO', 2, Decimal('6870.0000')),
#  ('CIBC Wood Gundy Inc.', 'C/S', 2, Decimal('2600.0000')),
#  ('CIBC Wood Gundy Securities, Inc.', 'C/S', 1, Decimal('1617.0000')),
#  ('Citigate Inc.', 'TO', 1, Decimal('1590.0000')),
#  ('Clark & Weinstock', 'C/S', 2, Decimal('3900.0000')),
#  ('Cleary, Gottlieb, Steen & Hamilton', 'C/S', 7, Decimal('12487.0000')),
#  ('Cleary, Gottlieb, Steen & Hamilton', 'SS', 8, Decimal('34200.0000')),
#  ('Cleary, Gottlieb, Steen & Hamilton', 'TO', 2, Decimal('2392.0000')),
#  ('Cohane Rafferty Securities Inc.', 'CM', 1, Decimal('1230.0000')),
#  ('Cooley Godward', 'SS', 1, Decimal('1180.0000')),
#  ('Copithorne & Bellows', 'SS', 1, Decimal('1180.0000')),
#  ('Corporate Communications', 'SS', 1, Decimal('2900.0000')),
#  ('Corporate Investor Communications Inc.', 'C/S', 2, Decimal('8160.0000')),
#  ('Corporate Investor Communications Inc.', 'SS', 6, Decimal('11400.0000')),
#  ('Correro Fishman Haygood Phelps Weiss Walmsey & Cas', 'SS', 1, Decimal('3000.0000')),
#  ('Cravath, Swaine & Moore', 'C/S', 17, Decimal('192635.0000')),
#  ('Cravath, Swaine & Moore', 'PF', 2, Decimal('19500.0000')),
#  ('Cravath, Swaine & Moore', 'SS', 10, Decimal('44759.0000')),
#  ('Cravath, Swaine & Moore', 'TO', 5, Decimal('28700.0000')),
#  ('Credit Suisse First Boston', 'C/S', 12, Decimal('42752.0000')),
#  ('Credit Suisse First Boston', 'PA', 1, Decimal('1880.0000')),
#  ('Credit Suisse First Boston', 'PF', 1, Decimal('6590.0000')),
#  ('Credit Suisse First Boston', 'SS', 12, Decimal('50440.0000')),
#  ('Credit Suisse First Boston', 'TO', 5, Decimal('11590.0000')),
#  ('Crouch & Hallett', 'C/S', 1, Decimal('1355.0000')),
#  ('D.F. King & Co., Inc.', None, 2, Decimal('2432.0000')),
#  ('D.F. King & Co., Inc.', 'C/S', 10, Decimal('88518.0000')),
#  ('D.F. King & Co., Inc.', 'PF', 3, Decimal('26090.0000')),
#  ('D.F. King & Co., Inc.', 'SS', 10, Decimal('43177.0000')),
#  ('D.F. King & Co., Inc.', 'TO', 6, Decimal('38292.0000')),
#  ('Daniels & Associates', 'C/S', 1, Decimal('1150.0000')),
#  ('Davies, Ward & Beck', 'SS', 1, Decimal('1000.0000')),
#  ('Davis Polk & Wardell', 'C/S', 15, Decimal('34095.0000')),
#  ('Davis Polk & Wardell', 'CM', 1, Decimal('5300.0000')),
#  ('Davis Polk & Wardell', 'SS', 9, Decimal('35537.0000')),
#  ('Davis Polk & Wardell', 'TO', 3, Decimal('13192.0000')),
#  ('Davis Wallis Foyster', 'C/S', 1, Decimal('1330.0000')),
#  ('Debevoise & Plimpton', 'C/S', 7, Decimal('12500.0000')),
#  ('Debevoise & Plimpton', 'SS', 4, Decimal('8930.0000')),
#  ('Debevoise & Plimpton', 'TO', 1, Decimal('1800.0000')),
#  ('Dechert Price & Rhoads', 'C/S', 3, Decimal('78880.0000')),
#  ('Dechert Price & Rhoads', 'SS', 1, Decimal('2322.0000')),
#  ('Deutsche Morgan Grenfell', 'C/S', 1, Decimal('1810.0000')),
#  ('Deutsche Morgan Grenfell', 'SS', 2, Decimal('4880.0000')),
#  ('Deutsche Morgan Grenfell', 'TO', 1, Decimal('1800.0000')),
#  ('Dewe Rogerson, Inc.', 'SS', 1, Decimal('1500.0000')),
#  ('Dewey Ballantine', 'C/S', 16, Decimal('128640.0000')),
#  ('Dewey Ballantine', 'CM', 1, Decimal('1230.0000')),
#  ('Dewey Ballantine', 'PA', 1, Decimal('1880.0000')),
#  ('Dewey Ballantine', 'PF', 5, Decimal('45590.0000')),
#  ('Dewey Ballantine', 'SS', 14, Decimal('57489.0000')),
#  ('Dewey Ballantine', 'TO', 9, Decimal('50662.0000')),
#  ('Dewey Square', 'PF', 2, Decimal('19500.0000')),
#  ('Dewey Square', 'TO', 2, Decimal('19500.0000')),
#  ('Dickstein Shapiro Morin & Oshinsky', 'TO', 1, Decimal('1000.0000')),
#  ('Dillon, Read & Co. Inc.', 'C/S', 2, Decimal('2910.0000')),
#  ('Dillon, Read & Co. Inc.', 'SS', 1, Decimal('3000.0000')),
#  ('Dinsmore & Shohl', 'C/S', 1, Decimal('2000.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 'C/S', 5, Decimal('6485.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 'CM', 1, Decimal('1500.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 'PF', 2, Decimal('19500.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 'SS', 5, Decimal('14300.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 'TO', 2, Decimal('19500.0000')),
#  ('Dorsey & Whitney', 'SS', 1, Decimal('9000.0000')),
#  ('Dresdner Kleinwort Benson', 'C/S', 1, Decimal('1870.0000')),
#  ('Drinker Biddle & Reath', 'SS', 1, Decimal('1180.0000')),
#  ('Duane, Morris & Heckscher', 'SS', 1, Decimal('1100.0000')),
#  ('Edelman Public Relations World', 'C/S', 1, Decimal('1283.0000')),
#  ('Edelman Public Relations World', 'SS', 1, Decimal('1100.0000')),
#  ('Evercore Group Inc.', 'TO', 1, Decimal('6200.0000')),
#  ('Evercore Partners', 'C/S', 1, Decimal('2560.0000')),
#  ('Faegre & Benson', 'C/S', 1, Decimal('1490.0000')),
#  ('Financial Dynamics', 'C/S', 1, Decimal('1810.0000')),
#  ('Financial Dynamics', 'TO', 1, Decimal('2800.0000')),
#  ('Fleishman-Hillard, Inc.', 'SS', 1, Decimal('5600.0000')),
#  ('Fleishman-Hillard, Inc.', 'TO', 1, Decimal('5600.0000')),
#  ('Foster Pepper & Shefelman', 'PF', 1, Decimal('6590.0000')),
#  ('Foster Pepper & Shefelman', 'SS', 1, Decimal('6590.0000')),
#  ('Freehill, Hollingdale & Page', 'PA', 1, Decimal('1880.0000')),
#  ('Freshfields', 'C/S', 3, Decimal('11630.0000')),
#  ('Freshfields', 'CM', 1, Decimal('5300.0000')),
#  ('Freshfields', 'SS', 1, Decimal('5600.0000')),
#  ('Freshfields', 'TO', 1, Decimal('5600.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', None, 1, Decimal('1216.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', 'C/S', 12, Decimal('97745.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', 'PF', 1, Decimal('6590.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', 'SS', 12, Decimal('44762.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', 'TO', 4, Decimal('14700.0000')),
#  ('Friedman, Billings, Ramsey & Co. Inc.', 'C/S', 1, Decimal('1075.0000')),
#  ('Fulbright & Jaworski', 'C/S', 2, Decimal('2450.0000')),
#  ('Fulbright & Jaworski', 'SS', 2, Decimal('2500.0000')),
#  ('Furman Selz Inc.', 'SS', 1, Decimal('1300.0000')),
#  ('Gallagher PR', 'SS', 1, Decimal('3700.0000')),
#  ('Gardner, Carton & Douglas', 'SS', 1, Decimal('1500.0000')),
#  ('Gavin Anderson & Company', 'C/S', 2, Decimal('2550.0000')),
#  ('Gavin Anderson & Company', 'PF', 1, Decimal('6590.0000')),
#  ('Gavin Anderson & Company', 'SS', 1, Decimal('6590.0000')),
#  ('Georgeson & Company Inc.', 'C/S', 9, Decimal('103535.0000')),
#  ('Georgeson & Company Inc.', 'PF', 4, Decimal('27790.0000')),
#  ('Georgeson & Company Inc.', 'SS', 13, Decimal('76862.0000')),
#  ('Georgeson & Company Inc.', 'TO', 6, Decimal('25690.0000')),
#  ('Gibbs & Bruns', 'TO', 1, Decimal('6200.0000')),
#  ('Gibson, Dunn & Crutcher', None, 1, Decimal('1216.0000')),
#  ('Gibson, Dunn & Crutcher', 'C/S', 7, Decimal('14207.0000')),
#  ('Gibson, Dunn & Crutcher', 'SS', 2, Decimal('10500.0000')),
#  ('Gibson, Dunn & Crutcher', 'TO', 1, Decimal('1000.0000')),
#  ('Gleacher Natwest Inc.', 'PF', 1, Decimal('1700.0000')),
#  ('Gleacher Natwest Inc.', 'SS', 2, Decimal('3300.0000')),
#  ('Goldman Sachs International', 'TO', 2, Decimal('4720.0000')),
#  ('Goldman, Sachs & Co.', None, 1, Decimal('1216.0000')),
#  ('Goldman, Sachs & Co.', 'C/S', 36, Decimal('148974.0000')),
#  ('Goldman, Sachs & Co.', 'PF', 4, Decimal('27790.0000')),
#  ('Goldman, Sachs & Co.', 'SS', 20, Decimal('82638.0000')),
#  ('Goldman, Sachs & Co.', 'TO', 6, Decimal('26490.0000')),
#  ('Goodman and Carr', 'SS', 1, Decimal('1000.0000')),
#  ('Goodman Phillips & Vineberg', 'SS', 1, Decimal('1000.0000')),
#  ('Goodwin, Procter & Hoar', 'C/S', 3, Decimal('3740.0000')),
#  ('Goodwin, Procter & Hoar', 'SS', 1, Decimal('4000.0000')),
#  ('Gordon Altman', 'C/S', 1, Decimal('1000.0000')),
#  ('Goulston & Storrs', 'C/S', 1, Decimal('1000.0000')),
#  ('Gray Carey Ware & Friedenrich', 'SS', 2, Decimal('11000.0000')),
#  ('Greenhill & Co.', 'C/S', 2, Decimal('3900.0000')),
#  ('Greenhill & Co.', 'SS', 2, Decimal('4600.0000')),
#  ('Hambrecht & Quist', 'SS', 1, Decimal('1300.0000')),
#  ('Hanover Capital Partners Ltd.', 'CM', 1, Decimal('1230.0000')),
#  ('Haskell Slaughter & Young', 'C/S', 1, Decimal('1250.0000')),
#  ('Heller Ehrman', 'C/S', 1, Decimal('1150.0000')),
#  ('Heller Ehrman White & McAuliffe', 'C/S', 1, Decimal('1200.0000')),
#  ('Heller Ehrman White & McAuliffe', 'SS', 1, Decimal('1300.0000')),
#  ('Hogan & Hartson', 'SS', 3, Decimal('6439.0000')),
#  ('Howard & Howard', 'C/S', 1, Decimal('6800.0000')),
#  ('Huber Lawrence Abel', 'TO', 1, Decimal('1920.0000')),
#  ('Hughes Hubbard & Reed', 'C/S', 1, Decimal('12000.0000')),
#  ('Hunton & Williams', 'C/S', 1, Decimal('1080.0000')),
#  ('Hutchins, Wheeler & Ditmar', 'CM', 1, Decimal('1230.0000')),
#  ('in-house', 'C/S', 1, Decimal('1200.0000')),
#  ('in-house', 'CM', 1, Decimal('5300.0000')),
#  ('in-house', 'SS', 1, Decimal('1000.0000')),
#  ('Innisfree M&A Inc.', 'C/S', 3, Decimal('78880.0000')),
#  ('Innisfree M&A Inc.', 'SS', 1, Decimal('6600.0000')),
#  ('Innisfree M&A Inc.', 'TO', 2, Decimal('3720.0000')),
#  ('J.P. Morgan & Co., Inc.', 'C/S', 5, Decimal('24557.0000')),
#  ('J.P. Morgan & Co., Inc.', 'PA', 1, Decimal('1880.0000')),
#  ('J.P. Morgan & Co., Inc.', 'SS', 4, Decimal('24250.0000')),
#  ('J.P. Morgan & Co., Inc.', 'TO', 1, Decimal('6200.0000')),
#  ('J.P. Morgan Securities Inc.', 'C/S', 1, Decimal('1100.0000')),
#  ('Jaffoni & Collins Inc.', 'SS', 1, Decimal('1600.0000')),
#  ('Jones, Day, Reavis & Pogue', None, 1, Decimal('1216.0000')),
#  ('Jones, Day, Reavis & Pogue', 'C/S', 13, Decimal('110945.0000')),
#  ('Jones, Day, Reavis & Pogue', 'SS', 6, Decimal('17686.0000')),
#  ('Jones, Day, Reavis & Pogue', 'TO', 1, Decimal('1700.0000')),
#  ('Jones, Walker, Wachter, Poitevent, Carrere & Denegre', 'C/S', 1, Decimal('2223.0000')),
#  ('Jose, Henry, Brantley & Keltner', 'TO', 1, Decimal('6200.0000')),
#  ('Kantrow, Spaht, Weaver & Blitzer', 'TO', 1, Decimal('6200.0000')),
#  ('Katten Muchin & Zavis', 'C/S', 1, Decimal('1120.0000')),
#  ('Katten Muchin & Zavis', 'SS', 1, Decimal('1230.0000')),
#  ('Katten Muchin & Zavis', 'TO', 1, Decimal('1800.0000')),
#  ('Keefe, Bruyette & Woods, Inc.', 'CM', 1, Decimal('1230.0000')),
#  ('Keefe, Bruyette & Woods, Inc.', 'SS', 2, Decimal('5300.0000')),
#  ('Kekst and Company', 'C/S', 14, Decimal('39970.0000')),
#  ('Kekst and Company', 'CM', 1, Decimal('1500.0000')),
#  ('Kekst and Company', 'PF', 2, Decimal('8290.0000')),
#  ('Kekst and Company', 'SS', 14, Decimal('52568.0000')),
#  ('Kekst and Company', 'TO', 3, Decimal('8520.0000')),
#  ('Ketchum Public Relations', 'SS', 2, Decimal('3000.0000')),
#  ('King & Spalding', 'C/S', 1, Decimal('1100.0000')),
#  ('Kirkland & Ellis', 'C/S', 4, Decimal('7450.0000')),
#  ('Kirkland & Ellis', 'SS', 1, Decimal('9500.0000')),
#  ('Kissel-Blake Inc.', 'SS', 2, Decimal('3200.0000')),
#  ('Kramer, Levin, Naftalis & Frankel', 'C/S', 1, Decimal('4000.0000')),
#  ('Kramer, Levin, Naftalis & Frankel', 'SS', 1, Decimal('1200.0000')),
#  ('Kramer, Levin, Naftalis, Nesse, Kamin & Frankel', 'SS', 1, Decimal('5600.0000')),
#  ('Kramer, Levin, Naftalis, Nesse, Kamin & Frankel', 'TO', 1, Decimal('5600.0000')),
#  ('Kummer Kaempfer Bonner & Renshaw', 'PF', 2, Decimal('19500.0000')),
#  ('Kummer Kaempfer Bonner & Renshaw', 'TO', 2, Decimal('19500.0000')),
#  ('Latham & Watkins', 'C/S', 6, Decimal('7983.0000')),
#  ('Latham & Watkins', 'PF', 2, Decimal('19500.0000')),
#  ('Latham & Watkins', 'SS', 3, Decimal('6700.0000')),
#  ('Latham & Watkins', 'TO', 2, Decimal('19500.0000')),
#  ('Lazard Brothers & Company Ltd.', 'C/S', 1, Decimal('9700.0000')),
#  ('Lazard Brothers & Company Ltd.', 'CM', 1, Decimal('5300.0000')),
#  ('Lazard Freres & Co. LLC', 'C/S', 9, Decimal('94160.0000')),
#  ('Lazard Freres & Co. LLC', 'PF', 2, Decimal('19500.0000')),
#  ('Lazard Freres & Co. LLC', 'SS', 1, Decimal('7000.0000')),
#  ('Lazard Freres & Co. LLC', 'TO', 2, Decimal('19500.0000')),
#  ('LeBoeuf, Lamb, Greene & MacRae', 'C/S', 1, Decimal('4210.0000')),
#  ('LeBoeuf, Lamb, Greene & MacRae', 'SS', 2, Decimal('2730.0000')),
#  ('Lehman Brothers', 'C/S', 8, Decimal('92170.0000')),
#  ('Lehman Brothers', 'CM', 1, Decimal('1500.0000')),
#  ('Lehman Brothers', 'PF', 1, Decimal('6590.0000')),
#  ('Lehman Brothers', 'SS', 7, Decimal('19690.0000')),
#  ('Lehman Brothers', 'TO', 2, Decimal('8120.0000')),
#  ('Liddell, Sapp, Zivley, Hill & LaBoon', 'SS', 1, Decimal('1200.0000')),
#  ('Liebowitz & Associates', 'C/S', 1, Decimal('1200.0000')),
#  ('Linklaters & Paines', 'C/S', 4, Decimal('88580.0000')),
#  ('Linklaters & Paines', 'TO', 1, Decimal('2800.0000')),
#  ('Locke, Purnell, Rain & Harrell', 'C/S', 1, Decimal('1100.0000')),
#  ('Long Aldridge Norman', 'C/S', 1, Decimal('1617.0000')),
#  ('Lowenstein, Sandler, Kohl, Fisher & Boy-Ian', 'SS', 1, Decimal('2500.0000')),
#  ('MacKenzie Partners, Inc.', 'C/S', 3, Decimal('5550.0000')),
#  ('MacKenzie Partners, Inc.', 'CM', 1, Decimal('1500.0000')),
#  ('MacKenzie Partners, Inc.', 'PF', 3, Decimal('26090.0000')),
#  ('MacKenzie Partners, Inc.', 'SS', 3, Decimal('21190.0000')),
#  ('MacKenzie Partners, Inc.', 'TO', 4, Decimal('26100.0000')),
#  ('Mallesons, Stephens, Jacques', 'PA', 1, Decimal('1880.0000')),
#  ('Mayer, Brown & Platt', 'C/S', 3, Decimal('4100.0000')),
#  ('Mayer, Brown & Platt', 'SS', 1, Decimal('7300.0000')),
#  ('Mayer, Brown & Platt', 'TO', 1, Decimal('1270.0000')),
#  ('Mayor, Day, Caldwell & Keeton', 'SS', 1, Decimal('1000.0000')),
#  ('McCormick & Pryor', 'SS', 1, Decimal('1180.0000')),
#  ('McDermott, Will & Emery', 'C/S', 1, Decimal('1100.0000')),
#  ('McDermott, Will & Emery', 'SS', 1, Decimal('1500.0000')),
#  ('McDonald & Co.', 'SS', 1, Decimal('1050.0000')),
#  ('McGuire, Woods, Battle & Boothe', 'SS', 2, Decimal('6650.0000')),
#  ('Merrill Lynch & Co.', 'C/S', 20, Decimal('33625.0000')),
#  ('Merrill Lynch & Co.', 'CM', 2, Decimal('2730.0000')),
#  ('Merrill Lynch & Co.', 'PF', 3, Decimal('26090.0000')),
#  ('Merrill Lynch & Co.', 'SS', 25, Decimal('104206.0000')),
#  ('Merrill Lynch & Co.', 'TO', 6, Decimal('30700.0000')),
#  ('Milbank, Tweed, Hadley & McCloy', 'C/S', 5, Decimal('89660.0000')),
#  ('Miller & Martin', 'C/S', 1, Decimal('1617.0000')),
#  ('Miller Shandwick Technologies', 'SS', 1, Decimal('3000.0000')),
#  ('Miller, Nash, Wiener, Hagen & Carlsen', 'SS', 1, Decimal('9000.0000')),
#  ('Montgomery Securities', 'C/S', 1, Decimal('1000.0000')),
#  ('Montgomery Securities', 'PF', 2, Decimal('8290.0000')),
#  ('Montgomery Securities', 'SS', 3, Decimal('23790.0000')),
#  ('Montgomery Securities', 'TO', 2, Decimal('2392.0000')),
#  ('Morgan Stanley & Co. Inc.', 'C/S', 12, Decimal('101840.0000')),
#  ('Morgan Stanley & Co. Inc.', 'SS', 11, Decimal('47980.0000')),
#  ('Morgan Stanley & Co. Inc.', 'TO', 5, Decimal('7680.0000')),
#  ('Morgan Stanley Dean Witter', None, 1, Decimal('1216.0000')),
#  ('Morgan Stanley Dean Witter', 'C/S', 12, Decimal('47820.0000')),
#  ('Morgan Stanley Dean Witter', 'SS', 7, Decimal('30360.0000')),
#  ('Morgan Stanley Dean Witter', 'TO', 1, Decimal('1392.0000')),
#  ('Morgan, Lewis & Bockius', 'C/S', 1, Decimal('1200.0000')),
#  ('Morgan, Lewis & Bockius', 'SS', 1, Decimal('3100.0000')),
#  ('Morgan, Lewis & Bockius', 'TO', 1, Decimal('6200.0000')),
#  ('Morris, Nichols, Arsht & Tunnell', 'C/S', 11, Decimal('91720.0000')),
#  ('Morris, Nichols, Arsht & Tunnell', 'PF', 4, Decimal('27790.0000')),
#  ('Morris, Nichols, Arsht & Tunnell', 'SS', 10, Decimal('37720.0000')),
#  ('Morris, Nichols, Arsht & Tunnell', 'TO', 2, Decimal('19500.0000')),
#  ('Morrison & Foerster', 'SS', 1, Decimal('3000.0000')),
#  ('Morrison & Foerster', 'TO', 1, Decimal('1900.0000')),
#  ('Morrison & Hecker', 'C/S', 1, Decimal('1100.0000')),
#  ('Morrow & Co., Inc.', 'C/S', 1, Decimal('1200.0000')),
#  ('Morrow & Co., Inc.', 'SS', 6, Decimal('11087.0000')),
#  ('Morrow & Co., Inc.', 'TO', 3, Decimal('9800.0000')),
#  ('Munger, Tolles & Olson', 'C/S', 1, Decimal('1700.0000')),
#  ('Munsch Hardt Kopf Harr & Dinan', 'C/S', 1, Decimal('1080.0000')),
#  ('NationsBanc Capital Markets', 'SS', 2, Decimal('2000.0000')),
#  ('NationsBanc Capital Markets', 'TO', 1, Decimal('1000.0000')),
#  ('Nationsbank ontgomery Securities', 'C/S', 1, Decimal('6800.0000')),
#  ('Neal, Gerber & Eisenberg', 'C/S', 2, Decimal('2625.0000')),
#  ('Nesbitt Burns Inc.', 'C/S', 1, Decimal('1500.0000')),
#  ('NM Rothschild', 'C/S', 1, Decimal('2300.0000')),
#  ('NM Rothschild', 'TO', 1, Decimal('2800.0000')),
#  ('Noonan/Russo Communications, Inc.', 'SS', 1, Decimal('1650.0000')),
#  ('Nyemaster, Goode, McLaughlin, Voigts, West, Hansel', 'C/S', 1, Decimal('2600.0000')),
#  ("O'Melveny & Myers", 'C/S', 6, Decimal('82880.0000')),
#  ("O'Melveny & Myers", 'TO', 1, Decimal('1000.0000')),
#  ('Orrick, Herrington & Sutcliffe', 'SS', 1, Decimal('1500.0000')),
#  ('Orrick, Herrington & Sutcliffe', 'TO', 1, Decimal('1800.0000')),
#  ('Oscar Folger, solo practitioner', 'SS', 1, Decimal('1500.0000')),
#  ('Osler, Hoskin & Harcourt', 'SS', 1, Decimal('1000.0000')),
#  ('PaineWebber Inc.', 'C/S', 3, Decimal('3740.0000')),
#  ('PaineWebber Inc.', 'SS', 1, Decimal('1389.0000')),
#  ('Paul, Weiss, Rifkind, Wharton & Garrison', 'C/S', 11, Decimal('167835.0000')),
#  ('Paul, Weiss, Rifkind, Wharton & Garrison', 'SS', 8, Decimal('22000.0000')),
#  ('Paul, Weiss, Rifkind, Wharton & Garrison', 'TO', 1, Decimal('1392.0000')),
#  ('Peper, Martin, Jensen, Maichel and Hetlage', 'SS', 1, Decimal('2900.0000')),
#  ('Pepper, Hamilton & Scheetz', 'C/S', 1, Decimal('1360.0000')),
#  ('Perkins Coie', 'C/S', 1, Decimal('2820.0000')),
#  ('Peter J. Solomon Company', 'SS', 1, Decimal('2322.0000')),
#  ('Pillsbury Madison & Sutro', 'C/S', 1, Decimal('1490.0000')),
#  ('Pillsbury Madison & Sutro', 'SS', 1, Decimal('5000.0000')),
#  ('Piper & Marbury', 'C/S', 1, Decimal('1150.0000')),
#  ('Piper & Marbury', 'SS', 1, Decimal('1700.0000')),
#  ('Potter Anderson & Corroon', 'C/S', 3, Decimal('4200.0000')),
#  ('Powell, Goldstein, Frazer & Murphy', 'C/S', 1, Decimal('1000.0000')),
#  ('Powell, Goldstein, Frazer & Murphy', 'SS', 1, Decimal('1000.0000')),
#  ('Proskauer Rose Goetz Mendelsohn', 'C/S', 2, Decimal('2625.0000')),
#  ('Quarles & Brady', 'TO', 1, Decimal('1800.0000')),
#  ('Raymond James & Associates Inc.', 'SS', 1, Decimal('1230.0000')),
#  ('Raymond James & Associates Inc.', 'TO', 1, Decimal('1800.0000')),
#  ('RBC Dominion Securities Inc.', 'C/S', 2, Decimal('2814.0000')),
#  ('Richards, Layton & Finger', 'C/S', 19, Decimal('118730.0000')),
#  ('Richards, Layton & Finger', 'CM', 1, Decimal('1500.0000')),
#  ('Richards, Layton & Finger', 'PF', 2, Decimal('8290.0000')),
#  ('Richards, Layton & Finger', 'SS', 20, Decimal('80559.0000')),
#  ('Richards, Layton & Finger', 'TO', 3, Decimal('13700.0000')),
#  ('Riordan & McKenzie', 'SS', 1, Decimal('1100.0000')),
#  ('Robinson Lerer & Montgomery', 'PF', 1, Decimal('1700.0000')),
#  ('Robinson Lerer & Montgomery', 'SS', 2, Decimal('12600.0000')),
#  ('Robinson Lerer & Montgomery', 'TO', 1, Decimal('6200.0000')),
#  ('Robinson Silverman Pearce Aronsohn & Berman', 'C/S', 2, Decimal('3900.0000')),
#  ('Rogers & Wells', 'C/S', 3, Decimal('3905.0000')),
#  ('Rogers & Wells', 'SS', 1, Decimal('2500.0000')),
#  ('Ropes & Gray', 'C/S', 1, Decimal('1120.0000')),
#  ('Rosenberg & Liebentritt', 'SS', 2, Decimal('5700.0000')),
#  ('Rothschild Inc./NM Rothschild & Sons Ltd.', 'C/S', 3, Decimal('78880.0000')),
#  ('Rudnick & Wolfe', 'C/S', 1, Decimal('1057.0000')),
#  ('Salomon Brothers Inc.', 'C/S', 11, Decimal('97187.0000')),
#  ('Salomon Brothers Inc.', 'SS', 8, Decimal('39400.0000')),
#  ('Salomon Brothers Inc.', 'TO', 2, Decimal('6600.0000')),
#  ('Salomon Smith Barney', 'SS', 2, Decimal('10060.0000')),
#  ('Sard Verbinnen & Co., Inc.', 'C/S', 8, Decimal('87400.0000')),
#  ('Sard Verbinnen & Co., Inc.', 'PF', 2, Decimal('19500.0000')),
#  ('Sard Verbinnen & Co., Inc.', 'SS', 3, Decimal('22770.0000')),
#  ('Sard Verbinnen & Co., Inc.', 'TO', 3, Decimal('21300.0000')),
#  ('SBC Warburg', 'C/S', 1, Decimal('8000.0000')),
#  ('Schreck Morris', 'PF', 2, Decimal('19500.0000')),
#  ('Schreck Morris', 'TO', 2, Decimal('19500.0000')),
#  ('Schroder Wertheim & Co.', 'TO', 1, Decimal('1392.0000')),
#  ('Schulte Roth & Zabel', 'C/S', 2, Decimal('3900.0000')),
#  ('Shareholder Communications Corporation', 'C/S', 1, Decimal('9700.0000')),
#  ('Shearman & Sterling', 'C/S', 13, Decimal('105002.0000')),
#  ('Shearman & Sterling', 'CM', 1, Decimal('5300.0000')),
#  ('Shearman & Sterling', 'PF', 1, Decimal('1700.0000')),
#  ('Shearman & Sterling', 'SS', 14, Decimal('52519.0000')),
#  ('Shearman & Sterling', 'TO', 5, Decimal('11910.0000')),
#  ('Sheehan Phinney Bass & Green', 'TO', 1, Decimal('1700.0000')),
#  ('Sidley & Austin', 'C/S', 2, Decimal('3280.0000')),
#  ('Sidley & Austin', 'PF', 2, Decimal('19500.0000')),
#  ('Sidley & Austin', 'SS', 2, Decimal('2700.0000')),
#  ('Sidley & Austin', 'TO', 2, Decimal('19500.0000')),
#  ('Simpson Thacher & Bartlett', 'C/S', 15, Decimal('126630.0000')),
#  ('Simpson Thacher & Bartlett', 'CM', 1, Decimal('1500.0000')),
#  ('Simpson Thacher & Bartlett', 'PF', 3, Decimal('26090.0000')),
#  ('Simpson Thacher & Bartlett', 'SS', 21, Decimal('81449.0000')),
#  ('Simpson Thacher & Bartlett', 'TO', 6, Decimal('30892.0000')),
#  ('SJ Berwin & Co.', 'C/S', 1, Decimal('2000.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 'C/S', 17, Decimal('43180.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 'CM', 1, Decimal('1230.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 'PF', 4, Decimal('27790.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 'SS', 21, Decimal('80130.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 'TO', 8, Decimal('35190.0000')),
#  ('Skinner & Co.', 'SS', 2, Decimal('5000.0000')),
#  ('Slaughter & May', 'C/S', 3, Decimal('19510.0000')),
#  ('Smith Barney Inc.', 'C/S', 6, Decimal('9590.0000')),
#  ('Smith Barney Inc.', 'CM', 1, Decimal('1230.0000')),
#  ('Smith Barney Inc.', 'SS', 6, Decimal('15919.0000')),
#  ('Smith Barney Inc.', 'TO', 2, Decimal('7592.0000')),
#  ('Societe Generale Securities Corporation', 'C/S', 1, Decimal('2000.0000')),
#  ('Sonnenschein Nath & Rosenthal', 'TO', 1, Decimal('1800.0000')),
#  ('Squardon, Ellenoff', 'C/S', 1, Decimal('1900.0000')),
#  ('Squardon, Ellenoff, Plesent & Sheinfeld', 'C/S', 1, Decimal('1355.0000')),
#  ('Stikeman, Elliot', 'C/S', 2, Decimal('3117.0000')),
#  ('Stoel Rives', 'C/S', 2, Decimal('11923.0000')),
#  ('Stoel Rives', 'SS', 2, Decimal('4800.0000')),
#  ('Stroock & Stroock & Lavan', 'C/S', 1, Decimal('1000.0000')),
#  ('Stroock & Stroock & Lavan', 'TO', 1, Decimal('1000.0000')),
#  ('Sullivan & Cromwell', 'C/S', 33, Decimal('151054.0000')),
#  ('Sullivan & Cromwell', 'CM', 1, Decimal('1230.0000')),
#  ('Sullivan & Cromwell', 'PF', 1, Decimal('6590.0000')),
#  ('Sullivan & Cromwell', 'SS', 18, Decimal('73266.0000')),
#  ('Sullivan & Cromwell', 'TO', 6, Decimal('14390.0000')),
#  ('Sullivan & Worcester', 'C/S', 1, Decimal('2600.0000')),
#  ('Sutherland, Asbill & Brennan', 'C/S', 2, Decimal('4220.0000')),
#  ('Swindler & Berlin', 'C/S', 4, Decimal('79960.0000')),
#  ('Taft, Stettinius & Hollister', 'C/S', 1, Decimal('1100.0000')),
#  ('Tanner & Co. Inc.', 'C/S', 2, Decimal('3000.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 'C/S', 10, Decimal('98040.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 'CM', 1, Decimal('1230.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 'PF', 3, Decimal('26090.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 'SS', 11, Decimal('76527.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 'TO', 4, Decimal('27020.0000')),
#  ('The Atkins Company', 'SS', 1, Decimal('1500.0000')),
#  ('The Blackstone Group L.P.', 'C/S', 2, Decimal('2640.0000')),
#  ('The Blackstone Group L.P.', 'SS', 1, Decimal('1500.0000')),
#  ('The Dilenschneider Group', 'C/S', 1, Decimal('2000.0000')),
#  ('Thompson, Hine & Flory', 'C/S', 1, Decimal('1000.0000')),
#  ('Tillinghast', 'C/S', 1, Decimal('2600.0000')),
#  ('Toronto Dominion', 'C/S', 1, Decimal('1600.0000')),
#  ('Tory, Tory, DesLauriers & Binnington', 'C/S', 2, Decimal('3117.0000')),
#  ('Troop, Meisinger, Steuer, Pasich', 'C/S', 1, Decimal('1900.0000')),
#  ('Troutman Sanders', 'C/S', 1, Decimal('1870.0000')),
#  ('UBS Securities', 'C/S', 2, Decimal('8083.0000')),
#  ('UBS Securities', 'SS', 3, Decimal('9700.0000')),
#  ('UBS Securities', 'TO', 1, Decimal('1590.0000')),
#  ('Union Bank of Switzerland', 'C/S', 1, Decimal('1617.0000')),
#  ('Venture Law Group', 'SS', 1, Decimal('1100.0000')),
#  ('Vinson & Elkins', 'C/S', 2, Decimal('2397.0000')),
#  ('Vinson & Elkins', 'SS', 3, Decimal('10050.0000')),
#  ('Vinson & Elkins', 'TO', 1, Decimal('1270.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', None, 1, Decimal('1216.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', 'C/S', 13, Decimal('28480.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', 'PF', 2, Decimal('19500.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', 'SS', 16, Decimal('78939.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', 'TO', 2, Decimal('19500.0000')),
#  ('Waller Lansden Dortch & Davis', 'SS', 1, Decimal('8180.0000')),
#  ('Wasserstein Perella & Co. Inc.', 'C/S', 4, Decimal('5975.0000')),
#  ('Wasserstein Perella & Co. Inc.', 'SS', 4, Decimal('17189.0000')),
#  ('Watson Farley', 'C/S', 2, Decimal('2625.0000')),
#  ('Weil, Gotshal & Manges', 'C/S', 8, Decimal('32388.0000')),
#  ('Weil, Gotshal & Manges', 'SS', 4, Decimal('17100.0000')),
#  ('White & Case', 'C/S', 2, Decimal('4550.0000')),
#  ('White & Case', 'SS', 2, Decimal('12500.0000')),
#  ('White & Case', 'TO', 2, Decimal('3820.0000')),
#  ('Wilcox & Savage', 'C/S', 1, Decimal('1080.0000')),
#  ('Wiley, Rein & Fielding', 'C/S', 3, Decimal('5100.0000')),
#  ('William Blair & Company', 'TO', 1, Decimal('1800.0000')),
#  ('Williams, Mullen, Christian & Dobbins', 'SS', 1, Decimal('2300.0000')),
#  ('Willkie Farr & Gallagher', 'C/S', 6, Decimal('9767.0000')),
#  ('Willkie Farr & Gallagher', 'SS', 3, Decimal('10622.0000')),
#  ('Willkie Farr & Gallagher', 'TO', 1, Decimal('1920.0000')),
#  ('Wilmer, Cutler & Pickering', 'C/S', 2, Decimal('13100.0000')),
#  ('Wilmer, Cutler & Pickering', 'SS', 1, Decimal('3000.0000')),
#  ('Wilson, Sonsini, Goodrich & Rosati', 'PF', 1, Decimal('1700.0000')),
#  ('Wilson, Sonsini, Goodrich & Rosati', 'SS', 4, Decimal('5480.0000')),
#  ('Wilson, Sonsini, Goodrich & Rosati', 'TO', 1, Decimal('1800.0000')),
#  ('Winthrop, Stimson, Putnam & Roberts', 'C/S', 1, Decimal('2100.0000')),
#  ('Winthrop, Stimson, Putnam & Roberts', 'CM', 1, Decimal('1500.0000')),
#  ('Wolf, Block, Schorr & Cohe', 'C/S', 1, Decimal('1300.0000')),
#  ('Wolfensohn', 'C/S', 1, Decimal('1283.0000')),
#  ('Young, Conaway, Stargatt & Taylor', 'C/S', 1, Decimal('1700.0000'))]

# %% [markdown]
# ### Query 5: Make up your own query to share.
# Be creative. Impress us with your brilliance!

# %%
# %%sql
# SELECT FirmID, PlayerID, CompanyID, DealID, DealName
# FROM Deals
#     JOIN DealParts USING (DealID)
#     JOIN Players USING (DealID)
#     JOIN Companies USING (CompanyID)
#     JOIN PlayerSupports USING (PlayerID)
#     JOIN Firms USING (FirmID)
# ORDER BY FirmID;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 1384 rows affected.
# [(2, 81, 268, 88, 'H&R Block Inc.'),
#  (2, 132, 268, 103, 'MCI Communications Corporation'),
#  (2, 132, 268, 103, 'MCI Communications Corporation'),
#  (2, 132, 268, 103, 'MCI Communications Corporation'),
#  (2, 263, 31, 99, 'Brooks Fiber Properties, Inc.'),
#  (2, 255, 193, 91, 'Ralston Purina Co.'),
#  (3, 94, 131, 102, 'Greenfield Industries, Inc.'),
#  (11, 261, 15, 97, 'Amerisource Health Corp.'),
#  (11, 297, 274, 103, 'MCI Communications Corporation'),
#  (11, 297, 274, 103, 'MCI Communications Corporation'),
#  (11, 297, 274, 103, 'MCI Communications Corporation'),
#  (12, 272, 147, 108, 'Sony Corporation of America'),
#  (19, 48, 185, 55, 'Valero Energy Corp.'),
#  (19, 272, 147, 108, 'Sony Corporation of America'),
#  (19, 278, 32, 114, 'Browning-Ferris Industries Inc.'),
#  (19, 317, 307, 140, 'Hermann Healthcare System'),
#  (33, 132, 268, 103, 'MCI Communications Corporation'),
#  (33, 132, 268, 103, 'MCI Communications Corporation'),
#  (33, 132, 268, 103, 'MCI Communications Corporation'),
#  (33, 209, 231, 45, 'Telco Communications Group Inc.'),
#  (36, 5, 124, 7, 'Berliner Kraft & Licht AG'),
#  (41, 328, 291, 146, 'Retail Property Trust'),
#  (42, 301, 44, 108, 'Sony Corporation of America'),
#  (46, 131, 197, 123, 'Lin Television Corp.'),
#  (46, 131, 197, 123, 'Lin Television Corp.'),
#  (50, 123, 111, 122, 'ITT Corp.'),
#  (50, 123, 111, 122, 'ITT Corp.'),
#  (62, 265, 59, 101, 'Coopers & Lybrand L.L.P.'),
#  (64, 140, 273, 45, 'Telco Communications Group Inc.'),
#  (65, 284, 112, 121, 'Homeside, Inc.'),
#  (66, 37, 191, 43, 'Tambrands Inc.'),
#  (66, 49, 53, 56, 'Value Health, Inc.'),
#  (66, 61, 33, 68, 'The Louisiana Land and Exploration Company'),
#  (66, 67, 152, 74, 'Nellcor Puritan Bennett Inc.'),
#  (66, 73, 169, 80, 'Barnett Banks, Inc.'),
#  (66, 87, 223, 94, 'Westin Hotels & Resorts'),
#  (66, 90, 158, 97, 'Amerisource Health Corp.'),
#  (66, 97, 91, 106, 'The Quick & Reilly Group, Inc.'),
#  (66, 102, 80, 58, 'Viacom Inc.'),
#  (66, 144, 273, 40, 'Renaissance Hotel Group N.V.'),
#  (66, 166, 3, 1, 'ADT Limited'),
#  (66, 186, 98, 21, 'Great Western Financial Corp.'),
#  (66, 191, 113, 26, 'Horizon/CMS Healthcare Corp.'),
#  (66, 196, 137, 31, 'KU Energy Corporation'),
#  (66, 199, 167, 35, 'Minnesota Mining and Manufacturing Comp.'),
#  (66, 236, 174, 72, 'Northrop Grumman Corp.'),
#  (66, 243, 227, 79, 'Tandem Computers Inc.'),
#  (66, 250, 90, 86, 'Fisher Scientific International Inc.'),
#  (66, 252, 56, 88, 'H&R Block Inc.'),
#  (66, 272, 147, 108, 'Sony Corporation of America'),
#  (66, 273, 204, 109, 'Rohr Inc.'),
#  (66, 280, 61, 116, 'Cowles Media Company'),
#  (66, 289, 194, 126, 'Quality Food Centers Inc.'),
#  (66, 297, 274, 103, 'MCI Communications Corporation'),
#  (66, 297, 274, 103, 'MCI Communications Corporation'),
#  (66, 297, 274, 103, 'MCI Communications Corporation'),
#  (66, 239, 184, 75, 'Pennzoil Comp.'),
#  (67, 6, 20, 8, 'Cascade Communications Corp.'),
#  (67, 31, 67, 36, 'Morgan Stanley Group Inc.'),
#  (67, 33, 162, 38, 'Parker & Parsley Petrolium Company'),
#  (67, 46, 1, 53, 'U.S. Robotics Corp.'),
#  (67, 47, 5, 54, 'U.S. West, Inc.'),
#  (67, 59, 200, 66, 'Falcon Drilling Co.'),
#  (67, 65, 146, 72, 'Northrop Grumman Corp.'),
#  (67, 72, 55, 79, 'Tandem Computers Inc.'),
#  (67, 100, 218, 110, 'Tejas Gas Corp.'),
#  (67, 125, 100, 21, 'Great Western Financial Corp.'),
#  (67, 154, 145, 34, 'Living Centers of America Inc.'),
#  (67, 156, 178, 62, 'Celebrity Cruise Lines Inc'),
#  (67, 156, 178, 62, 'Celebrity Cruise Lines Inc'),
#  (67, 164, 250, 108, 'Sony Corporation of America'),
#  (67, 166, 3, 1, 'ADT Limited'),
#  (67, 168, 11, 3, 'American Medical Response, Inc.'),
#  (67, 169, 13, 4, 'American Standard Companies, Inc.'),
#  (67, 170, 16, 5, 'Amphenol Corp.'),
#  (67, 185, 116, 20, 'General Motors Corp.'),
#  (67, 189, 106, 24, 'Heritage Media Corp.'),
#  (67, 203, 199, 39, 'Read-Rite Corp.'),
#  (67, 205, 202, 41, 'Revco D.S., Inc.'),
#  (67, 207, 226, 43, 'Tambrands Inc.'),
#  (67, 211, 235, 47, 'Texas Instruments Inc.'),
#  (67, 221, 257, 57, 'Verifone, Inc.'),
#  (67, 238, 170, 74, 'Nellcor Puritan Bennett Inc.'),
#  (67, 240, 207, 76, 'Rykoff Sexton Inc.'),
#  (67, 253, 143, 123, 'Lin Television Corp.'),
#  (67, 253, 143, 123, 'Lin Television Corp.'),
#  (67, 256, 217, 92, 'SFX Broadcasting Inc.'),
#  (67, 260, 12, 96, 'American Radio Systems Corp.'),
#  (67, 267, 157, 103, 'MCI Communications Corporation'),
#  (67, 267, 157, 103, 'MCI Communications Corporation'),
#  (67, 267, 157, 103, 'MCI Communications Corporation'),
#  (67, 268, 171, 104, 'Network General Corp.'),
#  (67, 271, 211, 107, 'Salomon Inc.'),
#  (67, 296, 142, 27, 'International Family Entertainment Inc.'),
#  (67, 173, 39, 8, 'Cascade Communications Corp.'),
#  (67, 280, 61, 116, 'Cowles Media Company'),
#  (67, 239, 184, 75, 'Pennzoil Comp.'),
#  (67, 293, 250, 130, 'Seagram Company'),
#  (67, 334, 297, 145, 'Renal Treatment Centers Inc.'),
#  (68, 12, 7, 14, 'DQE Inc.'),
#  (68, 19, 48, 22, 'Healthsource, Inc.'),
#  (68, 22, 64, 25, 'HFS Inc.'),
#  (68, 35, 65, 41, 'Revco D.S., Inc.'),
#  (68, 46, 1, 53, 'U.S. Robotics Corp.'),
#  (68, 51, 214, 112, 'Viacom Inc.'),
#  (68, 56, 260, 63, 'Central Fidelity Banks Inc.'),
#  (68, 58, 120, 65, 'Equitable of Iowa Companies'),
#  (68, 67, 152, 74, 'Nellcor Puritan Bennett Inc.'),
#  (68, 69, 130, 76, 'Rykoff Sexton Inc.'),
#  (68, 71, 88, 78, 'Signet Banking Corp.'),
#  (68, 76, 188, 83, 'Chauvco Resources LTD.'),
#  (68, 100, 218, 110, 'Tejas Gas Corp.'),
#  (68, 104, 221, 114, 'Browning-Ferris Industries Inc.'),
#  (68, 110, 168, 121, 'Homeside, Inc.'),
#  (68, 114, 94, 126, 'Quality Food Centers Inc.'),
#  (68, 115, 94, 127, 'Ralphs Grocery Company'),
#  (68, 117, 133, 129, 'Santa Fe Pacific Pipeline Partners'),
#  (68, 120, 219, 132, 'Westinghouse Electric Corp.'),
#  (68, 121, 256, 58, 'Viacom Inc.'),
#  (68, 122, 264, 1, 'ADT Limited'),
#  (68, 125, 100, 21, 'Great Western Financial Corp.'),
#  (68, 150, 85, 51, 'U.S. Bancorp'),
#  (68, 169, 13, 4, 'American Standard Companies, Inc.'),
#  (68, 185, 116, 20, 'General Motors Corp.'),
#  (68, 188, 229, 23, 'Hercules Inc. and Mallickrodt Inc'),
#  (68, 192, 123, 27, 'International Family Entertainment Inc.'),
#  (68, 194, 129, 29, 'Johnson & Higgins'),
#  (68, 195, 132, 30, 'Keystone International Inc.'),
#  (68, 198, 14, 33, 'Lincoln National Corporation'),
#  (68, 202, 181, 38, 'Parker & Parsley Petrolium Company'),
#  (68, 208, 228, 44, 'Target Therapeutics, Inc.'),
#  (68, 214, 248, 50, 'United Waste Systems, Inc.'),
#  (68, 223, 259, 59, 'Vivra Inc.'),
#  (68, 228, 47, 64, 'Cigna Corporation'),
#  (68, 233, 164, 69, 'Montgomery Securities'),
#  (68, 237, 176, 73, 'Octel Communications Corporation'),
#  (68, 241, 213, 77, 'Scudder, Stevens & Clark Inc.'),
#  (68, 252, 56, 88, 'H&R Block Inc.'),
#  (68, 254, 163, 90, 'Monterey Resources Inc.'),
#  (68, 257, 263, 93, 'Western National Corp.'),
#  (68, 258, 265, 94, 'Westin Hotels & Resorts'),
#  (68, 260, 12, 96, 'American Radio Systems Corp.'),
#  (68, 262, 19, 98, 'Apria Healthcare Group Inc.'),
#  (68, 264, 35, 100, 'Calilber Systems Inc.'),
#  (68, 267, 157, 103, 'MCI Communications Corporation'),
#  (68, 267, 157, 103, 'MCI Communications Corporation'),
#  (68, 267, 157, 103, 'MCI Communications Corporation'),
#  (68, 280, 61, 116, 'Cowles Media Company'),
#  (68, 293, 250, 130, 'Seagram Company'),
#  (68, 134, 160, 115, 'Corestates Financial Corp.'),
#  (68, 8, 261, 10, 'Cifra S.A.'),
#  (68, 116, 138, 128, 'Safety-Kleen Corp.'),
#  (68, 133, 277, 133, 'Allied Colloids Group PLC'),
#  (68, 305, 319, 134, 'American First Financial Insurance Group Inc.'),
#  (68, 312, 310, 138, 'Coulter Corp.'),
#  (68, 329, 292, 146, 'Retail Property Trust'),
#  (69, 127, 242, 1, 'ADT Limited'),
#  (70, 43, 117, 49, 'The Unilever Group'),
#  (70, 101, 84, 111, 'T&N PLC'),
#  (70, 127, 242, 1, 'ADT Limited'),
#  (70, 321, 302, 142, 'Lucas Varity PLC'),
#  (70, 326, 298, 144, 'Mercury Asset Management Group, P.L.C.'),
#  (71, 9, 52, 11, 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  (71, 15, 21, 17, 'First Financial Corp.'),
#  (71, 33, 162, 38, 'Parker & Parsley Petrolium Company'),
#  (71, 38, 29, 44, 'Target Therapeutics, Inc.'),
#  (71, 52, 119, 59, 'Vivra Inc.'),
#  (71, 87, 223, 94, 'Westin Hotels & Resorts'),
#  (71, 113, 187, 125, 'Medpartners, Inc.'),
#  (71, 124, 30, 103, 'MCI Communications Corporation'),
#  (71, 124, 30, 103, 'MCI Communications Corporation'),
#  (71, 124, 30, 103, 'MCI Communications Corporation'),
#  (71, 127, 242, 1, 'ADT Limited'),
#  (71, 135, 242, 4, 'American Standard Companies, Inc.'),
#  (71, 162, 161, 76, 'Rykoff Sexton Inc.'),
#  (71, 167, 6, 2, 'Alex. Brown Inc.'),
#  (71, 174, 43, 9, 'Chancellor Broadcasting Comp.'),
#  (71, 181, 74, 16, 'The Energy Group PLC'),
#  (71, 184, 92, 19, 'Fort Howard Corp.'),
#  (71, 185, 116, 20, 'General Motors Corp.'),
#  (71, 200, 165, 36, 'Morgan Stanley Group Inc.'),
#  (71, 204, 201, 40, 'Renaissance Hotel Group N.V.'),
#  (71, 222, 258, 58, 'Viacom Inc.'),
#  (71, 230, 82, 66, 'Falcon Drilling Co.'),
#  (71, 235, 172, 71, 'New York State Electric & Gas Corp.'),
#  (71, 246, 27, 82, 'Bergen Brunswig Corp.'),
#  (71, 253, 143, 123, 'Lin Television Corp.'),
#  (71, 253, 143, 123, 'Lin Television Corp.'),
#  (71, 278, 32, 114, 'Browning-Ferris Industries Inc.'),
#  (71, 203, 199, 39, 'Read-Rite Corp.'),
#  (71, 116, 138, 128, 'Safety-Kleen Corp.'),
#  (71, 307, 317, 135, 'AT&T Capital Corp.'),
#  (71, 326, 298, 144, 'Mercury Asset Management Group, P.L.C.'),
#  (72, 13, 50, 15, 'Eller Media Corp.'),
#  (72, 167, 6, 2, 'Alex. Brown Inc.'),
#  (73, 1, 24, 2, 'Alex. Brown Inc.'),
#  (73, 77, 192, 84, 'Doubletree Corporation'),
#  (73, 86, 10, 93, 'Western National Corp.'),
#  (73, 116, 138, 128, 'Safety-Kleen Corp.'),
#  (73, 169, 13, 4, 'American Standard Companies, Inc.'),
#  (73, 207, 226, 43, 'Tambrands Inc.'),
#  (73, 216, 253, 52, 'Uslife Corp.'),
#  (73, 241, 213, 77, 'Scudder, Stevens & Clark Inc.'),
#  (73, 277, 4, 113, 'Advanta Corp.'),
#  (73, 313, 311, 138, 'Coulter Corp.'),
#  (73, 323, 300, 143, 'MAPCO Inc.'),
#  (73, 340, 288, 147, 'Showboat Inc.'),
#  (74, 168, 11, 3, 'American Medical Response, Inc.'),
#  (75, 170, 16, 5, 'Amphenol Corp.'),
#  (75, 342, 284, 149, 'Starwood Lodging Corp.'),
#  (76, 2, 140, 3, 'American Medical Response, Inc.'),
#  (76, 3, 135, 5, 'Amphenol Corp.'),
#  (76, 10, 8, 12, 'Dauphin Deposit Corp.'),
#  (76, 17, 128, 19, 'Fort Howard Corp.'),
#  (76, 27, 141, 31, 'KU Energy Corporation'),
#  (76, 54, 9, 61, 'Yorkshire Electricity'),
#  (76, 56, 260, 63, 'Central Fidelity Banks Inc.'),
#  (76, 63, 95, 70, 'The Multicare Companies, Inc.'),
#  (76, 71, 88, 78, 'Signet Banking Corp.'),
#  (76, 74, 76, 81, 'Beacon Properties Corp.'),
#  (76, 88, 121, 95, 'Westinghouse Electric Corp.'),
#  (76, 89, 266, 96, 'American Radio Systems Corp.'),
#  (76, 94, 131, 102, 'Greenfield Industries, Inc.'),
#  (76, 114, 94, 126, 'Quality Food Centers Inc.'),
#  (76, 115, 94, 127, 'Ralphs Grocery Company'),
#  (76, 128, 262, 21, 'Great Western Financial Corp.'),
#  (76, 136, 174, 20, 'General Motors Corp.'),
#  (76, 146, 273, 110, 'Tejas Gas Corp.'),
#  (76, 150, 85, 51, 'U.S. Bancorp'),
#  (76, 153, 97, 34, 'Living Centers of America Inc.'),
#  (76, 164, 250, 108, 'Sony Corporation of America'),
#  (76, 165, 182, 27, 'International Family Entertainment Inc.'),
#  (76, 190, 108, 25, 'HFS Inc.'),
#  (76, 193, 127, 122, 'ITT Corp.'),
#  (76, 193, 127, 122, 'ITT Corp.'),
#  (76, 205, 202, 41, 'Revco D.S., Inc.'),
#  (76, 216, 253, 52, 'Uslife Corp.'),
#  (76, 218, 245, 54, 'U.S. West, Inc.'),
#  (76, 219, 254, 55, 'Valero Energy Corp.'),
#  (76, 236, 174, 72, 'Northrop Grumman Corp.'),
#  (76, 239, 184, 75, 'Pennzoil Comp.'),
#  (76, 240, 207, 76, 'Rykoff Sexton Inc.'),
#  (76, 246, 27, 82, 'Bergen Brunswig Corp.'),
#  (76, 253, 143, 123, 'Lin Television Corp.'),
#  (76, 253, 143, 123, 'Lin Television Corp.'),
#  (76, 267, 157, 103, 'MCI Communications Corporation'),
#  (76, 267, 157, 103, 'MCI Communications Corporation'),
#  (76, 267, 157, 103, 'MCI Communications Corporation'),
#  (76, 279, 60, 115, 'Corestates Financial Corp.'),
#  (76, 293, 250, 130, 'Seagram Company'),
#  (76, 294, 249, 131, 'Universal Outdoor Holdings Inc.'),
#  (76, 306, 316, 135, 'AT&T Capital Corp.'),
#  (76, 311, 313, 137, 'Central & South West Corp.'),
#  (77, 130, 153, 40, 'Renaissance Hotel Group N.V.'),
#  (77, 171, 216, 6, 'Bankamerica Corp.'),
#  (77, 175, 46, 10, 'Cifra S.A.'),
#  (77, 212, 240, 48, 'Transamerica Corp.'),
#  (77, 249, 79, 85, 'Evans Withycombe Residential Inc.'),
#  (77, 262, 19, 98, 'Apria Healthcare Group Inc.'),
#  (77, 273, 204, 109, 'Rohr Inc.'),
#  (77, 287, 151, 124, "Mac Frugal's Bargains & Close-Outs Inc."),
#  (77, 136, 174, 20, 'General Motors Corp.'),
#  (77, 315, 309, 139, 'First of America Bank Corp.'),
#  (78, 39, 81, 45, 'Telco Communications Group Inc.'),
#  (78, 82, 110, 123, 'Lin Television Corp.'),
#  (78, 82, 110, 123, 'Lin Television Corp.'),
#  (78, 148, 136, 118, 'Ernst & Young LLP'),
#  (78, 149, 49, 108, 'Sony Corporation of America'),
#  (78, 174, 43, 9, 'Chancellor Broadcasting Comp.'),
#  (78, 181, 74, 16, 'The Energy Group PLC'),
#  (78, 185, 116, 20, 'General Motors Corp.'),
#  (78, 192, 123, 27, 'International Family Entertainment Inc.'),
#  (78, 218, 245, 54, 'U.S. West, Inc.'),
#  (78, 295, 267, 132, 'Westinghouse Electric Corp.'),
#  (78, 339, 289, 147, 'Showboat Inc.'),
#  (79, 7, 80, 9, 'Chancellor Broadcasting Comp.'),
#  (79, 77, 192, 84, 'Doubletree Corporation'),
#  (79, 120, 219, 132, 'Westinghouse Electric Corp.'),
#  (79, 123, 111, 122, 'ITT Corp.'),
#  (79, 123, 111, 122, 'ITT Corp.'),
#  (79, 180, 73, 15, 'Eller Media Corp.'),
#  (79, 192, 123, 27, 'International Family Entertainment Inc.'),
#  (79, 290, 196, 127, 'Ralphs Grocery Company'),
#  (79, 102, 80, 58, 'Viacom Inc.'),
#  (79, 313, 311, 138, 'Coulter Corp.'),
#  (79, 340, 288, 147, 'Showboat Inc.'),
#  (80, 7, 80, 9, 'Chancellor Broadcasting Comp.'),
#  (80, 34, 18, 39, 'Read-Rite Corp.'),
#  (80, 37, 191, 43, 'Tambrands Inc.'),
#  (80, 53, 183, 60, 'Wyndham Hotel Corp.'),
#  (80, 106, 156, 116, 'Cowles Media Company'),
#  (80, 117, 133, 129, 'Santa Fe Pacific Pipeline Partners'),
#  (80, 124, 30, 103, 'MCI Communications Corporation'),
#  (80, 124, 30, 103, 'MCI Communications Corporation'),
#  (80, 124, 30, 103, 'MCI Communications Corporation'),
#  (80, 128, 262, 21, 'Great Western Financial Corp.'),
#  (80, 146, 273, 110, 'Tejas Gas Corp.'),
#  (80, 192, 123, 27, 'International Family Entertainment Inc.'),
#  (80, 193, 127, 122, 'ITT Corp.'),
#  (80, 193, 127, 122, 'ITT Corp.'),
#  (80, 197, 139, 32, 'Laidlaw Inc.'),
#  (80, 200, 165, 36, 'Morgan Stanley Group Inc.'),
#  (80, 208, 228, 44, 'Target Therapeutics, Inc.'),
#  (80, 217, 244, 53, 'U.S. Robotics Corp.'),
#  (80, 218, 245, 54, 'U.S. West, Inc.'),
#  (80, 219, 254, 55, 'Valero Energy Corp.'),
#  (80, 257, 263, 93, 'Western National Corp.'),
#  (80, 276, 251, 112, 'Viacom Inc.'),
#  (80, 338, 282, 150, 'United Meridian Corp.'),
#  (81, 7, 80, 9, 'Chancellor Broadcasting Comp.'),
#  (81, 18, 198, 20, 'General Motors Corp.'),
#  (81, 40, 134, 46, 'Tencor Instruments Inc.'),
#  (81, 40, 134, 46, 'Tencor Instruments Inc.'),
#  (81, 41, 198, 47, 'Texas Instruments Inc.'),
#  (81, 124, 30, 103, 'MCI Communications Corporation'),
#  (81, 124, 30, 103, 'MCI Communications Corporation'),
#  (81, 124, 30, 103, 'MCI Communications Corporation'),
#  (81, 124, 30, 103, 'MCI Communications Corporation'),
#  (81, 124, 30, 103, 'MCI Communications Corporation'),
#  (81, 124, 30, 103, 'MCI Communications Corporation'),
#  (81, 138, 38, 62, 'Celebrity Cruise Lines Inc'),
#  (81, 138, 38, 62, 'Celebrity Cruise Lines Inc'),
#  (81, 149, 49, 108, 'Sony Corporation of America'),
#  (81, 192, 123, 27, 'International Family Entertainment Inc.'),
#  (81, 205, 202, 41, 'Revco D.S., Inc.'),
#  (81, 234, 166, 70, 'The Multicare Companies, Inc.'),
#  (81, 260, 12, 96, 'American Radio Systems Corp.'),
#  (81, 246, 27, 82, 'Bergen Brunswig Corp.'),
#  (81, 333, 296, 145, 'Renal Treatment Centers Inc.'),
#  (82, 36, 2, 42, 'Stone-Consolidated Corp.'),
#  (82, 176, 51, 11, 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  (83, 9, 52, 11, 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  (84, 9, 52, 11, 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  (85, 9, 52, 11, 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  (85, 206, 224, 42, 'Stone-Consolidated Corp.'),
#  (86, 177, 66, 12, 'Dauphin Deposit Corp.'),
#  (87, 14, 180, 16, 'The Energy Group PLC'),
#  (87, 25, 154, 29, 'Johnson & Higgins'),
#  (87, 26, 242, 30, 'Keystone International Inc.'),
#  (87, 29, 209, 33, 'Lincoln National Corporation'),
#  (87, 33, 162, 38, 'Parker & Parsley Petrolium Company'),
#  (87, 34, 18, 39, 'Read-Rite Corp.'),
#  (87, 36, 2, 42, 'Stone-Consolidated Corp.'),
#  (87, 44, 252, 50, 'United Waste Systems, Inc.'),
#  (87, 45, 10, 52, 'Uslife Corp.'),
#  (87, 54, 9, 61, 'Yorkshire Electricity'),
#  (87, 64, 34, 71, 'New York State Electric & Gas Corp.'),
#  (87, 65, 146, 72, 'Northrop Grumman Corp.'),
#  (87, 68, 247, 75, 'Pennzoil Comp.'),
#  (87, 79, 125, 86, 'Fisher Scientific International Inc.'),
#  (87, 83, 234, 90, 'Monterey Resources Inc.'),
#  (87, 84, 72, 91, 'Ralston Purina Co.'),
#  (87, 86, 10, 93, 'Western National Corp.'),
#  (87, 89, 266, 96, 'American Radio Systems Corp.'),
#  (87, 98, 241, 107, 'Salomon Inc.'),
#  (87, 112, 58, 124, "Mac Frugal's Bargains & Close-Outs Inc."),
#  (87, 123, 111, 122, 'ITT Corp.'),
#  (87, 123, 111, 122, 'ITT Corp.'),
#  (87, 131, 197, 123, 'Lin Television Corp.'),
#  (87, 131, 197, 123, 'Lin Television Corp.'),
#  (87, 146, 273, 110, 'Tejas Gas Corp.'),
#  (87, 157, 57, 64, 'Cigna Corporation'),
#  (87, 159, 25, 121, 'Homeside, Inc.'),
#  (87, 178, 68, 13, 'The Dow Chemical Company'),
#  (87, 183, 89, 18, 'First USA, Inc.'),
#  (87, 186, 98, 21, 'Great Western Financial Corp.'),
#  (87, 187, 102, 22, 'Healthsource, Inc.'),
#  (87, 190, 108, 25, 'HFS Inc.'),
#  (87, 209, 231, 45, 'Telco Communications Group Inc.'),
#  (87, 230, 82, 66, 'Falcon Drilling Co.'),
#  (87, 232, 149, 68, 'The Louisiana Land and Exploration Company'),
#  (87, 244, 25, 80, 'Barnett Banks, Inc.'),
#  (87, 276, 251, 112, 'Viacom Inc.'),
#  (87, 290, 196, 127, 'Ralphs Grocery Company'),
#  (87, 294, 249, 131, 'Universal Outdoor Holdings Inc.'),
#  (87, 116, 138, 128, 'Safety-Kleen Corp.'),
#  (87, 302, 278, 133, 'Allied Colloids Group PLC'),
#  (87, 309, 315, 136, 'BDM International'),
#  (87, 323, 300, 143, 'MAPCO Inc.'),
#  (87, 324, 301, 143, 'MAPCO Inc.'),
#  (87, 327, 290, 146, 'Retail Property Trust'),
#  (87, 334, 297, 145, 'Renal Treatment Centers Inc.'),
#  (87, 337, 283, 150, 'United Meridian Corp.'),
#  (88, 107, 173, 13, 'The Dow Chemical Company'),
#  (88, 191, 113, 26, 'Horizon/CMS Healthcare Corp.'),
#  (88, 202, 181, 38, 'Parker & Parsley Petrolium Company'),
#  (88, 76, 188, 83, 'Chauvco Resources LTD.'),
#  (88, 85, 109, 92, 'SFX Broadcasting Inc.'),
#  (88, 310, 312, 137, 'Central & South West Corp.'),
#  (89, 32, 42, 37, 'Pacificorp'),
#  (89, 34, 18, 39, 'Read-Rite Corp.'),
#  (89, 80, 215, 87, 'W.R. Grace & Comp.'),
#  (89, 107, 173, 13, 'The Dow Chemical Company'),
#  (89, 170, 16, 5, 'Amphenol Corp.'),
#  (89, 187, 102, 22, 'Healthsource, Inc.'),
#  (90, 139, 36, 13, 'The Dow Chemical Company'),
#  (90, 223, 259, 59, 'Vivra Inc.'),
#  (91, 18, 198, 20, 'General Motors Corp.'),
#  (91, 23, 103, 26, 'Horizon/CMS Healthcare Corp.'),
#  (91, 27, 141, 31, 'KU Energy Corporation'),
#  (91, 35, 65, 41, 'Revco D.S., Inc.'),
#  (91, 65, 146, 72, 'Northrop Grumman Corp.'),
#  (91, 68, 247, 75, 'Pennzoil Comp.'),
#  (91, 69, 130, 76, 'Rykoff Sexton Inc.'),
#  (91, 75, 37, 82, 'Bergen Brunswig Corp.'),
#  (91, 125, 100, 21, 'Great Western Financial Corp.'),
#  (91, 126, 69, 40, 'Renaissance Hotel Group N.V.'),
#  (91, 129, 222, 122, 'ITT Corp.'),
#  (91, 129, 222, 122, 'ITT Corp.'),
#  (91, 139, 36, 13, 'The Dow Chemical Company'),
#  (91, 153, 97, 34, 'Living Centers of America Inc.'),
#  (91, 168, 11, 3, 'American Medical Response, Inc.'),
#  (91, 179, 71, 14, 'DQE Inc.'),
#  (91, 215, 243, 51, 'U.S. Bancorp'),
#  (91, 224, 269, 60, 'Wyndham Hotel Corp.'),
#  (91, 234, 166, 70, 'The Multicare Companies, Inc.'),
#  (91, 248, 69, 84, 'Doubletree Corporation'),
#  (91, 272, 147, 108, 'Sony Corporation of America'),
#  (91, 279, 60, 115, 'Corestates Financial Corp.'),
#  (91, 283, 104, 120, 'Healthsouth Corp.'),
#  (91, 284, 112, 121, 'Homeside, Inc.'),
#  (91, 288, 159, 125, 'Medpartners, Inc.'),
#  (91, 288, 159, 125, 'Medpartners, Inc.'),
#  (91, 291, 210, 128, 'Safety-Kleen Corp.'),
#  (91, 260, 12, 96, 'American Radio Systems Corp.'),
#  (91, 298, 275, 27, 'International Family Entertainment Inc.'),
#  (91, 29, 209, 33, 'Lincoln National Corporation'),
#  (91, 132, 268, 103, 'MCI Communications Corporation'),
#  (91, 132, 268, 103, 'MCI Communications Corporation'),
#  (91, 132, 268, 103, 'MCI Communications Corporation'),
#  (91, 269, 189, 105, 'Powernet Victoria'),
#  (91, 129, 222, 122, 'ITT Corp.'),
#  (91, 129, 222, 122, 'ITT Corp.'),
#  (91, 118, 115, 130, 'Seagram Company'),
#  (91, 49, 53, 56, 'Value Health, Inc.'),
#  (91, 257, 263, 93, 'Western National Corp.'),
#  (91, 304, 318, 134, 'American First Financial Insurance Group Inc.'),
#  (92, 117, 133, 129, 'Santa Fe Pacific Pipeline Partners'),
#  (92, 119, 50, 131, 'Universal Outdoor Holdings Inc.'),
#  (92, 337, 283, 150, 'United Meridian Corp.'),
#  (93, 181, 74, 16, 'The Energy Group PLC'),
#  (93, 213, 237, 49, 'The Unilever Group'),
#  (93, 302, 278, 133, 'Allied Colloids Group PLC'),
#  (94, 39, 81, 45, 'Telco Communications Group Inc.'),
#  (94, 124, 30, 103, 'MCI Communications Corporation'),
#  (94, 124, 30, 103, 'MCI Communications Corporation'),
#  (94, 124, 30, 103, 'MCI Communications Corporation'),
#  (94, 181, 74, 16, 'The Energy Group PLC'),
#  (95, 14, 180, 16, 'The Energy Group PLC'),
#  (95, 54, 9, 61, 'Yorkshire Electricity'),
#  (95, 124, 30, 103, 'MCI Communications Corporation'),
#  (95, 124, 30, 103, 'MCI Communications Corporation'),
#  (95, 124, 30, 103, 'MCI Communications Corporation'),
#  (96, 69, 130, 76, 'Rykoff Sexton Inc.'),
#  (96, 182, 87, 17, 'First Financial Corp.'),
#  (96, 74, 76, 81, 'Beacon Properties Corp.'),
#  (97, 183, 89, 18, 'First USA, Inc.'),
#  (98, 11, 208, 117, 'The Dow Chemical Company'),
#  (98, 11, 208, 117, 'The Dow Chemical Company'),
#  (98, 185, 116, 20, 'General Motors Corp.'),
#  (98, 274, 230, 110, 'Tejas Gas Corp.'),
#  (98, 341, 285, 149, 'Starwood Lodging Corp.'),
#  (99, 37, 191, 43, 'Tambrands Inc.'),
#  (99, 60, 72, 67, 'Imperial Chemical Industries PLC'),
#  (99, 63, 95, 70, 'The Multicare Companies, Inc.'),
#  (99, 97, 91, 106, 'The Quick & Reilly Group, Inc.'),
#  (99, 101, 84, 111, 'T&N PLC'),
#  (99, 106, 156, 116, 'Cowles Media Company'),
#  (99, 114, 94, 126, 'Quality Food Centers Inc.'),
#  (99, 115, 94, 127, 'Ralphs Grocery Company'),
#  (99, 130, 153, 40, 'Renaissance Hotel Group N.V.'),
#  (99, 150, 85, 51, 'U.S. Bancorp'),
#  (99, 154, 145, 34, 'Living Centers of America Inc.'),
#  (99, 161, 271, 126, 'Quality Food Centers Inc.'),
#  (99, 185, 116, 20, 'General Motors Corp.'),
#  (99, 247, 45, 83, 'Chauvco Resources LTD.'),
#  (99, 206, 224, 42, 'Stone-Consolidated Corp.'),
#  (99, 311, 313, 137, 'Central & South West Corp.'),
#  (100, 18, 198, 20, 'General Motors Corp.'),
#  (100, 41, 198, 47, 'Texas Instruments Inc.'),
#  (100, 61, 33, 68, 'The Louisiana Land and Exploration Company'),
#  (100, 64, 34, 71, 'New York State Electric & Gas Corp.'),
#  (100, 67, 152, 74, 'Nellcor Puritan Bennett Inc.'),
#  (100, 307, 317, 135, 'AT&T Capital Corp.'),
#  (101, 128, 262, 21, 'Great Western Financial Corp.'),
#  (102, 187, 102, 22, 'Healthsource, Inc.'),
#  (103, 188, 229, 23, 'Hercules Inc. and Mallickrodt Inc'),
#  (104, 188, 229, 23, 'Hercules Inc. and Mallickrodt Inc'),
#  (106, 189, 106, 24, 'Heritage Media Corp.'),
#  (107, 21, 236, 24, 'Heritage Media Corp.'),
#  (108, 24, 93, 27, 'International Family Entertainment Inc.'),
#  (109, 24, 93, 27, 'International Family Entertainment Inc.'),
#  (109, 292, 212, 129, 'Santa Fe Pacific Pipeline Partners'),
#  (109, 143, 273, 92, 'SFX Broadcasting Inc.'),
#  (110, 33, 162, 38, 'Parker & Parsley Petrolium Company'),
#  (110, 160, 175, 30, 'Keystone International Inc.'),
#  (110, 163, 232, 130, 'Seagram Company'),
#  (110, 239, 184, 75, 'Pennzoil Comp.'),
#  (110, 247, 45, 83, 'Chauvco Resources LTD.'),
#  (110, 274, 230, 110, 'Tejas Gas Corp.'),
#  (110, 296, 142, 27, 'International Family Entertainment Inc.'),
#  (112, 226, 40, 62, 'Celebrity Cruise Lines Inc'),
#  (112, 226, 40, 62, 'Celebrity Cruise Lines Inc'),
#  (113, 20, 203, 23, 'Hercules Inc. and Mallickrodt Inc'),
#  (113, 27, 141, 31, 'KU Energy Corporation'),
#  (113, 35, 65, 41, 'Revco D.S., Inc.'),
#  (113, 43, 117, 49, 'The Unilever Group'),
#  (113, 55, 206, 62, 'Celebrity Cruise Lines Inc'),
#  (113, 55, 206, 62, 'Celebrity Cruise Lines Inc'),
#  (113, 61, 33, 68, 'The Louisiana Land and Exploration Company'),
#  (113, 63, 95, 70, 'The Multicare Companies, Inc.'),
#  (113, 72, 55, 79, 'Tandem Computers Inc.'),
#  (113, 79, 125, 86, 'Fisher Scientific International Inc.'),
#  (113, 82, 110, 123, 'Lin Television Corp.'),
#  (113, 82, 110, 123, 'Lin Television Corp.'),
#  (113, 93, 83, 100, 'Calilber Systems Inc.'),
#  (113, 100, 218, 110, 'Tejas Gas Corp.'),
#  (113, 101, 84, 111, 'T&N PLC'),
#  (113, 166, 3, 1, 'ADT Limited'),
#  (113, 189, 106, 24, 'Heritage Media Corp.'),
#  (113, 200, 165, 36, 'Morgan Stanley Group Inc.'),
#  (113, 211, 235, 47, 'Texas Instruments Inc.'),
#  (113, 231, 118, 67, 'Imperial Chemical Industries PLC'),
#  (113, 239, 184, 75, 'Pennzoil Comp.'),
#  (113, 189, 106, 24, 'Heritage Media Corp.'),
#  (113, 83, 234, 90, 'Monterey Resources Inc.'),
#  (113, 80, 215, 87, 'W.R. Grace & Comp.'),
#  (113, 325, 299, 144, 'Mercury Asset Management Group, P.L.C.'),
#  (113, 335, 287, 148, 'Sodexho Alliance S.A.'),
#  (113, 342, 284, 149, 'Starwood Lodging Corp.'),
#  (114, 55, 206, 62, 'Celebrity Cruise Lines Inc'),
#  (114, 55, 206, 62, 'Celebrity Cruise Lines Inc'),
#  (116, 1, 24, 2, 'Alex. Brown Inc.'),
#  (116, 10, 8, 12, 'Dauphin Deposit Corp.'),
#  (116, 16, 23, 18, 'First USA, Inc.'),
#  (116, 17, 128, 19, 'Fort Howard Corp.'),
#  (116, 18, 198, 20, 'General Motors Corp.'),
#  (116, 22, 64, 25, 'HFS Inc.'),
#  (116, 29, 209, 33, 'Lincoln National Corporation'),
#  (116, 41, 198, 47, 'Texas Instruments Inc.'),
#  (116, 51, 214, 112, 'Viacom Inc.'),
#  (116, 62, 169, 69, 'Montgomery Securities'),
#  (116, 69, 130, 76, 'Rykoff Sexton Inc.'),
#  (116, 73, 169, 80, 'Barnett Banks, Inc.'),
#  (116, 75, 37, 82, 'Bergen Brunswig Corp.'),
#  (116, 91, 126, 98, 'Apria Healthcare Group Inc.'),
#  (116, 99, 22, 109, 'Rohr Inc.'),
#  (116, 103, 91, 113, 'Advanta Corp.'),
#  (116, 108, 23, 119, 'First Commerce Corp.'),
#  (116, 118, 115, 130, 'Seagram Company'),
#  (116, 123, 111, 122, 'ITT Corp.'),
#  (116, 123, 111, 122, 'ITT Corp.'),
#  (116, 212, 240, 48, 'Transamerica Corp.'),
#  (116, 214, 248, 50, 'United Waste Systems, Inc.'),
#  (116, 215, 243, 51, 'U.S. Bancorp'),
#  (116, 219, 254, 55, 'Valero Energy Corp.'),
#  (116, 227, 41, 63, 'Central Fidelity Banks Inc.'),
#  (116, 242, 220, 78, 'Signet Banking Corp.'),
#  (116, 250, 90, 86, 'Fisher Scientific International Inc.'),
#  (116, 251, 63, 87, 'W.R. Grace & Comp.'),
#  (116, 270, 195, 106, 'The Quick & Reilly Group, Inc.'),
#  (116, 314, 308, 139, 'First of America Bank Corp.'),
#  (116, 320, 183, 141, 'Interstate Hotel Company'),
#  (116, 320, 183, 141, 'Interstate Hotel Company'),
#  (119, 120, 219, 132, 'Westinghouse Electric Corp.'),
#  (119, 246, 27, 82, 'Bergen Brunswig Corp.'),
#  (119, 313, 311, 138, 'Coulter Corp.'),
#  (119, 322, 303, 142, 'Lucas Varity PLC'),
#  (120, 31, 67, 36, 'Morgan Stanley Group Inc.'),
#  (120, 89, 266, 96, 'American Radio Systems Corp.'),
#  (120, 91, 126, 98, 'Apria Healthcare Group Inc.'),
#  (120, 100, 218, 110, 'Tejas Gas Corp.'),
#  (120, 121, 256, 58, 'Viacom Inc.'),
#  (120, 122, 264, 1, 'ADT Limited'),
#  (120, 132, 268, 103, 'MCI Communications Corporation'),
#  (120, 132, 268, 103, 'MCI Communications Corporation'),
#  (120, 132, 268, 103, 'MCI Communications Corporation'),
#  (120, 147, 190, 101, 'Coopers & Lybrand L.L.P.'),
#  (120, 193, 127, 122, 'ITT Corp.'),
#  (120, 193, 127, 122, 'ITT Corp.'),
#  (120, 205, 202, 41, 'Revco D.S., Inc.'),
#  (120, 213, 237, 49, 'The Unilever Group'),
#  (120, 251, 63, 87, 'W.R. Grace & Comp.'),
#  (120, 252, 56, 88, 'H&R Block Inc.'),
#  (120, 259, 238, 95, 'Westinghouse Electric Corp.'),
#  (120, 261, 15, 97, 'Amerisource Health Corp.'),
#  (120, 263, 31, 99, 'Brooks Fiber Properties, Inc.'),
#  (120, 264, 35, 100, 'Calilber Systems Inc.'),
#  (120, 271, 211, 107, 'Salomon Inc.'),
#  (120, 59, 200, 66, 'Falcon Drilling Co.'),
#  (120, 132, 268, 103, 'MCI Communications Corporation'),
#  (120, 132, 268, 103, 'MCI Communications Corporation'),
#  (120, 132, 268, 103, 'MCI Communications Corporation'),
#  (120, 66, 150, 73, 'Octel Communications Corporation'),
#  (120, 237, 176, 73, 'Octel Communications Corporation'),
#  (120, 319, 305, 141, 'Interstate Hotel Company'),
#  (120, 319, 305, 141, 'Interstate Hotel Company'),
#  (120, 332, 295, 146, 'Retail Property Trust'),
#  (120, 333, 296, 145, 'Renal Treatment Centers Inc.'),
#  (121, 193, 127, 122, 'ITT Corp.'),
#  (121, 193, 127, 122, 'ITT Corp.'),
#  (122, 195, 132, 30, 'Keystone International Inc.'),
#  (123, 27, 141, 31, 'KU Energy Corporation'),
#  (124, 2, 140, 3, 'American Medical Response, Inc.'),
#  (124, 116, 138, 128, 'Safety-Kleen Corp.'),
#  (124, 197, 139, 32, 'Laidlaw Inc.'),
#  (125, 57, 144, 64, 'Cigna Corporation'),
#  (125, 198, 14, 33, 'Lincoln National Corporation'),
#  (126, 29, 209, 33, 'Lincoln National Corporation'),
#  (127, 154, 145, 34, 'Living Centers of America Inc.'),
#  (128, 129, 222, 122, 'ITT Corp.'),
#  (128, 129, 222, 122, 'ITT Corp.'),
#  (128, 151, 17, 34, 'Living Centers of America Inc.'),
#  (128, 206, 224, 42, 'Stone-Consolidated Corp.'),
#  (128, 289, 194, 126, 'Quality Food Centers Inc.'),
#  (128, 87, 223, 94, 'Westin Hotels & Resorts'),
#  (129, 117, 133, 129, 'Santa Fe Pacific Pipeline Partners'),
#  (129, 153, 97, 34, 'Living Centers of America Inc.'),
#  (129, 254, 163, 90, 'Monterey Resources Inc.'),
#  (129, 316, 306, 140, 'Hermann Healthcare System'),
#  (129, 338, 282, 150, 'United Meridian Corp.'),
#  (129, 343, 281, 151, 'Zilkha Energy Co.'),
#  (130, 30, 177, 35, 'Minnesota Mining and Manufacturing Comp.'),
#  (130, 153, 97, 34, 'Living Centers of America Inc.'),
#  (132, 32, 42, 37, 'Pacificorp'),
#  (133, 32, 42, 37, 'Pacificorp'),
#  (136, 204, 201, 40, 'Renaissance Hotel Group N.V.'),
#  (137, 130, 153, 40, 'Renaissance Hotel Group N.V.'),
#  (137, 297, 274, 103, 'MCI Communications Corporation'),
#  (137, 297, 274, 103, 'MCI Communications Corporation'),
#  (137, 297, 274, 103, 'MCI Communications Corporation'),
#  (137, 327, 290, 146, 'Retail Property Trust'),
#  (137, 336, 153, 148, 'Sodexho Alliance S.A.'),
#  (138, 37, 191, 43, 'Tambrands Inc.'),
#  (139, 37, 191, 43, 'Tambrands Inc.'),
#  (140, 208, 228, 44, 'Target Therapeutics, Inc.'),
#  (141, 39, 81, 45, 'Telco Communications Group Inc.'),
#  (142, 39, 81, 45, 'Telco Communications Group Inc.'),
#  (143, 81, 268, 88, 'H&R Block Inc.'),
#  (143, 210, 233, 46, 'Tencor Instruments Inc.'),
#  (144, 40, 134, 46, 'Tencor Instruments Inc.'),
#  (144, 50, 107, 57, 'Verifone, Inc.'),
#  (144, 203, 199, 39, 'Read-Rite Corp.'),
#  (144, 95, 155, 104, 'Network General Corp.'),
#  (144, 237, 176, 73, 'Octel Communications Corporation'),
#  (145, 42, 114, 48, 'Transamerica Corp.'),
#  (145, 72, 55, 79, 'Tandem Computers Inc.'),
#  (145, 147, 190, 101, 'Coopers & Lybrand L.L.P.'),
#  (146, 214, 248, 50, 'United Waste Systems, Inc.'),
#  (147, 215, 243, 51, 'U.S. Bancorp'),
#  (148, 150, 85, 51, 'U.S. Bancorp'),
#  (149, 178, 68, 13, 'The Dow Chemical Company'),
#  (149, 217, 244, 53, 'U.S. Robotics Corp.'),
#  (149, 292, 212, 129, 'Santa Fe Pacific Pipeline Partners'),
#  (149, 281, 70, 117, 'The Dow Chemical Company'),
#  (149, 281, 70, 117, 'The Dow Chemical Company'),
#  (150, 6, 20, 8, 'Cascade Communications Corp.'),
#  (150, 46, 1, 53, 'U.S. Robotics Corp.'),
#  (151, 16, 23, 18, 'First USA, Inc.'),
#  (151, 64, 34, 71, 'New York State Electric & Gas Corp.'),
#  (151, 70, 272, 77, 'Scudder, Stevens & Clark Inc.'),
#  (151, 90, 158, 97, 'Amerisource Health Corp.'),
#  (151, 220, 255, 56, 'Value Health, Inc.'),
#  (151, 253, 143, 123, 'Lin Television Corp.'),
#  (151, 253, 143, 123, 'Lin Television Corp.'),
#  (151, 304, 318, 134, 'American First Financial Insurance Group Inc.'),
#  (151, 308, 314, 136, 'BDM International'),
#  (151, 331, 294, 146, 'Retail Property Trust'),
#  (152, 221, 257, 57, 'Verifone, Inc.'),
#  (153, 50, 107, 57, 'Verifone, Inc.'),
#  (154, 53, 183, 60, 'Wyndham Hotel Corp.'),
#  (154, 245, 26, 81, 'Beacon Properties Corp.'),
#  (154, 320, 183, 141, 'Interstate Hotel Company'),
#  (154, 320, 183, 141, 'Interstate Hotel Company'),
#  (155, 225, 270, 61, 'Yorkshire Electricity'),
#  (156, 54, 9, 61, 'Yorkshire Electricity'),
#  (156, 176, 51, 11, 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  (156, 232, 149, 68, 'The Louisiana Land and Exploration Company'),
#  (156, 321, 302, 142, 'Lucas Varity PLC'),
#  (157, 19, 48, 22, 'Healthsource, Inc.'),
#  (157, 37, 191, 43, 'Tambrands Inc.'),
#  (157, 75, 37, 82, 'Bergen Brunswig Corp.'),
#  (157, 89, 266, 96, 'American Radio Systems Corp.'),
#  (157, 99, 22, 109, 'Rohr Inc.'),
#  (157, 124, 30, 103, 'MCI Communications Corporation'),
#  (157, 124, 30, 103, 'MCI Communications Corporation'),
#  (157, 124, 30, 103, 'MCI Communications Corporation'),
#  (157, 152, 78, 118, 'Ernst & Young LLP'),
#  (157, 155, 101, 60, 'Wyndham Hotel Corp.'),
#  (157, 196, 137, 31, 'KU Energy Corporation'),
#  (157, 228, 47, 64, 'Cigna Corporation'),
#  (157, 240, 207, 76, 'Rykoff Sexton Inc.'),
#  (157, 264, 35, 100, 'Calilber Systems Inc.'),
#  (157, 295, 267, 132, 'Westinghouse Electric Corp.'),
#  (157, 309, 315, 136, 'BDM International'),
#  (157, 310, 312, 137, 'Central & South West Corp.'),
#  (157, 315, 309, 139, 'First of America Bank Corp.'),
#  (157, 318, 304, 141, 'Interstate Hotel Company'),
#  (157, 318, 304, 141, 'Interstate Hotel Company'),
#  (157, 324, 301, 143, 'MAPCO Inc.'),
#  (160, 54, 9, 61, 'Yorkshire Electricity'),
#  (160, 325, 299, 144, 'Mercury Asset Management Group, P.L.C.'),
#  (161, 105, 88, 115, 'Corestates Financial Corp.'),
#  (161, 113, 187, 125, 'Medpartners, Inc.'),
#  (164, 256, 217, 92, 'SFX Broadcasting Inc.'),
#  (173, 117, 133, 129, 'Santa Fe Pacific Pipeline Partners'),
#  (173, 344, 280, 151, 'Zilkha Energy Co.'),
#  (177, 32, 42, 37, 'Pacificorp'),
#  (188, 48, 185, 55, 'Valero Energy Corp.'),
#  (188, 179, 71, 14, 'DQE Inc.'),
#  (188, 28, 205, 32, 'Laidlaw Inc.'),
#  (190, 224, 269, 60, 'Wyndham Hotel Corp.'),
#  (196, 44, 252, 50, 'United Waste Systems, Inc.'),
#  (196, 188, 229, 23, 'Hercules Inc. and Mallickrodt Inc'),
#  (197, 17, 128, 19, 'Fort Howard Corp.'),
#  (197, 242, 220, 78, 'Signet Banking Corp.'),
#  (199, 68, 247, 75, 'Pennzoil Comp.'),
#  (199, 300, 273, 127, 'Ralphs Grocery Company'),
#  (199, 143, 273, 92, 'SFX Broadcasting Inc.'),
#  (200, 238, 170, 74, 'Nellcor Puritan Bennett Inc.'),
#  (200, 243, 227, 79, 'Tandem Computers Inc.'),
#  (204, 48, 185, 55, 'Valero Energy Corp.'),
#  (204, 66, 150, 73, 'Octel Communications Corporation'),
#  (205, 164, 250, 108, 'Sony Corporation of America'),
#  (207, 47, 5, 54, 'U.S. West, Inc.'),
#  (207, 106, 156, 116, 'Cowles Media Company'),
#  (210, 116, 138, 128, 'Safety-Kleen Corp.'),
#  (215, 109, 122, 120, 'Healthsouth Corp.'),
#  (217, 167, 6, 2, 'Alex. Brown Inc.'),
#  (217, 180, 73, 15, 'Eller Media Corp.'),
#  (219, 175, 46, 10, 'Cifra S.A.'),
#  (220, 36, 2, 42, 'Stone-Consolidated Corp.'),
#  (222, 18, 198, 20, 'General Motors Corp.'),
#  (222, 41, 198, 47, 'Texas Instruments Inc.'),
#  (222, 65, 146, 72, 'Northrop Grumman Corp.'),
#  (222, 116, 138, 128, 'Safety-Kleen Corp.'),
#  (222, 122, 264, 1, 'ADT Limited'),
#  (222, 129, 222, 122, 'ITT Corp.'),
#  (222, 129, 222, 122, 'ITT Corp.'),
#  (222, 171, 216, 6, 'Bankamerica Corp.'),
#  (222, 187, 102, 22, 'Healthsource, Inc.'),
#  (222, 190, 108, 25, 'HFS Inc.'),
#  (222, 192, 123, 27, 'International Family Entertainment Inc.'),
#  (222, 294, 249, 131, 'Universal Outdoor Holdings Inc.'),
#  (222, 309, 315, 136, 'BDM International'),
#  (225, 1, 24, 2, 'Alex. Brown Inc.'),
#  (225, 60, 72, 67, 'Imperial Chemical Industries PLC'),
#  (225, 77, 192, 84, 'Doubletree Corporation'),
#  (225, 84, 72, 91, 'Ralston Purina Co.'),
#  (225, 277, 4, 113, 'Advanta Corp.'),
#  (227, 89, 266, 96, 'American Radio Systems Corp.'),
#  (227, 107, 173, 13, 'The Dow Chemical Company'),
#  (227, 122, 264, 1, 'ADT Limited'),
#  (227, 153, 97, 34, 'Living Centers of America Inc.'),
#  (228, 30, 177, 35, 'Minnesota Mining and Manufacturing Comp.'),
#  (228, 307, 317, 135, 'AT&T Capital Corp.'),
#  (229, 9, 52, 11, 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  (234, 9, 52, 11, 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  (234, 11, 208, 117, 'The Dow Chemical Company'),
#  (234, 11, 208, 117, 'The Dow Chemical Company'),
#  (234, 18, 198, 20, 'General Motors Corp.'),
#  (234, 35, 65, 41, 'Revco D.S., Inc.'),
#  (234, 36, 2, 42, 'Stone-Consolidated Corp.'),
#  (234, 56, 260, 63, 'Central Fidelity Banks Inc.'),
#  (234, 62, 169, 69, 'Montgomery Securities'),
#  (234, 64, 34, 71, 'New York State Electric & Gas Corp.'),
#  (234, 71, 88, 78, 'Signet Banking Corp.'),
#  (234, 83, 234, 90, 'Monterey Resources Inc.'),
#  (234, 91, 126, 98, 'Apria Healthcare Group Inc.'),
#  (234, 121, 256, 58, 'Viacom Inc.'),
#  (234, 125, 100, 21, 'Great Western Financial Corp.'),
#  (234, 127, 242, 1, 'ADT Limited'),
#  (234, 118, 115, 130, 'Seagram Company'),
#  (234, 135, 242, 4, 'American Standard Companies, Inc.'),
#  (234, 139, 36, 13, 'The Dow Chemical Company'),
#  (234, 154, 145, 34, 'Living Centers of America Inc.'),
#  (234, 179, 71, 14, 'DQE Inc.'),
#  (234, 215, 243, 51, 'U.S. Bancorp'),
#  (234, 230, 82, 66, 'Falcon Drilling Co.'),
#  (234, 251, 63, 87, 'W.R. Grace & Comp.'),
#  (234, 260, 12, 96, 'American Radio Systems Corp.'),
#  (234, 266, 99, 102, 'Greenfield Industries, Inc.'),
#  (234, 269, 189, 105, 'Powernet Victoria'),
#  (234, 272, 147, 108, 'Sony Corporation of America'),
#  (234, 279, 60, 115, 'Corestates Financial Corp.'),
#  (234, 291, 210, 128, 'Safety-Kleen Corp.'),
#  (236, 13, 50, 15, 'Eller Media Corp.'),
#  (237, 6, 20, 8, 'Cascade Communications Corp.'),
#  (237, 221, 257, 57, 'Verifone, Inc.'),
#  (237, 66, 150, 73, 'Octel Communications Corporation'),
#  (237, 302, 278, 133, 'Allied Colloids Group PLC'),
#  (238, 188, 229, 23, 'Hercules Inc. and Mallickrodt Inc'),
#  (238, 232, 149, 68, 'The Louisiana Land and Exploration Company'),
#  (238, 302, 278, 133, 'Allied Colloids Group PLC'),
#  (239, 3, 135, 5, 'Amphenol Corp.'),
#  (239, 35, 65, 41, 'Revco D.S., Inc.'),
#  (239, 44, 252, 50, 'United Waste Systems, Inc.'),
#  (239, 80, 215, 87, 'W.R. Grace & Comp.'),
#  (239, 109, 122, 120, 'Healthsouth Corp.'),
#  (239, 123, 111, 122, 'ITT Corp.'),
#  (239, 123, 111, 122, 'ITT Corp.'),
#  (239, 189, 106, 24, 'Heritage Media Corp.'),
#  (239, 209, 231, 45, 'Telco Communications Group Inc.'),
#  (239, 257, 263, 93, 'Western National Corp.'),
#  (239, 290, 196, 127, 'Ralphs Grocery Company'),
#  (239, 306, 316, 135, 'AT&T Capital Corp.'),
#  (239, 334, 297, 145, 'Renal Treatment Centers Inc.'),
#  (240, 5, 124, 7, 'Berliner Kraft & Licht AG'),
#  (243, 222, 258, 58, 'Viacom Inc.'),
#  (244, 49, 53, 56, 'Value Health, Inc.'),
#  (246, 34, 18, 39, 'Read-Rite Corp.'),
#  (246, 270, 195, 106, 'The Quick & Reilly Group, Inc.'),
#  (247, 225, 270, 61, 'Yorkshire Electricity'),
#  (247, 235, 172, 71, 'New York State Electric & Gas Corp.'),
#  (248, 14, 180, 16, 'The Energy Group PLC'),
#  (248, 19, 48, 22, 'Healthsource, Inc.'),
#  (248, 22, 64, 25, 'HFS Inc.'),
#  (248, 37, 191, 43, 'Tambrands Inc.'),
#  (248, 43, 117, 49, 'The Unilever Group'),
#  (248, 46, 1, 53, 'U.S. Robotics Corp.'),
#  (248, 51, 214, 112, 'Viacom Inc.'),
#  (248, 67, 152, 74, 'Nellcor Puritan Bennett Inc.'),
#  (248, 69, 130, 76, 'Rykoff Sexton Inc.'),
#  (248, 73, 169, 80, 'Barnett Banks, Inc.'),
#  (248, 76, 188, 83, 'Chauvco Resources LTD.'),
#  (248, 86, 10, 93, 'Western National Corp.'),
#  (248, 99, 22, 109, 'Rohr Inc.'),
#  (248, 100, 218, 110, 'Tejas Gas Corp.'),
#  (248, 114, 94, 126, 'Quality Food Centers Inc.'),
#  (248, 115, 94, 127, 'Ralphs Grocery Company'),
#  (248, 117, 133, 129, 'Santa Fe Pacific Pipeline Partners'),
#  (248, 120, 219, 132, 'Westinghouse Electric Corp.'),
#  (248, 150, 85, 51, 'U.S. Bancorp'),
#  (248, 156, 178, 62, 'Celebrity Cruise Lines Inc'),
#  (248, 156, 178, 62, 'Celebrity Cruise Lines Inc'),
#  (248, 169, 13, 4, 'American Standard Companies, Inc.'),
#  (248, 174, 43, 9, 'Chancellor Broadcasting Comp.'),
#  (248, 175, 46, 10, 'Cifra S.A.'),
#  (248, 185, 116, 20, 'General Motors Corp.'),
#  (248, 186, 98, 21, 'Great Western Financial Corp.'),
#  (248, 188, 229, 23, 'Hercules Inc. and Mallickrodt Inc'),
#  (248, 192, 123, 27, 'International Family Entertainment Inc.'),
#  (248, 193, 127, 122, 'ITT Corp.'),
#  (248, 193, 127, 122, 'ITT Corp.'),
#  (248, 195, 132, 30, 'Keystone International Inc.'),
#  (248, 196, 137, 31, 'KU Energy Corporation'),
#  (248, 198, 14, 33, 'Lincoln National Corporation'),
#  (248, 199, 167, 35, 'Minnesota Mining and Manufacturing Comp.'),
#  (248, 202, 181, 38, 'Parker & Parsley Petrolium Company'),
#  (248, 208, 228, 44, 'Target Therapeutics, Inc.'),
#  (248, 212, 240, 48, 'Transamerica Corp.'),
#  (248, 214, 248, 50, 'United Waste Systems, Inc.'),
#  (248, 223, 259, 59, 'Vivra Inc.'),
#  (248, 228, 47, 64, 'Cigna Corporation'),
#  (248, 231, 118, 67, 'Imperial Chemical Industries PLC'),
#  (248, 237, 176, 73, 'Octel Communications Corporation'),
#  (248, 241, 213, 77, 'Scudder, Stevens & Clark Inc.'),
#  (248, 252, 56, 88, 'H&R Block Inc.'),
#  (248, 254, 163, 90, 'Monterey Resources Inc.'),
#  (248, 261, 15, 97, 'Amerisource Health Corp.'),
#  (248, 262, 19, 98, 'Apria Healthcare Group Inc.'),
#  (248, 264, 35, 100, 'Calilber Systems Inc.'),
#  (248, 270, 195, 106, 'The Quick & Reilly Group, Inc.'),
#  (248, 280, 61, 116, 'Cowles Media Company'),
#  (248, 281, 70, 117, 'The Dow Chemical Company'),
#  (248, 281, 70, 117, 'The Dow Chemical Company'),
#  (248, 203, 199, 39, 'Read-Rite Corp.'),
#  (248, 293, 250, 130, 'Seagram Company'),
#  (248, 297, 274, 103, 'MCI Communications Corporation'),
#  (248, 297, 274, 103, 'MCI Communications Corporation'),
#  (248, 297, 274, 103, 'MCI Communications Corporation'),
#  (248, 8, 261, 10, 'Cifra S.A.'),
#  (248, 258, 265, 94, 'Westin Hotels & Resorts'),
#  (248, 305, 319, 134, 'American First Financial Insurance Group Inc.'),
#  (248, 312, 310, 138, 'Coulter Corp.'),
#  (248, 329, 292, 146, 'Retail Property Trust'),
#  (248, 343, 281, 151, 'Zilkha Energy Co.'),
#  (249, 72, 55, 79, 'Tandem Computers Inc.'),
#  (249, 82, 110, 123, 'Lin Television Corp.'),
#  (249, 82, 110, 123, 'Lin Television Corp.'),
#  (249, 174, 43, 9, 'Chancellor Broadcasting Comp.'),
#  (251, 268, 171, 104, 'Network General Corp.'),
#  (257, 110, 168, 121, 'Homeside, Inc.'),
#  (257, 227, 41, 63, 'Central Fidelity Banks Inc.'),
#  (257, 282, 86, 119, 'First Commerce Corp.'),
#  (258, 181, 74, 16, 'The Energy Group PLC'),
#  (258, 325, 299, 144, 'Mercury Asset Management Group, P.L.C.'),
#  (259, 16, 23, 18, 'First USA, Inc.'),
#  (259, 32, 42, 37, 'Pacificorp'),
#  (259, 70, 272, 77, 'Scudder, Stevens & Clark Inc.'),
#  (259, 193, 127, 122, 'ITT Corp.'),
#  (259, 193, 127, 122, 'ITT Corp.'),
#  (259, 213, 237, 49, 'The Unilever Group'),
#  (259, 250, 90, 86, 'Fisher Scientific International Inc.'),
#  (259, 267, 157, 103, 'MCI Communications Corporation'),
#  (259, 267, 157, 103, 'MCI Communications Corporation'),
#  (259, 267, 157, 103, 'MCI Communications Corporation'),
#  (259, 321, 302, 142, 'Lucas Varity PLC'),
#  (259, 327, 290, 146, 'Retail Property Trust'),
#  (260, 38, 29, 44, 'Target Therapeutics, Inc.'),
#  (260, 39, 81, 45, 'Telco Communications Group Inc.'),
#  (260, 64, 34, 71, 'New York State Electric & Gas Corp.'),
#  (260, 65, 146, 72, 'Northrop Grumman Corp.'),
#  (260, 91, 126, 98, 'Apria Healthcare Group Inc.'),
#  (260, 103, 91, 113, 'Advanta Corp.'),
#  (260, 128, 262, 21, 'Great Western Financial Corp.'),
#  (260, 170, 16, 5, 'Amphenol Corp.'),
#  (260, 210, 233, 46, 'Tencor Instruments Inc.'),
#  (260, 218, 245, 54, 'U.S. West, Inc.'),
#  (260, 219, 254, 55, 'Valero Energy Corp.'),
#  (260, 239, 184, 75, 'Pennzoil Comp.'),
#  (260, 243, 227, 79, 'Tandem Computers Inc.'),
#  (260, 267, 157, 103, 'MCI Communications Corporation'),
#  (260, 267, 157, 103, 'MCI Communications Corporation'),
#  (260, 267, 157, 103, 'MCI Communications Corporation'),
#  (260, 256, 217, 92, 'SFX Broadcasting Inc.'),
#  (260, 338, 282, 150, 'United Meridian Corp.'),
#  (261, 182, 87, 17, 'First Financial Corp.'),
#  (263, 2, 140, 3, 'American Medical Response, Inc.'),
#  (263, 10, 8, 12, 'Dauphin Deposit Corp.'),
#  (263, 12, 7, 14, 'DQE Inc.'),
#  (263, 17, 128, 19, 'Fort Howard Corp.'),
#  (263, 21, 236, 24, 'Heritage Media Corp.'),
#  (263, 33, 162, 38, 'Parker & Parsley Petrolium Company'),
#  (263, 40, 134, 46, 'Tencor Instruments Inc.'),
#  (263, 48, 185, 55, 'Valero Energy Corp.'),
#  (263, 54, 9, 61, 'Yorkshire Electricity'),
#  (263, 57, 144, 64, 'Cigna Corporation'),
#  (263, 73, 169, 80, 'Barnett Banks, Inc.'),
#  (263, 74, 76, 81, 'Beacon Properties Corp.'),
#  (263, 79, 125, 86, 'Fisher Scientific International Inc.'),
#  (263, 88, 121, 95, 'Westinghouse Electric Corp.'),
#  (263, 93, 83, 100, 'Calilber Systems Inc.'),
#  (263, 94, 131, 102, 'Greenfield Industries, Inc.'),
#  (263, 103, 91, 113, 'Advanta Corp.'),
#  (263, 112, 58, 124, "Mac Frugal's Bargains & Close-Outs Inc."),
#  (263, 129, 222, 122, 'ITT Corp.'),
#  (263, 129, 222, 122, 'ITT Corp.'),
#  (263, 131, 197, 123, 'Lin Television Corp.'),
#  (263, 131, 197, 123, 'Lin Television Corp.'),
#  (263, 146, 273, 110, 'Tejas Gas Corp.'),
#  (263, 150, 85, 51, 'U.S. Bancorp'),
#  (263, 166, 3, 1, 'ADT Limited'),
#  (263, 170, 16, 5, 'Amphenol Corp.'),
#  (263, 183, 89, 18, 'First USA, Inc.'),
#  (263, 185, 116, 20, 'General Motors Corp.'),
#  (263, 186, 98, 21, 'Great Western Financial Corp.'),
#  (263, 190, 108, 25, 'HFS Inc.'),
#  (263, 191, 113, 26, 'Horizon/CMS Healthcare Corp.'),
#  (263, 205, 202, 41, 'Revco D.S., Inc.'),
#  (263, 216, 253, 52, 'Uslife Corp.'),
#  (263, 220, 255, 56, 'Value Health, Inc.'),
#  (263, 232, 149, 68, 'The Louisiana Land and Exploration Company'),
#  (263, 240, 207, 76, 'Rykoff Sexton Inc.'),
#  (263, 246, 27, 82, 'Bergen Brunswig Corp.'),
#  (263, 251, 63, 87, 'W.R. Grace & Comp.'),
#  (263, 274, 230, 110, 'Tejas Gas Corp.'),
#  (263, 284, 112, 121, 'Homeside, Inc.'),
#  (263, 289, 194, 126, 'Quality Food Centers Inc.'),
#  (263, 116, 138, 128, 'Safety-Kleen Corp.'),
#  (263, 45, 10, 52, 'Uslife Corp.'),
#  (263, 307, 317, 135, 'AT&T Capital Corp.'),
#  (263, 313, 311, 138, 'Coulter Corp.'),
#  (263, 318, 304, 141, 'Interstate Hotel Company'),
#  (263, 318, 304, 141, 'Interstate Hotel Company'),
#  (263, 322, 303, 142, 'Lucas Varity PLC'),
#  (263, 331, 294, 146, 'Retail Property Trust'),
#  (263, 336, 153, 148, 'Sodexho Alliance S.A.'),
#  (263, 337, 283, 150, 'United Meridian Corp.'),
#  (263, 344, 280, 151, 'Zilkha Energy Co.'),
#  (265, 63, 95, 70, 'The Multicare Companies, Inc.'),
#  (265, 73, 169, 80, 'Barnett Banks, Inc.'),
#  (265, 125, 100, 21, 'Great Western Financial Corp.'),
#  (265, 126, 69, 40, 'Renaissance Hotel Group N.V.'),
#  (265, 34, 18, 39, 'Read-Rite Corp.'),
#  (266, 33, 162, 38, 'Parker & Parsley Petrolium Company'),
#  (266, 42, 114, 48, 'Transamerica Corp.'),
#  (266, 47, 5, 54, 'U.S. West, Inc.'),
#  (266, 50, 107, 57, 'Verifone, Inc.'),
#  (266, 52, 119, 59, 'Vivra Inc.'),
#  (266, 59, 200, 66, 'Falcon Drilling Co.'),
#  (266, 61, 33, 68, 'The Louisiana Land and Exploration Company'),
#  (266, 72, 55, 79, 'Tandem Computers Inc.'),
#  (266, 124, 30, 103, 'MCI Communications Corporation'),
#  (266, 124, 30, 103, 'MCI Communications Corporation'),
#  (266, 124, 30, 103, 'MCI Communications Corporation'),
#  (266, 173, 39, 8, 'Cascade Communications Corp.'),
#  (266, 177, 66, 12, 'Dauphin Deposit Corp.'),
#  (266, 178, 68, 13, 'The Dow Chemical Company'),
#  (266, 181, 74, 16, 'The Energy Group PLC'),
#  (266, 184, 92, 19, 'Fort Howard Corp.'),
#  (266, 194, 129, 29, 'Johnson & Higgins'),
#  (266, 200, 165, 36, 'Morgan Stanley Group Inc.'),
#  (266, 204, 201, 40, 'Renaissance Hotel Group N.V.'),
#  (266, 207, 226, 43, 'Tambrands Inc.'),
#  (266, 217, 244, 53, 'U.S. Robotics Corp.'),
#  (266, 235, 172, 71, 'New York State Electric & Gas Corp.'),
#  (266, 238, 170, 74, 'Nellcor Puritan Bennett Inc.'),
#  (266, 253, 143, 123, 'Lin Television Corp.'),
#  (266, 253, 143, 123, 'Lin Television Corp.'),
#  ...]
